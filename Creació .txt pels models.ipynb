# %%
# IMPORT THE NECESSARY LIBRARIES
import pandas as pd
import os

# %%
# OPEN GDC MANIFEST
mf_name = 'C:/Users/NOE/Desktop/Mostres descarregades/MANIFEST3.txt'
data = pd.read_csv(mf_name, delimiter='\t')

# %%
#CREATE THE FILE WHERE DF IS GOING TO BE SAVED
try:
    df_file_name = 'C:/Users/NOE/Desktop/Mostres descarregades/adrenal_gland3.txt'
    df_file = open(df_file_name, 'w')
    print('File has been created')
except Exception as e:
    print('File hasn\'t been opened:', e)
# Out:
# File has been created

# %%
# LOOPING THROUGH FILES IDs TO ACCESS THE FILES, DF IS CREATED WITH TPM EXPESSION DATA

compt = 0
df = pd.DataFrame()

for _, row in data.iterrows():
    file_name = str(row[1])
    
    file_path = 'C:/Users/NOE/Desktop/Mostres descarregades/' + file_name
    
    if os.path.exists(file_path):  
        data_sample = pd.read_csv(file_path, delimiter='\t', skiprows=[0, 2, 3, 4, 5])
        
        df[file_name] = data_sample.set_index('gene_name')['tpm_unstranded']
        compt += 1
        print(f'Sample nº {compt} added into df')
    else:
        print(f'File not found: {file_path}')
# Out:
# Sample nº 1 added into df

# %%
df.to_csv(df_file_name)
df = df.loc[:, ~df.columns.duplicated()]
df.head(10)
# Out:
#            2f7e6f7f-a4f9-4849-8add-3fbafb75b5c2/9406f2f9-832a-42e7-b5e9-a48924b573b7.rna_seq.augmented_star_gene_counts.tsv
# gene_name
# TSPAN6                                                3.0125
# TNMD                                                  0.2660
# DPM1                                                 66.9505
# SCYL3                                                 2.7953
# C1orf112                                              0.6183
# FGR                                                   2.5775
# CFH                                                   8.0402
# FUCA2                                                39.7947
# GCLC                                                  9.9965
# NFYA                                                 16.5265

# %%
mf_name = 'C:/Users/NOE/Desktop/Mostres descarregades/gene_tpm_adrenal_gland.gct'
data = pd.read_csv(mf_name, skiprows=2, delimiter='\t')

# %%
data
# Out:
#           id               Name  Description  GTEX-111CU-0126-SM-5GZWZ  \
# 0          0  ENSG00000223972.5      DDX11L1                    0.0376
# 1          1  ENSG00000227232.5       WASH7P                    0.9295
# 2          2  ENSG00000278267.1    MIR6859-1                    0.0000
# 3          3  ENSG00000243485.5  MIR1302-2HG                    0.0000
# 4          4  ENSG00000237613.2      FAM138A                    0.0000
# ...      ...                ...          ...                       ...
# 56195  56195  ENSG00000198695.2       MT-ND6                17540.0000
# 56196  56196  ENSG00000210194.1        MT-TE                   56.9600
# 56197  56197  ENSG00000198727.2       MT-CYB                33690.0000
# 56198  56198  ENSG00000210195.2        MT-TT                   44.7900
# 56199  56199  ENSG00000210196.2        MT-TP                    1.4330
#
#        GTEX-111YS-0126-SM-5987T  GTEX-1122O-0326-SM-5H124  \
# 0                        0.0000                    0.0174
# 1                        1.3960                    1.5200
# 2                        0.0000                    0.0000
# 3                        0.0793                    0.0000
# 4                        0.0000                    0.0000
# ...                         ...                       ...
# 56195                 8850.0000                13580.0000
# 56196                   34.3400                  125.3000
# 56197                36360.0000                34170.0000
# 56198                    3.6420                    2.2820
# 56199                    1.5150                    1.7720
#
#        GTEX-117YX-0126-SM-5EGH5  GTEX-11DXX-0126-SM-5EGH7  \
# 0                        0.0000                    0.0276
# 1                        1.5650                    1.5460
# 2                        0.0000                    0.0000
# 3                        0.0000                    0.0000
# 4                        0.0426                    0.0784
# ...                         ...                       ...
# 56195                11290.0000                10060.0000
# 56196                   35.3900                   38.7600
# 56197                25660.0000                23360.0000
# 56198                    3.9370                    3.6180
# 56199                    4.5850                    4.9160
#
#        GTEX-11DXY-1626-SM-5H12L  GTEX-11DXZ-0226-SM-5EGGZ  ...  \
# 0                        0.0483                    0.0000  ...
# 1                        5.7580                    3.8780  ...
# 2                        0.0000                    0.0000  ...
# 3                        0.0483                    0.0959  ...
# 4                        0.0343                    0.0341  ...
# ...                         ...                       ...  ...
# 56195                 3435.0000                 7840.0000  ...
# 56196                    6.6620                   18.6600  ...
# 56197                40970.0000                34080.0000  ...
# 56198                    2.5330                    1.8880  ...
# 56199                    3.0730                    3.0540  ...
#
#        GTEX-ZT9W-0126-SM-4YCFD  GTEX-ZT9X-0126-SM-4YCFC  \
# 0                       0.0000                   0.0000
# 1                       1.4070                   1.1270
# 2                       0.0000                   0.0000
# 3                       0.0415                   0.0346
# 4                       0.0000                   0.0000
# ...                        ...                      ...
# 56195                5129.0000                5658.0000
# 56196                  31.2500                  11.7100
# 56197               19140.0000               40680.0000
# 56198                   1.0890                   2.7210
# 56199                   3.1710                   0.4401
#
#        GTEX-ZTSS-0326-SM-5987M  GTEX-ZUA1-1926-SM-5E45E  \
# 0                       0.0473                   0.0000
# 1                       3.2030                   2.6360
# 2                       0.0000                   0.3960
# 3                       0.0000                   0.0622
# 4                       0.0000                   0.0221
# ...                        ...                      ...
# 56195                8966.0000                3252.0000
# 56196                  26.6700                  17.5600
# 56197               22680.0000               28450.0000
# 56198                   2.4780                   3.2640
# 56199                   4.2100                   2.7720
#
#        GTEX-ZVP2-0126-SM-5NQ7D  GTEX-ZVT2-0826-SM-5GIEO  \
# 0                       0.0000                    0.000
# 1                       2.5360                    1.168
# 2                       0.0000                    0.000
# 3                       0.0405                    0.000
# 4                       0.0000                    0.000
# ...                        ...                      ...
# 56195               13030.0000                12000.000
# 56196                 243.5000                   41.470
# 56197               28780.0000                31970.000
# 56198                   1.5940                    2.089
# 56199                   1.0320                    2.028
#
#        GTEX-ZY6K-0126-SM-5SIAM  GTEX-ZYFG-0926-SM-5BC5U  \
# 0                       0.0778                   0.0000
# 1                       5.7760                   1.9160
# 2                       0.0000                   0.0000
# 3                       0.0000                   0.0630
# 4                       0.0368                   0.0149
# ...                        ...                      ...
# 56195               13660.0000                8548.0000
# 56196                  46.1600                  30.0300
# 56197               23020.0000               31680.0000
# 56198                   3.3980                  19.0000
# 56199                   3.2980                   2.9400
#
#        GTEX-ZYVF-1626-SM-5N9EH  GTEX-ZZPU-1226-SM-5N9CK
# 0                       0.0000                   0.0363
# 1                       5.9680                   2.2680
# 2                       0.0000                   0.0000
# 3                       0.0216                   0.0000
# 4                       0.0000                   0.0000
# ...                        ...                      ...
# 56195                4296.0000                7690.0000
# 56196                   9.5040                  31.8200
# 56197               44710.0000               29300.0000
# 56198                   0.5678                   0.4753
# 56199                   2.2040                   0.4613
#
# [56200 rows x 261 columns]

# %%
columns_to_save = ['Description', 'GTEX-111CU-0126-SM-5GZWZ', 'GTEX-111YS-0126-SM-5987T', 'GTEX-1122O-0326-SM-5H124']
df_selected_columns = data[columns_to_save]
df_selected_columns
output_txt_file = 'C:/Users/NOE/Desktop/Mostres descarregades/adrenal_gland.txt'
df_selected_columns.to_csv(output_txt_file, sep='\t', index=False, header=True, float_format='%.6f')

# %%
print(df_selected_columns.head(10))
# Out:
#     Description  GTEX-111CU-0126-SM-5GZWZ  GTEX-111YS-0126-SM-5987T  \
# 0       DDX11L1                    0.0376                    0.0000
# 1        WASH7P                    0.9295                    1.3960
# 2     MIR6859-1                    0.0000                    0.0000
# 3   MIR1302-2HG                    0.0000                    0.0793
# 4       FAM138A                    0.0000                    0.0000
# 5        OR4G4P                    0.0773                    0.1226
# 6       OR4G11P                    0.1382                    0.1096
# 7         OR4F5                    0.0708                    0.0748
# 8  RP11-34P13.7                    0.0158                    0.0167
# 9        CICP27                    0.0375                    0.0000
#
#    GTEX-1122O-0326-SM-5H124
# 0                    0.0174
# 1                    1.5200
# 2                    0.0000
# 3                    0.0000
# 4                    0.0000
# 5                    0.1076
# 6                    0.0000
# 7                    0.1313
# 8                    0.0000
# 9                    0.0783
