# %%
import glob
import os
import time
from scipy.io import loadmat
import cobra
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Carregar models:
#normal_model1 = cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/NormalModel_GTEX_111CU_0126_SM_5GZWZ.mat")
#normal_model2 = cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/NormalModel_GTEX_111YS_0126_SM_5987T.mat")
#normal_model3 = cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/NormalModel_GTEX_1122O_0326_SM_5H124.mat")
#cancer_model1 = cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/CancerModel_aa51d383_ce36_4247_bfcd_d104a121f7d3_4e605b10_da43_45f0_a43d_27.mat")
#cancer_model2 = cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/CancerModel_x2f7e6f7f_a4f9_4849_8add_3fbafb75b5c2_9406f2f9_832a_42e7_b5e9_a.mat")
#cancer_model3 = cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/CancerModel_x3fadb519_dd1a_4765_be25_e7ecaaa9b8e0_8919cfd0_6cd6_423f_9231_4.mat")
BRCA_cancer1=cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/CancerBRCAModel_BRCA_C_TCGA_C8_A27B_01A_11R_A169_07.mat")
BRCA_cancer2=cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/CancerBRCAModel_BRCA_C_TCGA_E2_A14R_01A_11R_A115_07.mat")
BRCA_cancer3=cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/CancerBRCAModel_BRCA_C_TCGA_LD_A7W6_01A_81R_A352_07.mat")
BRCA_control1=cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/ControlBRCAModel_BRCA_H_TCGA_A7_A0DB_11A_33R_A089_07_1.mat")
BRCA_control2=cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/ControlBRCAModel_BRCA_H_TCGA_A7_A13E_11A_61R_A12P_07.mat")
BRCA_control3=cobra.io.load_matlab_model("C:/Users/NOE/Desktop/Mostres TFG Obtingudes/ControlBRCAModel_BRCA_H_TCGA_BH_A1FR_11B_42R_A13Q_07.mat")
# Out:
# No defined compartments in model ContextModel_CancerBRCA. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel_CancerBRCA. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel_CancerBRCA. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel_ControlBRCA. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel_ControlBRCA. Compartments will be deduced heuristically using regular expressions.
# ...

# %%
#de cada model fer FBA per obtenir els fluxes:
#solution_normal1=normal_model1.optimize()
#solution_normal1
#solution_normal2=normal_model2.optimize()
#solution_normal2
#solution_normal3=normal_model3.optimize()
#solution_normal3
#solution_cancer1=cancer_model1.optimize()
#solution_cancer1
#solution_cancer2=cancer_model2.optimize()
#solution_cancer2
#solution_cancer3=cancer_model3.optimize()
#solution_cancer3
solution_cancerBRCA1=BRCA_cancer1.optimize()
solution_cancerBRCA2=BRCA_cancer2.optimize()
solution_cancerBRCA3=BRCA_cancer3.optimize()
solution_BRCAcontrol1=BRCA_control1.optimize()
solution_BRCAcontrol2=BRCA_control2.optimize()
solution_BRCAcontrol3=BRCA_control3.optimize()
solution_cancerBRCA1
solution_cancerBRCA2
solution_cancerBRCA3
solution_BRCAcontrol1
solution_BRCAcontrol2
solution_BRCAcontrol3
# Out:
# <Solution 195.805 at 0x2a70654a0d0>

# %%
#Visualitzar els fluxes de cada model:
#flujos_normal1=solution_normal1.fluxes
#print(flujos_normal1)
#flujos_normal2=solution_normal2.fluxes
#print(flujos_normal2)
#flujos_normal3=solution_normal3.fluxes
#print(flujos_normal3)
#flujos_cancer1=solution_cancer1.fluxes
#print(flujos_cancer1)
#flujos_cancer2=solution_cancer2.fluxes
#print(flujos_cancer2)
#flujos_cancer3=solution_cancer3.fluxes
#print(flujos_cancer3)
flujosBRCAcancer1= solution_cancerBRCA1.fluxes
flujosBRCAcancer2=solution_cancerBRCA2.fluxes
flujosBRCAcancer3=solution_cancerBRCA3.fluxes
flujosBRCAcontrol1=solution_BRCAcontrol1.fluxes
flujosBRCAcontrol2=solution_BRCAcontrol2.fluxes
flujosBRCAcontrol3=solution_BRCAcontrol3.fluxes
print(flujosBRCAcancer1)
print(flujosBRCAcancer2)
print(flujosBRCAcancer3)
print(flujosBRCAcontrol1)
print(flujosBRCAcontrol2)
print(flujosBRCAcontrol3)
# Out:
# 10FTHF7GLUtl        0.000000
# 10FTHFtl            0.000000
# 13DAMPPOX           0.000000
# 2HBO             -228.826242
# 2HBt2               0.000000
#                     ...
# sink_asp_L[c]    1000.000000
# sink_glu_L[c]    -777.088348
# sink_gly[c]       -95.830226
# sink_4abut[l]       0.000000
# DM_4abut[c]         0.000000
# Name: fluxes, Length: 4026, dtype: float64
# 10FTHF7GLUtl       0.000000
# 10FTHF7GLUtm       0.000000
# 10FTHFtl           0.000000
# 13DAMPPOX          0.000000
# 2AMACHYD           0.000000
#                     ...
# sink_pro_L[c]    905.159487
# sink_gly[c]      884.706830
# sink_4abut[l]      0.000000
# DM_4abut[c]        0.000000
# DM_btn[n]          0.000000
# Name: fluxes, Length: 4137, dtype: float64
# 10FTHF7GLUtl             0.000000
# 10FTHF7GLUtm             0.000000
# 10FTHFtl                 0.000000
# 10FTHFtm                 0.000000
# 13DAMPPOX                0.000000
#                           ...
# sink_tyr_L[c]          -30.892737
# ...

# %%
df_BRCAcancer1=pd.DataFrame({'Reacciones':flujosBRCAcancer1.index,'Flujos_BRCA_cancer1':flujosBRCAcancer1.values})
df_BRCAcancer2=pd.DataFrame({'Reacciones':flujosBRCAcancer2.index,'Flujos_BRCA_cancer2':flujosBRCAcancer2.values})
df_BRCAcancer3=pd.DataFrame({'Reacciones':flujosBRCAcancer3.index,'Flujos_BRCA_cancer3':flujosBRCAcancer3.values})
df_BRCAcontrol1=pd.DataFrame({'Reacciones':flujosBRCAcontrol1.index,'Flujos_BRCA_control1':flujosBRCAcontrol1.values})
df_BRCAcontrol2=pd.DataFrame({'Reacciones':flujosBRCAcontrol2.index,'Flujos_BRCA_control2':flujosBRCAcontrol2.values})
df_BRCAcontrol3=pd.DataFrame({'Reacciones':flujosBRCAcontrol3.index,'Flujos_BRCA_control3':flujosBRCAcontrol3.values,})



df_BRCAcancer1=df_BRCAcancer1.set_index('Reacciones', drop=True)
df_BRCAcancer1
df_BRCAcancer2=df_BRCAcancer2.set_index('Reacciones', drop=True)
df_BRCAcancer2
df_BRCAcancer3=df_BRCAcancer3.set_index('Reacciones', drop=True)
df_BRCAcancer3
df_BRCAcontrol1=df_BRCAcontrol1.set_index('Reacciones', drop=True)
df_BRCAcontrol1
df_BRCAcontrol2=df_BRCAcontrol2.set_index('Reacciones', drop=True)
df_BRCAcontrol2
df_BRCAcontrol3=df_BRCAcontrol3.set_index('Reacciones', drop=True)
df_BRCAcontrol3




desktop_path = os.path.join(os.path.expanduser("~"), "Desktop/TFG-Example")
folder_path = os.path.join(desktop_path, "DataFrames Flujos Prueba")
os.makedirs(folder_path, exist_ok=True)

df_BRCAcancer1.to_csv(os.path.join(folder_path, 'df_BRCAcancer1.txt'), sep='\t', index=True)
df_BRCAcancer2.to_csv(os.path.join(folder_path, 'df_BRCAcancer2.txt'), sep='\t', index=True)
df_BRCAcancer3.to_csv(os.path.join(folder_path, 'df_BRCAcancer3.txt'), sep='\t', index=True)
df_BRCAcontrol1.to_csv(os.path.join(folder_path, 'df_BRCAcontrol1.txt'), sep='\t', index=True)
df_BRCAcontrol2.to_csv(os.path.join(folder_path, 'df_BRCAcontrol2.txt'), sep='\t', index=True)
df_BRCAcontrol3.to_csv(os.path.join(folder_path, 'df_BRCAcontrol3.txt'), sep='\t', index=True)

print(df_BRCAcontrol1)
# Out:
#                      Flujos_BRCA_control1
# Reacciones
# 10FTHF7GLUtl                     0.000000
# 10FTHF7GLUtm                     0.000000
# 10FTHFtl                         0.000000
# 13DAMPPOX                        0.000000
# 2HBO                         -1000.000000
# ...                                   ...
# sink_gln_L[c]                 -288.643183
# sink_glu_L[c]                 -277.919800
# sink_4abut[l]                    0.000000
# DM_4glu56dihdind[c]              0.000000
# DM_btn[n]                        0.000000
#
# [4457 rows x 1 columns]

# %%
#Fer els Data Frame de cada model amb els fluxos i les reaccions:
df_normal1 = pd.DataFrame({'Reacciones': solution_normal1.fluxes.index,'FlujosN1': solution_normal1.fluxes.values})
print(df_normal1)

df_normal2 = pd.DataFrame({'Reacciones': solution_normal2.fluxes.index,'FlujosN2': solution_normal2.fluxes.values})
print(df_normal2)

df_normal3 = pd.DataFrame({'Reacciones': solution_normal3.fluxes.index,'FlujosN3': solution_normal3.fluxes.values})
print(df_normal3)

df_cancer1 = pd.DataFrame({'Reacciones': solution_cancer1.fluxes.index,'FlujosC1': solution_cancer1.fluxes.values})
print(df_cancer1)

df_cancer2 = pd.DataFrame({'Reacciones': solution_cancer2.fluxes.index,'FlujosC2': solution_cancer2.fluxes.values})
print(df_cancer2)

df_cancer3 = pd.DataFrame({'Reacciones': solution_cancer3.fluxes.index,'FlujosC3': solution_cancer3.fluxes.values})
print(df_cancer3)
# Out:
#         Reacciones  FlujosN1
# 0     10FTHF7GLUtl       0.0
# 1     10FTHF7GLUtm       0.0
# 2         10FTHFtl       0.0
# 3      11DOCRTSLtm       0.0
# 4      11DOCRTSLtr       0.0
# ...            ...       ...
# 5733  DM_CE1562[c]       0.0
# 5734  DM_CE5025[c]       0.0
# 5735     DM_btn[n]       0.0
# 5736          Htmi       0.0
# 5737   NADH2_u10mi       0.0
#
# [5738 rows x 2 columns]
#                Reacciones  FlujosN2
# 0            10FTHF7GLUtl       0.0
# 1            10FTHF7GLUtm       0.0
# 2                10FTHFtl       0.0
# 3                10FTHFtm       0.0
# 4             11DOCRTSLtm       0.0
# ...                   ...       ...
# 5674         DM_CE1562[c]       0.0
# 5675  DM_1a2425thvitd2[m]       0.0
# 5676            DM_btn[n]       0.0
# 5677                 Htmi       0.0
# 5678          NADH2_u10mi       0.0
#
# [5679 rows x 2 columns]
#         Reacciones  FlujosN3
# 0     10FTHF7GLUtl       0.0
# 1     10FTHF7GLUtm       0.0
# ...

# %%
#Fer una carpeta en el desktop:
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop/TFG-Example")
folder_path = os.path.join(desktop_path, "DataFrames Flujos Prueba")
os.makedirs(folder_path, exist_ok=True)

# %%
#Descarregar en la carpeta desktop creada els arxius en format .txt:
df_normal1.to_csv(os.path.join(folder_path, 'df_normal1.txt'), sep='\t', index=False)
df_normal2.to_csv(os.path.join(folder_path, 'df_normal2.txt'), sep='\t', index=False)
df_normal3.to_csv(os.path.join(folder_path, 'df_normal3.txt'), sep='\t', index=False)
df_cancer1.to_csv(os.path.join(folder_path, 'df_cancer1.txt'), sep='\t', index=False)
df_cancer2.to_csv(os.path.join(folder_path, 'df_cancer2.txt'), sep='\t', index=False)
df_cancer3.to_csv(os.path.join(folder_path, 'df_cancer3.txt'), sep='\t', index=False)
