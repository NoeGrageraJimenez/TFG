# %% [markdown]
# # Creació DataFrame:

# %% [markdown]
# ## 1. DataFrame IGT:

# %%
import os
import pandas as pd

# Ruta de la carpeta que contiene los archivos .txt
carpetaIGT = "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/Archivos con symbol/IGT"

# Lista para almacenar los DataFrames de los archivos .txt
dataframes = []

# Recorremos todos los archivos en la carpeta
for archivo in os.listdir(carpetaIGT):
    if archivo.endswith(".txt"):
        # Construimos la ruta completa del archivo
        ruta_completa = os.path.join(carpetaIGT, archivo)
        # Cargamos el archivo .txt en un DataFrame
        df = pd.read_csv(ruta_completa, sep='\t', index_col=0)  # Ajusta el separador si es necesario
        # Almacenamos el DataFrame en la lista
        dataframes.append(df)
        print(f"Longitud de {archivo}: {len(df)}")

# Combinamos todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, axis=1)

ruta_guardado = "C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/IGT_DataFrame.csv"
df_completo.to_csv(ruta_guardado)

# Visualizamos el DataFrame completo
df_completo
# Out:
# Longitud de GSM5009231_DP005_s.txt: 35089
# Longitud de GSM5009232_DP007_s.txt: 35089
# Longitud de GSM5009233_DP008_s.txt: 35089
# Longitud de GSM5009237_DP013_s.txt: 35089
# Longitud de GSM5009241_DP025_s.txt: 35089
# Longitud de GSM5009249_DP048_s.txt: 35089
# Longitud de GSM5009251_DP051_s.txt: 35089
# Longitud de GSM5009258_DP059_s.txt: 35089
# Longitud de GSM5009260_DP063_s.txt: 35089
# Longitud de GSM5009264_DP067_s.txt: 35089
# Longitud de GSM5009265_DP068_s.txt: 35089
# Longitud de GSM5009268_DP071_s.txt: 35089
# Longitud de GSM5009273_DP076_s.txt: 35089
# Longitud de GSM5009277_DP081_s.txt: 35089
# Longitud de GSM5009278_DP082_s.txt: 35089
# Longitud de GSM5009282_DP088_s.txt: 35089
# Longitud de GSM5009285_DP093_s.txt: 35089
# Longitud de GSM5009296_DP108_s.txt: 35089
# Longitud de GSM5009298_DP110_s.txt: 35089
# Longitud de GSM5009302_DP116_s.txt: 35089
# Longitud de GSM5009307_DP123_s.txt: 35089
# Longitud de GSM5009313_DP137_s.txt: 35089
# ...

# %% [markdown]
# ## 2.DataFrame ND:

# %%
import os
import pandas as pd

# Ruta de la carpeta que contiene los archivos .txt
carpetaND = "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/Archivos con symbol/ND"

# Lista para almacenar los DataFrames de los archivos .txt
dataframes = []

# Recorremos todos los archivos en la carpeta
for archivo in os.listdir(carpetaND):
    if archivo.endswith(".txt"):
        # Construimos la ruta completa del archivo
        ruta_completa = os.path.join(carpetaND, archivo)
        # Cargamos el archivo .txt en un DataFrame
        df = pd.read_csv(ruta_completa, sep='\t', index_col=0)  # Ajusta el separador si es necesario
        # Almacenamos el DataFrame en la lista
        dataframes.append(df)
        print(f"Longitud de {archivo}: {len(df)}")

# Combinamos todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, axis=1)

ruta_guardado = "C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/ND_DataFrame.csv"
df_completo.to_csv(ruta_guardado)

# Visualizamos el DataFrame completo
df_completo
# Out:
# Longitud de GSM5009234_DP010_s.txt: 35089
# Longitud de GSM5009235_DP011_s.txt: 35089
# Longitud de GSM5009236_DP012_s.txt: 35089
# Longitud de GSM5009239_DP019_s.txt: 35089
# Longitud de GSM5009240_DP021_s.txt: 35089
# Longitud de GSM5009252_DP052_s.txt: 35089
# Longitud de GSM5009254_DP054_s.txt: 35089
# Longitud de GSM5009261_DP064_s.txt: 35089
# Longitud de GSM5009266_DP069_s.txt: 35089
# Longitud de GSM5009275_DP079_s.txt: 35089
# Longitud de GSM5009280_DP086_s.txt: 35089
# Longitud de GSM5009286_DP095_s.txt: 35089
# Longitud de GSM5009309_DP125_s.txt: 35089
# Longitud de GSM5009312_DP132_s.txt: 35089
# Longitud de GSM5009320_DP146_s.txt: 35089
# Longitud de GSM5009321_DP147_s.txt: 35089
# Longitud de GSM5009334_DP173_s.txt: 35089
# Longitud de GSM5009340_DP181_s.txt: 35089
#               GSM5009234_DP010  GSM5009235_DP011  GSM5009236_DP012  \
# symbol
# TSPAN6                     188               198               343
# ...

# %% [markdown]
# ## 3.DataFrame T2D:

# %%
import os
import pandas as pd

# Ruta de la carpeta que contiene los archivos .txt
carpetaT2D = "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/Archivos con symbol/T2D"

# Lista para almacenar los DataFrames de los archivos .txt
dataframes = []

# Recorremos todos los archivos en la carpeta
for archivo in os.listdir(carpetaT2D):
    if archivo.endswith(".txt"):
        # Construimos la ruta completa del archivo
        ruta_completa = os.path.join(carpetaT2D, archivo)
        # Cargamos el archivo .txt en un DataFrame
        df = pd.read_csv(ruta_completa, sep='\t', index_col=0)  # Ajusta el separador si es necesario
        # Almacenamos el DataFrame en la lista
        dataframes.append(df)
        print(f"Longitud de {archivo}: {len(df)}")

# Combinamos todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, axis=1)

ruta_guardado = "C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/T2D_DataFrame.csv"
df_completo.to_csv(ruta_guardado)

# Visualizamos el DataFrame completo
df_completo
# Out:
# Longitud de GSM5009230_DP003_s.txt: 35089
# Longitud de GSM5009243_DP030_s.txt: 35089
# Longitud de GSM5009244_DP034_s.txt: 35089
# Longitud de GSM5009247_DP042_s.txt: 35089
# Longitud de GSM5009250_DP049_s.txt: 35089
# Longitud de GSM5009255_DP055_s.txt: 35089
# Longitud de GSM5009257_DP058_s.txt: 35089
# Longitud de GSM5009267_DP070_s.txt: 35089
# Longitud de GSM5009279_DP083_s.txt: 35089
# Longitud de GSM5009281_DP087_s.txt: 35089
# Longitud de GSM5009288_DP097_s.txt: 35089
# Longitud de GSM5009289_DP099_s.txt: 35089
# Longitud de GSM5009290_DP102_s.txt: 35089
# Longitud de GSM5009291_DP103_s.txt: 35089
# Longitud de GSM5009292_DP104_s.txt: 35089
# Longitud de GSM5009293_DP105_s.txt: 35089
# Longitud de GSM5009295_DP107_s.txt: 35089
# Longitud de GSM5009297_DP109_s.txt: 35089
# Longitud de GSM5009299_DP111_s.txt: 35089
# Longitud de GSM5009304_DP118_s.txt: 35089
# Longitud de GSM5009306_DP122_s.txt: 35089
# Longitud de GSM5009308_DP124_s.txt: 35089
# ...

# %% [markdown]
# ## 4.DataFrame T3cD:

# %%
import os
import pandas as pd

# Ruta de la carpeta que contiene los archivos .txt
carpetaT3cD = "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/Archivos con symbol/T3cD"

# Lista para almacenar los DataFrames de los archivos .txt
dataframes = []

# Recorremos todos los archivos en la carpeta
for archivo in os.listdir(carpetaT3cD):
    if archivo.endswith(".txt"):
        # Construimos la ruta completa del archivo
        ruta_completa = os.path.join(carpetaT3cD, archivo)
        # Cargamos el archivo .txt en un DataFrame
        df = pd.read_csv(ruta_completa, sep='\t', index_col=0)  # Ajusta el separador si es necesario
        # Almacenamos el DataFrame en la lista
        dataframes.append(df)
        print(f"Longitud de {archivo}: {len(df)}")

# Combinamos todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, axis=1)

ruta_guardado = "C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/T3cD_DataFrame.csv"
df_completo.to_csv(ruta_guardado)

# Visualizamos el DataFrame completo
df_completo
# Out:
# Longitud de GSM5009229_DP002_s.txt: 35089
# Longitud de GSM5009238_DP017_s.txt: 35089
# Longitud de GSM5009242_DP028_s.txt: 35089
# Longitud de GSM5009245_DP039_s.txt: 35089
# Longitud de GSM5009246_DP040_s.txt: 35089
# Longitud de GSM5009248_DP043_s.txt: 35089
# Longitud de GSM5009253_DP053_s.txt: 35089
# Longitud de GSM5009256_DP057_s.txt: 35089
# Longitud de GSM5009259_DP061_s.txt: 35089
# Longitud de GSM5009262_DP065_s.txt: 35089
# Longitud de GSM5009263_DP066_s.txt: 35089
# Longitud de GSM5009269_DP072_s.txt: 35089
# Longitud de GSM5009270_DP073_s.txt: 35089
# Longitud de GSM5009271_DP074_s.txt: 35089
# Longitud de GSM5009272_DP075_s.txt: 35089
# Longitud de GSM5009274_DP077_s.txt: 35089
# Longitud de GSM5009276_DP080_s.txt: 35089
# Longitud de GSM5009283_DP089_s.txt: 35089
# Longitud de GSM5009284_DP090_s.txt: 35089
# Longitud de GSM5009287_DP096_s.txt: 35089
# Longitud de GSM5009294_DP106_s.txt: 35089
# Longitud de GSM5009300_DP112_s.txt: 35089
# ...

# %% [markdown]
# ## DataFrame Conjunt:

# %%
import os
import pandas as pd

# Definimos las rutas de las carpetas que contienen los archivos .txt
directorios = {
    "IGT": "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/Archivos con symbol/IGT",
    "ND": "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/Archivos con symbol/ND",
    "T2D": "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/Archivos con symbol/T2D",
    "T3cD": "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/Archivos con symbol/T3cD"
}

# Función para cargar los DataFrames de los archivos .txt
def cargar_dataframes(directorios):
    dataframes = {}
    for key, carpeta in directorios.items():
        dataframes[key] = []
        # Recorremos todos los archivos en la carpeta
        for archivo in os.listdir(carpeta):
            if archivo.endswith(".txt"):
                # Construimos la ruta completa del archivo
                ruta_completa = os.path.join(carpeta, archivo)
                # Cargamos el archivo .txt en un DataFrame
                df = pd.read_csv(ruta_completa, sep='\t', index_col=0)  # Ajusta el separador si es necesario
                # Almacenamos el DataFrame en la lista
                dataframes[key].append(df)
                print(f"Longitud de {archivo}: {len(df)}")
    return dataframes

# Cargamos todos los DataFrames
dataframes = cargar_dataframes(directorios)

# Concatenamos todos los DataFrames y añadimos el nombre correspondiente a cada tipo
df_completo = pd.concat([pd.concat([df.set_axis([f"{key}_{col}" for col in df.columns], axis=1) for df in dfs], axis=1) for key, dfs in dataframes.items()], axis=1)

# Guardamos el DataFrame en un archivo CSV
ruta_guardado = "C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/AllConditions_DataFrame.csv"
df_completo.to_csv(ruta_guardado)

num_columnas_IGT = sum(col.startswith('IGT') for col in df_completo.columns)
num_columnas_ND = sum(col.startswith('ND') for col in df_completo.columns)
num_columnas_T2D = sum(col.startswith('T2D') for col in df_completo.columns)
num_columnas_T3cD = sum(col.startswith('T3cD') for col in df_completo.columns)

print(f"Número de columnas que comienzan con IGT: {num_columnas_IGT}")
print(f"Número de columnas que comienzan con ND: {num_columnas_ND}")
print(f"Número de columnas que comienzan con T2D: {num_columnas_T2D}")
print(f"Número de columnas que comienzan con T3cD: {num_columnas_T3cD}")

# Visualizamos el DataFrame completo
df_completo
# Out:
# Longitud de GSM5009231_DP005_s.txt: 35089
# Longitud de GSM5009232_DP007_s.txt: 35089
# Longitud de GSM5009233_DP008_s.txt: 35089
# Longitud de GSM5009237_DP013_s.txt: 35089
# Longitud de GSM5009241_DP025_s.txt: 35089
# Longitud de GSM5009249_DP048_s.txt: 35089
# Longitud de GSM5009251_DP051_s.txt: 35089
# Longitud de GSM5009258_DP059_s.txt: 35089
# Longitud de GSM5009260_DP063_s.txt: 35089
# Longitud de GSM5009264_DP067_s.txt: 35089
# Longitud de GSM5009265_DP068_s.txt: 35089
# Longitud de GSM5009268_DP071_s.txt: 35089
# Longitud de GSM5009273_DP076_s.txt: 35089
# Longitud de GSM5009277_DP081_s.txt: 35089
# Longitud de GSM5009278_DP082_s.txt: 35089
# Longitud de GSM5009282_DP088_s.txt: 35089
# Longitud de GSM5009285_DP093_s.txt: 35089
# Longitud de GSM5009296_DP108_s.txt: 35089
# Longitud de GSM5009298_DP110_s.txt: 35089
# Longitud de GSM5009302_DP116_s.txt: 35089
# Longitud de GSM5009307_DP123_s.txt: 35089
# Longitud de GSM5009313_DP137_s.txt: 35089
# ...

# %% [markdown]
# # Data Frame sense símbols:

# %%
import os
import pandas as pd
# Definimos las rutas de las carpetas que contienen los archivos .txt
directorios = {
    "IGT": "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/samples IGT",
    "ND": "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/samples ND",
    "T2D": "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/samples T2D",
    "T3cD": "C:/Users/NOE/Desktop/TFG-Example/Islet data/Mostres/samples T3cD"
}

# Función para cargar los DataFrames de los archivos .txt
def cargar_dataframes(directorios):
    dataframes = {}
    for key, carpeta in directorios.items():
        dataframes[key] = []
        # Recorremos todos los archivos en la carpeta
        for archivo in os.listdir(carpeta):
            if archivo.endswith(".txt"):
                # Construimos la ruta completa del archivo
                ruta_completa = os.path.join(carpeta, archivo)
                # Cargamos el archivo .txt en un DataFrame
                df = pd.read_csv(ruta_completa, sep='\t', index_col=0)  # Ajusta el separador si es necesario
                # Almacenamos el DataFrame en la lista
                dataframes[key].append(df)
                print(f"Longitud de {archivo}: {len(df)}")
    return dataframes

# Cargamos todos los DataFrames
dataframes = cargar_dataframes(directorios)

# Concatenamos todos los DataFrames y añadimos el nombre correspondiente a cada tipo
df_completo = pd.concat([pd.concat([df.set_axis([f"{key}_{col}" for col in df.columns], axis=1) for df in dfs], axis=1) for key, dfs in dataframes.items()], axis=1)

# Guardamos el DataFrame en un archivo CSV
ruta_guardado = "C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/SSConditions_DataFrame.csv"
df_completo.to_csv(ruta_guardado)

num_columnas_IGT = sum(col.startswith('IGT') for col in df_completo.columns)
num_columnas_ND = sum(col.startswith('ND') for col in df_completo.columns)
num_columnas_T2D = sum(col.startswith('T2D') for col in df_completo.columns)
num_columnas_T3cD = sum(col.startswith('T3cD') for col in df_completo.columns)

print(f"Número de columnas que comienzan con IGT: {num_columnas_IGT}")
print(f"Número de columnas que comienzan con ND: {num_columnas_ND}")
print(f"Número de columnas que comienzan con T2D: {num_columnas_T2D}")
print(f"Número de columnas que comienzan con T3cD: {num_columnas_T3cD}")

# Visualizamos el DataFrame completo
df_completo
# Out:
# Longitud de GSM5009231_DP005_htseq_counts.txt: 58381
# Longitud de GSM5009232_DP007_htseq_counts.txt: 58381
# Longitud de GSM5009233_DP008_htseq_counts.txt: 58381
# Longitud de GSM5009237_DP013_htseq_counts.txt: 58381
# Longitud de GSM5009241_DP025_htseq_counts.txt: 58381
# Longitud de GSM5009249_DP048_htseq_counts.txt: 58381
# Longitud de GSM5009251_DP051_htseq_counts.txt: 58381
# Longitud de GSM5009258_DP059_htseq_counts.txt: 58381
# Longitud de GSM5009260_DP063_htseq_counts.txt: 58381
# Longitud de GSM5009264_DP067_htseq_counts.txt: 58381
# Longitud de GSM5009265_DP068_htseq_counts.txt: 58381
# Longitud de GSM5009268_DP071_htseq_counts.txt: 58381
# Longitud de GSM5009273_DP076_htseq_counts.txt: 58381
# Longitud de GSM5009277_DP081_htseq_counts.txt: 58381
# Longitud de GSM5009278_DP082_htseq_counts.txt: 58381
# Longitud de GSM5009282_DP088_htseq_counts.txt: 58381
# Longitud de GSM5009285_DP093_htseq_counts.txt: 58381
# Longitud de GSM5009296_DP108_htseq_counts.txt: 58381
# ...
