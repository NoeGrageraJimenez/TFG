# %%
import pandas as pd
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

# %% [markdown]
# Seleccionar les condicions del dataframe genèric que es volen estudiar:

# %%
counts= pd.read_csv('C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/SSConditions_DataFrame.csv')

#Possar com a index la columna entre parentesi:
counts= counts.set_index('ensembl')

#Del dataFrame quedar-nos amb les columnes que comencen per ND i IGT:
counts= counts.filter(regex='^(ND|IGT)')
counts
# Out:
#                     IGT_counts  IGT_counts.1  IGT_counts.2  IGT_counts.3  \
# ensembl
# ENSG00000000003.14         438           118           567           342
# ENSG00000000005.5            0             0             1             7
# ENSG00000000419.12         518           570           892           558
# ENSG00000000457.13         249           308           285           351
# ENSG00000000460.16          43            32            43            56
# ...                        ...           ...           ...           ...
# ENSG00000285498.1            0             0             0             0
# ENSG00000285505.1            0             0             0             0
# ENSG00000285508.1            0             0             0             0
# ENSG00000285509.1            5             0             6             4
# ENSG00000285513.1            0             0             0             0
#
#                     IGT_counts.4  IGT_counts.5  IGT_counts.6  IGT_counts.7  \
# ensembl
# ENSG00000000003.14           183           113           341           377
# ENSG00000000005.5              2             0             0             2
# ENSG00000000419.12           606           686           597          1079
# ENSG00000000457.13           207           314           222           554
# ENSG00000000460.16            56            65            49            80
# ...                          ...           ...           ...           ...
# ENSG00000285498.1              0             0             0             0
# ENSG00000285505.1              0             0             0             0
# ENSG00000285508.1              0             0             0             0
# ENSG00000285509.1              0             7             1             2
# ENSG00000285513.1              0             0             0             0
#
#                     IGT_counts.8  IGT_counts.9  ...  ND_counts.8  ND_counts.9  \
# ensembl                                         ...
# ENSG00000000003.14           455           186  ...           44           34
# ENSG00000000005.5              0             0  ...            0            0
# ENSG00000000419.12           835           565  ...          129          165
# ENSG00000000457.13           320           170  ...           70           73
# ENSG00000000460.16            41            40  ...           22           34
# ...                          ...           ...  ...          ...          ...
# ENSG00000285498.1              0             0  ...            1            0
# ENSG00000285505.1              0             0  ...            0            0
# ENSG00000285508.1              0             0  ...            0            0
# ENSG00000285509.1              5             0  ...            0            2
# ENSG00000285513.1              0             0  ...            0            0
#
#                     ND_counts.10  ND_counts.11  ND_counts.12  ND_counts.13  \
# ensembl
# ENSG00000000003.14            28           315           584           704
# ENSG00000000005.5              0             2             0            12
# ENSG00000000419.12           148          1017          1267           876
# ENSG00000000457.13            57           433           611           247
# ENSG00000000460.16             5            81           133            59
# ...                          ...           ...           ...           ...
# ENSG00000285498.1              0             0             0             0
# ENSG00000285505.1              0             0             0             0
# ENSG00000285508.1              0             0             0             0
# ENSG00000285509.1              0             9            13            11
# ENSG00000285513.1              0             0             0             0
#
#                     ND_counts.14  ND_counts.15  ND_counts.16  ND_counts.17
# ensembl
# ENSG00000000003.14           391           451           622           379
# ENSG00000000005.5              0             0             0             0
# ENSG00000000419.12           900           879          1395           856
# ENSG00000000457.13           427           330           593           228
# ENSG00000000460.16            72            69            83            53
# ...                          ...           ...           ...           ...
# ENSG00000285498.1              0             0             0             0
# ENSG00000285505.1              0             0             0             0
# ENSG00000285508.1              0             0             0             0
# ENSG00000285509.1             13             4            12            24
# ENSG00000285513.1              0             0             0             0
#
# [58381 rows x 59 columns]

# %%
# Del DataFrame filtrar les columnes que tinguin tots els valors 0 (no expressió), i dels ensmbl treure decimals:
counts1= counts[counts.sum(axis=1) > 0]

counts1.index = [col.split('.')[0] for col in counts1.index]
counts1
# Out:
#                  IGT_counts  IGT_counts.1  IGT_counts.2  IGT_counts.3  \
#
# IGT_counts.18              210                0              785
# IGT_counts.19             1176                1              751
# IGT_counts.20              621                0              882
# IGT_counts.21              955                0              965
# IGT_counts.22              383               11             1057
# IGT_counts.23              562                0             1029
# IGT_counts.24              664                0             1229
# IGT_counts.25              342                0             1087
# IGT_counts.26              529                0              798
# IGT_counts.27              332                1             1258
# IGT_counts.28              544                0             1182
# IGT_counts.29              725                3              943
# IGT_counts.30              433                0             1131
# IGT_counts.31              722                0             1166
# IGT_counts.32              575                0             1052
# IGT_counts.33              812                0             1029
# IGT_counts.34              182                0              805
# IGT_counts.35              529                0             1540
# IGT_counts.36              655                6             1547
# IGT_counts.37              448               54             1081
# IGT_counts.38              640               12             1467
# IGT_counts.39              809                2             1464
# IGT_counts.40              702                0             1510
# ND_counts                  188                0              697
# ND_counts.1                198                0              595
# ND_counts.2                343                0              503
# ND_counts.3                214                0              683
# ND_counts.4                400               21              552
# ND_counts.5                528                0             1609
# ND_counts.6                536                0             1007
# ND_counts.7                246                0              461
# ND_counts.8                 44                0              129
# ND_counts.9                 34                0              165
# ND_counts.10                28                0              148
# ND_counts.11               315                2             1017
# ND_counts.12               584                0             1267
# ND_counts.13               704               12              876
# ND_counts.14               391                0              900
# ND_counts.15               451                0              879
# ND_counts.16               622                0             1395
# ND_counts.17               379                0              856
#
#                ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# IGT_counts                 249               43                2
# IGT_counts.1               308               32                2
# IGT_counts.2               285               43               63
# IGT_counts.3               351               56                0
# IGT_counts.4               207               56                0
# IGT_counts.5               314               65                1
# IGT_counts.6               222               49                7
# IGT_counts.7               554               80               11
# IGT_counts.8               320               41                6
# IGT_counts.9               170               40                0
# IGT_counts.10              356               49               31
# IGT_counts.11              285               85               17
# IGT_counts.12               28               12                0
# IGT_counts.13               67               33                1
# IGT_counts.14               71               11               12
# IGT_counts.15              421               76               88
# IGT_counts.16              303               74               44
# IGT_counts.17              404               56               15
# IGT_counts.18              450               85                4
# IGT_counts.19              385              105              104
# IGT_counts.20              334              132                8
# IGT_counts.21              442               70               54
# IGT_counts.22              403              104                5
# IGT_counts.23              339              117               16
# IGT_counts.24              356               49                4
# IGT_counts.25              318               84               37
# IGT_counts.26              271               45               36
# IGT_counts.27              447               61               23
# IGT_counts.28              320               64               71
# IGT_counts.29              416               38               15
# IGT_counts.30              296               32               29
# IGT_counts.31              269               31                6
# IGT_counts.32              243               17                8
# IGT_counts.33              253               45               19
# IGT_counts.34              220               44               28
# IGT_counts.35              393              100               10
# IGT_counts.36              537               87               27
# IGT_counts.37              436               94               66
# IGT_counts.38              405               73               44
# IGT_counts.39              455               69               33
# IGT_counts.40              492               85               19
# ND_counts                  232              119               18
# ND_counts.1                229               85                1
# ND_counts.2                140               27               26
# ND_counts.3                300              101                8
# ND_counts.4                188               46                0
# ND_counts.5                347               35                4
# ND_counts.6                424              125               10
# ND_counts.7                347              105                1
# ND_counts.8                 70               22                1
# ND_counts.9                 73               34                2
# ND_counts.10                57                5                0
# ND_counts.11               433               81               10
# ND_counts.12               611              133                8
# ND_counts.13               247               59               20
# ND_counts.14               427               72               31
# ND_counts.15               330               69               18
# ND_counts.16               593               83               40
# ND_counts.17               228               53                8
#
#                ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# IGT_counts                 283              426              324
# IGT_counts.1               186              426              471
# IGT_counts.2              1287             1011              446
# IGT_counts.3               130              516              369
# IGT_counts.4                57              525              396
# IGT_counts.5                14              722              358
# IGT_counts.6               140              509              285
# IGT_counts.7               616              668              316
# IGT_counts.8               470              672              495
# IGT_counts.9                40              441              222
# IGT_counts.10              908              796              530
# IGT_counts.11              443              474              316
# IGT_counts.12                4              262               53
# IGT_counts.13                3              124              116
# IGT_counts.14               15              144               78
# IGT_counts.15             3459              718              416
# IGT_counts.16              123              394              292
# IGT_counts.17              511              699              461
# IGT_counts.18              191              398              469
# IGT_counts.19             2404              704              488
# IGT_counts.20              872              919              515
# IGT_counts.21             1643             1023              545
# IGT_counts.22              542              618              482
# IGT_counts.23              847              860              564
# IGT_counts.24              423              732              355
# IGT_counts.25              619              752              439
# IGT_counts.26              375              744              463
# IGT_counts.27              226              526              326
# IGT_counts.28             1827              781              426
# IGT_counts.29              368              953              598
# IGT_counts.30              463              705              260
# IGT_counts.31              704             1008              510
# IGT_counts.32              529              632              362
# IGT_counts.33             1483             1210              571
# IGT_counts.34              347              777              287
# IGT_counts.35             1004              842              276
# IGT_counts.36             1599             1323              685
# IGT_counts.37             2613              941              813
# IGT_counts.38              420              876              429
# IGT_counts.39              576             1013              470
# IGT_counts.40              770             1104              668
# ND_counts                   29              612              318
# ND_counts.1                121              468              226
# ND_counts.2                472              556              317
# ND_counts.3                 23              582              402
# ND_counts.4                 42              383              196
# ND_counts.5                217              767              354
# ND_counts.6                301              570              341
# ND_counts.7                  3              431              173
# ND_counts.8                  2              149               62
# ND_counts.9                  7              151              106
# ND_counts.10                 5              101               50
# ND_counts.11               294              611              468
# ND_counts.12              1109              775              590
# ND_counts.13               203              554              317
# ND_counts.14               368              722              529
# ND_counts.15               221              494              719
# ND_counts.16               633              939              673
# ND_counts.17               404              613              362
#
#                ENSG00000001167  ...  ENSG00000285467  ENSG00000285471  \
# IGT_counts                 252  ...                1                0
# IGT_counts.1               236  ...                0                0
# IGT_counts.2               237  ...                1                0
# IGT_counts.3               250  ...               23                0
# IGT_counts.4               251  ...                7                0
# IGT_counts.5               327  ...                9                0
# IGT_counts.6               185  ...                0                0
# IGT_counts.7               305  ...                2                0
# IGT_counts.8               241  ...                6                0
# IGT_counts.9               202  ...                7                1
# IGT_counts.10              331  ...               10                0
# IGT_counts.11              212  ...               14                0
# IGT_counts.12               81  ...                0                0
# IGT_counts.13               97  ...                1                0
# IGT_counts.14               42  ...                3                0
# IGT_counts.15              201  ...                7                0
# IGT_counts.16              314  ...                4                0
# IGT_counts.17              392  ...                6                0
# IGT_counts.18              307  ...                8                0
# IGT_counts.19              363  ...                6                0
# IGT_counts.20              341  ...                4                0
# IGT_counts.21              533  ...                6                0
# IGT_counts.22              340  ...                7                0
# IGT_counts.23              330  ...                7                0
# IGT_counts.24              413  ...                3                0
# IGT_counts.25              319  ...                2                0
# IGT_counts.26              276  ...                0                0
# IGT_counts.27              264  ...               12                0
# IGT_counts.28              299  ...                1                0
# IGT_counts.29              211  ...               13                0
# IGT_counts.30              191  ...                7                0
# IGT_counts.31              333  ...               10                0
# IGT_counts.32              177  ...                3                0
# IGT_counts.33              275  ...                2                0
# IGT_counts.34              214  ...                2                0
# IGT_counts.35              316  ...                9                0
# IGT_counts.36              400  ...               15                0
# IGT_counts.37              407  ...                2                0
# IGT_counts.38              224  ...                1                0
# IGT_counts.39              235  ...                5                0
# IGT_counts.40              245  ...                9                0
# ND_counts                  298  ...                5                0
# ND_counts.1                180  ...                3                0
# ND_counts.2                246  ...                6                0
# ND_counts.3                402  ...               10                0
# ND_counts.4                323  ...                2                0
# ND_counts.5                269  ...                2                0
# ND_counts.6                329  ...                8                0
# ND_counts.7                199  ...                5                0
# ND_counts.8                 70  ...                3                0
# ND_counts.9                 69  ...                1                0
# ND_counts.10                47  ...                2                0
# ND_counts.11               426  ...                9                0
# ND_counts.12               477  ...                3                0
# ND_counts.13               243  ...                7                0
# ND_counts.14               379  ...                3                0
# ND_counts.15               299  ...                0                0
# ND_counts.16               466  ...                5                0
# ND_counts.17               304  ...                0                0
#
#                ENSG00000285473  ENSG00000285476  ENSG00000285480  \
# IGT_counts                   0               18                1
# IGT_counts.1                 0               14                0
# IGT_counts.2                 0                5                0
# IGT_counts.3                 0                2                0
# IGT_counts.4                 0                0                0
# IGT_counts.5                 0               29                0
# IGT_counts.6                 0               13                0
# IGT_counts.7                 0               27                0
# IGT_counts.8                 0               91                0
# IGT_counts.9                 0                2                0
# IGT_counts.10                0               34                0
# IGT_counts.11                0               57                0
# IGT_counts.12                0                3                0
# IGT_counts.13                0                9                0
# IGT_counts.14                0                7                0
# IGT_counts.15                0                0                0
# IGT_counts.16                0               64                0
# IGT_counts.17                0               72                0
# IGT_counts.18                0               55                0
# IGT_counts.19                0                1                0
# IGT_counts.20                0               38                0
# IGT_counts.21                0               57                0
# IGT_counts.22                0               18                0
# IGT_counts.23                0               10                0
# IGT_counts.24                1               32                0
# IGT_counts.25                0               33                0
# IGT_counts.26                0               38                0
# IGT_counts.27                0               32                0
# IGT_counts.28                0               85                0
# IGT_counts.29                0                8                0
# IGT_counts.30                0                5                0
# IGT_counts.31                0               14                0
# IGT_counts.32                0               16                0
# IGT_counts.33                0               94                0
# IGT_counts.34                0               69                0
# IGT_counts.35                0                3                0
# IGT_counts.36                0               53                0
# IGT_counts.37                0              115                0
# IGT_counts.38                0               35                0
# IGT_counts.39                0               38                0
# IGT_counts.40                0                2                0
# ND_counts                    0               69                0
# ND_counts.1                  0               30                0
# ND_counts.2                  0               13                0
# ND_counts.3                  0               64                0
# ND_counts.4                  0               19                0
# ND_counts.5                  0               44                0
# ND_counts.6                  0               41                0
# ND_counts.7                  1              112                0
# ND_counts.8                  0                8                0
# ND_counts.9                  0               19                0
# ND_counts.10                 0               30                0
# ND_counts.11                 0               45                0
# ND_counts.12                 0               23                0
# ND_counts.13                 0               27                0
# ND_counts.14                 0               32                0
# ND_counts.15                 0               24                0
# ND_counts.16                 0               55                0
# ND_counts.17                 0               68                0
#
#                ENSG00000285483  ENSG00000285486  ENSG00000285492  \
# IGT_counts                   2                0                1
# IGT_counts.1                 0                0                0
# IGT_counts.2                 0                0                4
# IGT_counts.3                 0                0               12
# IGT_counts.4                 0                0                0
# IGT_counts.5                 0                0                0
# IGT_counts.6                 0                0                2
# IGT_counts.7                 2                0                2
# IGT_counts.8                 0                1                0
# IGT_counts.9                 0               25                0
# IGT_counts.10                0                0                1
# IGT_counts.11                0                0                0
# IGT_counts.12                0                0                1
# IGT_counts.13                0                2                2
# IGT_counts.14                0                1                0
# IGT_counts.15                0                0                1
# IGT_counts.16                0                0                3
# IGT_counts.17                0                2                0
# IGT_counts.18                0                2               11
# IGT_counts.19                1                1               10
# IGT_counts.20                0                0                0
# IGT_counts.21                0                0                1
# IGT_counts.22                4                0                0
# IGT_counts.23                0                0                3
# IGT_counts.24                0                1                0
# IGT_counts.25                3                2                0
# IGT_counts.26                1                1                4
# IGT_counts.27                0                2                0
# IGT_counts.28                0                0                0
# IGT_counts.29                0                0                4
# IGT_counts.30                0                0                0
# IGT_counts.31                0                1                0
# IGT_counts.32                0                0                3
# IGT_counts.33                0                0                0
# IGT_counts.34                1                0                0
# IGT_counts.35                0                0                0
# IGT_counts.36                3                0                0
# IGT_counts.37                0                0               21
# IGT_counts.38                0                0                7
# IGT_counts.39                0                0                0
# IGT_counts.40                0                0                0
# ND_counts                    0                1                0
# ND_counts.1                  0                0                5
# ND_counts.2                  0                0                0
# ND_counts.3                  0                2                5
# ND_counts.4                  0                0                0
# ND_counts.5                  0                0                4
# ND_counts.6                  6                0                4
# ND_counts.7                  0               17               10
# ND_counts.8                  0                0                1
# ND_counts.9                  0                0                0
# ND_counts.10                 0                0                0
# ND_counts.11                 2                0                3
# ND_counts.12                 2                0                0
# ND_counts.13                 0                0                0
# ND_counts.14                 1                0                3
# ND_counts.15                 2                0                0
# ND_counts.16                 0                0                1
# ND_counts.17                 0                0                0
#
#                ENSG00000285498  ENSG00000285509
# IGT_counts                   0                5
# IGT_counts.1                 0                0
# IGT_counts.2                 0                6
# IGT_counts.3                 0                4
# IGT_counts.4                 0                0
# IGT_counts.5                 0                7
# IGT_counts.6                 0                1
# IGT_counts.7                 0                2
# IGT_counts.8                 0                5
# IGT_counts.9                 0                0
# IGT_counts.10                0               10
# IGT_counts.11                0                6
# IGT_counts.12                0                0
# IGT_counts.13                0                2
# IGT_counts.14                0                0
# IGT_counts.15                0                9
# IGT_counts.16                0                4
# IGT_counts.17                0                7
# IGT_counts.18                0                1
# IGT_counts.19                0                1
# IGT_counts.20                0                2
# IGT_counts.21                0                4
# IGT_counts.22                0                6
# IGT_counts.23                0                0
# IGT_counts.24                0               11
# IGT_counts.25                0                1
# IGT_counts.26                0                1
# IGT_counts.27                0                6
# IGT_counts.28                0               10
# IGT_counts.29                0                1
# IGT_counts.30                0                6
# IGT_counts.31                0                9
# IGT_counts.32                0                0
# IGT_counts.33                0                4
# IGT_counts.34                0                0
# IGT_counts.35                0                6
# IGT_counts.36                0                9
# IGT_counts.37                0               10
# IGT_counts.38                0                0
# IGT_counts.39                0                4
# IGT_counts.40                0                2
# ND_counts                    0                2
# ND_counts.1                  0                0
# ND_counts.2                  0                0
# ND_counts.3                  0                8
# ND_counts.4                  0               17
# ND_counts.5                  0               11
# ND_counts.6                  0                5
# ND_counts.7                  0                0
# ND_counts.8                  1                0
# ND_counts.9                  0                2
# ND_counts.10                 0                0
# ND_counts.11                 0                9
# ND_counts.12                 0               13
# ND_counts.13                 0               11
# ND_counts.14                 0               13
# ND_counts.15                 0                4
# ND_counts.16                 0               12
# ND_counts.17                 0               24
#
# [59 rows x 49239 columns]

# %% [markdown]
# # Preparar les dades per fer DEG:

# %% [markdown]
# Abans d'estudiar els DEG's s'han de preparar i obtenir els components necessaris per fer l'estudi i implementar deseq2: metadata, data frame amb els nivells d'expressió.

# %%
#Definir les condicions, marcant el numero de files a les que correspon:
conditions = ['IGT'] * 41 + ['ND'] * 18 

# Crear un dataframe composat per el nom de les mostres i a quina condició patològica té:
metadata = pd.DataFrame(zip(counts.index, conditions), columns=['Sample', 'condition'])

#En el dataframe metadata establir la columna sample com index:
metadata=metadata.set_index('Sample')
metadata
# Out:
#               condition
# Sample
# IGT_counts          IGT
# IGT_counts.1        IGT
# IGT_counts.2        IGT
# IGT_counts.3        IGT
# IGT_counts.4        IGT
# IGT_counts.5        IGT
# IGT_counts.6        IGT
# IGT_counts.7        IGT
# IGT_counts.8        IGT
# IGT_counts.9        IGT
# IGT_counts.10       IGT
# IGT_counts.11       IGT
# IGT_counts.12       IGT
# IGT_counts.13       IGT
# IGT_counts.14       IGT
# IGT_counts.15       IGT
# IGT_counts.16       IGT
# IGT_counts.17       IGT
# IGT_counts.18       IGT
# IGT_counts.19       IGT
# IGT_counts.20       IGT
# IGT_counts.21       IGT
# IGT_counts.22       IGT
# IGT_counts.23       IGT
# IGT_counts.24       IGT
# IGT_counts.25       IGT
# IGT_counts.26       IGT
# IGT_counts.27       IGT
# IGT_counts.28       IGT
# IGT_counts.29       IGT
# IGT_counts.30       IGT
# IGT_counts.31       IGT
# IGT_counts.32       IGT
# IGT_counts.33       IGT
# IGT_counts.34       IGT
# IGT_counts.35       IGT
# IGT_counts.36       IGT
# IGT_counts.37       IGT
# IGT_counts.38       IGT
# IGT_counts.39       IGT
# IGT_counts.40       IGT
# ND_counts            ND
# ND_counts.1          ND
# ND_counts.2          ND
# ND_counts.3          ND
# ND_counts.4          ND
# ND_counts.5          ND
# ND_counts.6          ND
# ND_counts.7          ND
# ND_counts.8          ND
# ND_counts.9          ND
# ND_counts.10         ND
# ND_counts.11         ND
# ND_counts.12         ND
# ND_counts.13         ND
# ND_counts.14         ND
# ND_counts.15         ND
# ND_counts.16         ND
# ND_counts.17         ND

# %% [markdown]
# Creació de l'objecte dds; objecte AnnData que conté informació per calcular el canvi logarítmic (LFC), entre d'altres.

# %%
from pydeseq2.dds import DeseqDataSet

# Creació de dds: objecte amb informació informació necessaria per fer DEG.
dds = DeseqDataSet(counts=counts,metadata=metadata,design_factors="condition")
dds
# Out:
# AnnData object with n_obs × n_vars = 59 × 49239
#     obs: 'condition'
#     obsm: 'design_matrix'

# %%
# Ampliació de l'AnnData, amb el càlcul dels valors estadístics (resultats) com: log2FoldChange, Pvalue, Pvalue asj (equival a qvalue)...
dds.deseq2()
dds
# Out:
# Fitting size factors...
# ... done in 0.18 seconds.
#
# Fitting dispersions...
# ... done in 8.95 seconds.
#
# Fitting dispersion trend curve...
# ... done in 1.16 seconds.
#
# Fitting MAP dispersions...
# ... done in 9.46 seconds.
#
# Fitting LFCs...
# ... done in 6.69 seconds.
#
# Replacing 1386 outlier genes.
#
# Fitting dispersions...
# ... done in 0.36 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.34 seconds.
#
# Fitting LFCs...
# ... done in 0.31 seconds.
# AnnData object with n_obs × n_vars = 59 × 49239
#     obs: 'condition'
#     uns: 'trend_coeffs', 'disp_function_type', '_squared_logres', 'prior_disp_var'
#     obsm: 'design_matrix', 'size_factors', 'replaceable'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'refitted'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks'

# %% [markdown]
# # Veure si estan les dades normalitzades:

# %% [markdown]
# ## 1. Boxplot abans de normalitzar:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))  # Ajusta el tamany de la figura

counts1.boxplot()
plt.title('Boxplot of Counts before normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### TRANSFORMAR LES DADES PER VISUALITZAR-HO MILLOR: Log2P

# %%
import numpy as np
counts1_t= np.log2(counts1 +1)
counts1_t

plt.figure(figsize=(12, 8))  # Ajusta el tamaño de la figura

counts1_t.boxplot(patch_artist=True, boxprops = dict(facecolor = "lightblue"))
plt.title('Boxplot of Counts before normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Reduïr la densitat de mostres per veure millor: 20 mostres

# %%
columns_IGT = [col for col in counts1_t.columns if col.startswith('IGT')]
columns_ND = [col for col in counts1_t.columns if col.startswith('ND')]

counts1_t_20 = counts1_t[columns_IGT[:10] + columns_ND[:10]]

plt.figure(figsize=(12, 8))  # Ajusta el tamaño de la figura

bp=counts1_t_20.boxplot(patch_artist=True, boxprops = dict(facecolor = "lightblue"))

plt.title('Boxplot of Counts before normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 2. Boxplot després normalitzar:

# %% [markdown]
# #### 2.1 Construcció dataframe normalitzat:

# %%
normalized_data=dds.layers['normed_counts']
normalized_data
# Out:
# array([[5.64582749e+02, 0.00000000e+00, 6.67702886e+02, ...,
#         1.28900171e+00, 0.00000000e+00, 6.44500855e+00],
#        [1.21134259e+02, 0.00000000e+00, 5.85140064e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.78684169e+02, 8.44240156e-01, 7.53062220e+02, ...,
#         3.37696063e+00, 0.00000000e+00, 5.06544094e+00],
#        ...,
#        [4.89142515e+02, 0.00000000e+00, 9.53339847e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 4.33829282e+00],
#        [3.69205853e+02, 0.00000000e+00, 8.28042066e+02, ...,
#         5.93578542e-01, 0.00000000e+00, 7.12294250e+00],
#        [3.59397780e+02, 0.00000000e+00, 8.11726911e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 2.27586984e+01]])

# %%
normalized_df = pd.DataFrame(dds.layers['normed_counts'].T, index=dds.var_names, columns=dds.obs_names)
normalized_df
# Out:
# Sample           IGT_counts  IGT_counts.1  IGT_counts.2  IGT_counts.3  \
# ENSG00000000003  564.582749    121.134259    478.684169    300.073525
# ENSG00000000005    0.000000      0.000000      0.844240      6.141856
# ENSG00000000419  667.702886    585.140064    753.062220    489.593646
# ENSG00000000457  320.961426    316.180947    240.608445    307.970197
# ENSG00000000460   55.427074     32.849969     36.302327     49.134846
# ...                     ...           ...           ...           ...
# ENSG00000285483    2.578003      0.000000      0.000000      0.000000
# ENSG00000285486    0.000000      0.000000      0.000000      0.000000
# ENSG00000285492    1.289002      0.000000      3.376961     10.528896
# ENSG00000285498    0.000000      0.000000      0.000000      0.000000
# ENSG00000285509    6.445009      0.000000      5.065441      3.509632
#
# Sample           IGT_counts.4  IGT_counts.5  IGT_counts.6  IGT_counts.7  \
# ENSG00000000003    164.487782     96.757213    364.524292    298.713371
# ENSG00000000005      1.797681      0.000000      0.000000      1.584686
# ENSG00000000419    544.697245    587.393347    638.184758    854.938268
# ENSG00000000457    186.059950    268.865176    237.314935    438.958110
# ENSG00000000460     50.335059     55.656804     52.380324     63.387453
# ...                       ...           ...           ...           ...
# ENSG00000285483      0.000000      0.000000      0.000000      1.584686
# ENSG00000285486      0.000000      0.000000      0.000000      0.000000
# ENSG00000285492      0.000000      0.000000      2.137972      1.584686
# ENSG00000285498      0.000000      0.000000      0.000000      0.000000
# ENSG00000285509      0.000000      5.993810      1.068986      1.584686
#
# Sample           IGT_counts.8  IGT_counts.9  ...  ND_counts.8  ND_counts.9  \
# ENSG00000000003    384.910973    187.509312  ...   166.507538   104.635133
# ENSG00000000005      0.000000      0.000000  ...     0.000000     0.000000
# ENSG00000000419    706.375082    569.584739  ...   488.169826   507.788145
# ENSG00000000457    270.706618    171.379479  ...   264.898355   224.657785
# ENSG00000000460     34.684285     40.324583  ...    83.253769   104.635133
# ...                       ...           ...  ...          ...          ...
# ENSG00000285483      0.000000      0.000000  ...     0.000000     0.000000
# ENSG00000285486      0.845958     25.202865  ...     0.000000     0.000000
# ENSG00000285492      0.000000      0.000000  ...     3.784262     0.000000
# ENSG00000285498      0.000000      0.000000  ...     3.784262     0.000000
# ENSG00000285509      4.229791      0.000000  ...     0.000000     6.155008
#
# Sample           ND_counts.10  ND_counts.11  ND_counts.12  ND_counts.13  \
# ENSG00000000003    137.539222    222.595571    362.611179    694.185536
# ENSG00000000005      0.000000      1.413305      0.000000     11.832708
# ENSG00000000419    726.993030    718.665702    786.692404    863.787684
# ENSG00000000457    279.990559    305.980579    379.375737    243.556573
# ENSG00000000460     24.560575     57.238861     82.580971     58.177481
# ...                       ...           ...           ...           ...
# ENSG00000285483      0.000000      1.413305      1.241819      0.000000
# ENSG00000285486      0.000000      0.000000      0.000000      0.000000
# ENSG00000285492      0.000000      2.119958      0.000000      0.000000
# ENSG00000285498      0.000000      0.000000      0.000000      0.000000
# ENSG00000285509      0.000000      6.359873      8.071824     10.846649
#
# Sample           ND_counts.14  ND_counts.15  ND_counts.16  ND_counts.17
# ENSG00000000003    283.984017    489.142515    369.205853    359.397780
# ENSG00000000005      0.000000      0.000000      0.000000      0.000000
# ENSG00000000419    653.671651    953.339847    828.042066    811.726911
# ENSG00000000457    310.130883    357.909158    351.992075    216.207635
# ENSG00000000460     52.293732     74.835551     49.267019     50.258792
# ...                       ...           ...           ...           ...
# ENSG00000285483      0.726302      2.169146      0.000000      0.000000
# ENSG00000285486      0.000000      0.000000      0.000000      0.000000
# ENSG00000285492      2.178906      0.000000      0.593579      0.000000
# ENSG00000285498      0.000000      0.000000      0.000000      0.000000
# ENSG00000285509      9.441924      4.338293      7.122943     22.758698
#
# [49239 rows x 59 columns]

# %%
#EXPORTAR DATAFRAME:
#import os
#directory = r"C:/Users/NOE/Desktop/TFG-Example/Islets study/Expressió genètica/Normalized dataframes"
#file_path = os.path.join(directory, "normalized_IGT_ND.csv")
#normalized_df.to_csv(file_path)

# %%
normalized_df_t= np.log2(normalized_df +1)
normalized_df_t

plt.figure(figsize=(12, 8)) 

normalized_df_t.boxplot(patch_artist=True, boxprops = dict(facecolor = "lightblue"))
plt.title('Boxplot of Counts after normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')

plt.xticks(rotation=90)
plt.show()

# %%
columns_IGT_n = [col for col in normalized_df_t.columns if col.startswith('IGT')]
columns_ND_n = [col for col in normalized_df_t.columns if col.startswith('ND')]

normalized_t_20 = normalized_df_t[columns_IGT_n[:10] + columns_ND_n[:10]]

plt.figure(figsize=(12, 8))  # Ajusta el tamaño de la figura

bp=normalized_t_20.boxplot(patch_artist=True, boxprops = dict(facecolor = "lightblue"))

plt.title('Boxplot of Counts after normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## DEG study:

# %%
from pydeseq2.default_inference import DefaultInference

#Creació de stat_res: objecte que tindrà només els resultats estadístics: log2foldchange...
inference = DefaultInference(n_cpus=8)
stat_res=DeseqStats(dds, inference=inference, contrast=('condition','IGT','ND'))
stat_res.summary()
# Out:
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition IGT vs ND
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  375.858358        0.207009  0.191833  1.079108  0.280540
# ENSG00000000005    1.135940        0.609883  1.085685  0.561749  0.574287
# ENSG00000000419  760.691720       -0.018704  0.106511 -0.175606  0.860604
# ENSG00000000457  278.923873       -0.102330  0.088957 -1.150334  0.250006
# ENSG00000000460   59.355734       -0.482489  0.162198 -2.974696  0.002933
# ...                     ...             ...       ...       ...       ...
# ENSG00000285483    0.416860       -0.908301  1.201300 -0.756098  0.449590
# ENSG00000285486    0.405219        0.273287  1.231707  0.221876  0.824410
# ENSG00000285492    1.961758       -0.130679  0.776063 -0.168387  0.866279
# ENSG00000285498    0.064140       -0.554218  3.282275 -0.168852  0.865913
# ENSG00000285509    4.401411       -1.140698  0.421924 -2.703561  0.006860
#
#                      padj
# ENSG00000000003  0.732487
# ENSG00000000005       NaN
# ENSG00000000419  0.973310
# ENSG00000000457  0.706371
# ENSG00000000460  0.103487
# ...                   ...
# ENSG00000285483       NaN
# ENSG00000285486       NaN
# ENSG00000285492       NaN
# ENSG00000285498       NaN
# ENSG00000285509       NaN
#
# [49239 rows x 6 columns]
# ... done in 3.20 seconds.

# %%
#Guardar els valors (resultats) de stat_res com a nom de res:
res =stat_res.results_df
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  375.858358        0.207009  0.191833  1.079108  0.280540
# ENSG00000000005    1.135940        0.609883  1.085685  0.561749  0.574287
# ENSG00000000419  760.691720       -0.018704  0.106511 -0.175606  0.860604
# ENSG00000000457  278.923873       -0.102330  0.088957 -1.150334  0.250006
# ENSG00000000460   59.355734       -0.482489  0.162198 -2.974696  0.002933
# ...                     ...             ...       ...       ...       ...
# ENSG00000285483    0.416860       -0.908301  1.201300 -0.756098  0.449590
# ENSG00000285486    0.405219        0.273287  1.231707  0.221876  0.824410
# ENSG00000285492    1.961758       -0.130679  0.776063 -0.168387  0.866279
# ENSG00000285498    0.064140       -0.554218  3.282275 -0.168852  0.865913
# ENSG00000285509    4.401411       -1.140698  0.421924 -2.703561  0.006860
#
#                      padj
# ENSG00000000003  0.732487
# ENSG00000000005       NaN
# ENSG00000000419  0.973310
# ENSG00000000457  0.706371
# ENSG00000000460  0.103487
# ...                   ...
# ENSG00000285483       NaN
# ENSG00000285486       NaN
# ENSG00000285492       NaN
# ENSG00000285498       NaN
# ENSG00000285509       NaN
#
# [49239 rows x 6 columns]

# %%
from sanbomics.tools import id_map

#Mapejar els símbols genètics corresponents a les anotacions ensembl:
mapper = id_map(species='human')
res['Symbol'] = res.index.map(mapper.mapper)
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  375.858358        0.207009  0.191833  1.079108  0.280540
# ENSG00000000005    1.135940        0.609883  1.085685  0.561749  0.574287
# ENSG00000000419  760.691720       -0.018704  0.106511 -0.175606  0.860604
# ENSG00000000457  278.923873       -0.102330  0.088957 -1.150334  0.250006
# ENSG00000000460   59.355734       -0.482489  0.162198 -2.974696  0.002933
# ...                     ...             ...       ...       ...       ...
# ENSG00000285483    0
# ENSG00000249751  0.042144      ECSCR
# ENSG00000253755  0.028480      IGHGP
# ENSG00000275832  0.038299   ARHGAP23
#
# [135 rows x 7 columns]

# %% [markdown]
# ### PCA:

# %% [markdown]
# #### PCA amb valors normalitzats:

# %%
normalized=normalized_df.T
normalized
import pandas as pd

# Añadir la columna "conditions" basada en el índice
normalized['conditions'] = normalized.index.map(lambda x: 'IGT' if x.startswith('IGT') else 'ND' if x.startswith('ND') else 'Other')
normalized.set_index('conditions', inplace=True)
normalized.index.name = None
normalized

# Añadir la columna "patologia" basada en el índice
normalized['patologia'] = normalized.index.map(lambda x: 'IGT' if x.startswith('IGT') else 'ND' if x.startswith('ND') else 'Other')

# Mover el índice a una nueva columna
normalized.reset_index(inplace=True)

# Cambiar el nombre de la nueva columna a 'patologia' y eliminar la columna anterior
normalized = normalized.rename(columns={'index': 'patologia'}).iloc[:, :-1]

normalized
# Out:
#    patologia  ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# 0        IGT       564.582749         0.000000       667.702886
# 1        IGT       121.134259         0.000000       585.140064
# 2        IGT       478.684169         0.844240       753.062220
# 3        IGT       300.073525         6.141856       489.593646
# 4        IGT       164.487782         1.797681       544.697245
# 5        IGT        96.757213         0.000000       587.393347
# 6        IGT       364.524292         0.000000       638.184758
# 7        IGT       298.713371         1.584686       854.938268
# 8        IGT       384.910973         0.000000       706.375082
# 9        IGT       187.509312         0.000000       569.584739
# 10       IGT       353.814124         1.486614       689.045573
# 11       IGT       412.196696         5.916699       435.863492
# 12       IGT       173.794697         2.896578       611.178017
# 13       IGT       252.862250         3.241824       638.639272
# 14       IGT       238.413304         0.000000       658.474838
# 15       IGT       767.019940         3.921370       586.636927
# 16       IGT       236.602331         0.000000       517.741572
# 17       IGT       355.811759         0.000000       722.696498
# 18       IGT       149.350735         0.000000       558.287271
# 19       IGT       922.357268         0.784317       589.022371
# 20       IGT       464.778790         0.000000       660.120600
# 21       IGT       575.687184         0.000000       581.715322
# 22       IGT       291.431199         8.370087       804.289235
# 23       IGT       426.457586         0.000000       780.827146
# 24       IGT       507.324091         0.000000       939.007994
# 25       IGT       324.215830         0.000000      1030.475461
# 26       IGT       471.403175         0.000000       711.114809
# 27       IGT       274.080640         0.825544      1038.534474
# 28       IGT       415.570298         0.000000       902.948699
# 29       IGT       538.773431         2.229407       700.777028
# 30       IGT       418.925304         0.000000      1094.236765
# 31       IGT       554.723577         0.000000       895.855527
# 32       IGT       579.850118         0.000000      1060.873608
# 33       IGT       717.105479         0.000000       908.745737
# 34       IGT       182.802226         0.000000       808.548310
# 35       IGT       428.698918         0.000000      1248.008191
# 36       IGT       346.729666         3.176150       818.917243
# 37       IGT       272.583119        32.856001       657.728464
# 38       IGT       492.957847         9.242960      1129.951815
# 39       IGT       531.688306         1.314433       962.165242
# 40       IGT       436.315453         0.000000       938.513296
# 41        ND       212.142914         0.000000       786.508569
# 42        ND       258.847656         0.000000       777.850280
# 43        ND       442.780550         0.000000       649.325413
# 44        ND       215.273565         0.000000       687.064696
# 45        ND       649.873599        34.118364       896.825566
# 46        ND       464.356110         0.000000      1415.054887
columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

x = normalized.iloc[:, 1:49240].values  
y = normalized.loc[:, ["patologia"]].values

pca = PCA(n_components=2)
components = pca.fit_transform(x)

# Crear DataFrame para los componentes principales
pca_df = pd.DataFrame(data=components, columns=['PC1', 'PC2'])

# Concatenar con la columna y
pcaDF = pd.concat([pca_df, pd.DataFrame(y, columns=["patologia"])], axis=1)


# Graficar los resultados
plt.figure(figsize=(12, 6))
scatter=sns.scatterplot(data=pcaDF, x='PC1', y='PC2', hue="patologia")

explained_variance = pca.explained_variance_ratio_

# Imprimir la varianza explicada de cada componente
for i, var in enumerate(explained_variance):
    print(f"Varianza explicada por el Componente Principal {i+1}: {var:.2%}")


plt.title('PCA: Componentes Principales')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.show()
# Out:
# Varianza explicada por el Componente Principal 1: 50.80%
# Varianza explicada por el Componente Principal 2: 30.84%

# %% [markdown]
# #### PCA sense valors normalitzat:

# %%
import scanpy as sc

#PCA
sc.tl.pca(dds)
sc.pl.pca(dds, color='condition',size=200)

# %% [markdown]
# ## ClusterMap:

# %%
import numpy as np
import seaborn as sns

dds.layers['normed_counts']
# Out:
# array([[5.64582749e+02, 0.00000000e+00, 6.67702886e+02, ...,
#         1.28900171e+00, 0.00000000e+00, 6.44500855e+00],
#        [1.21134259e+02, 0.00000000e+00, 5.85140064e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.78684169e+02, 8.44240156e-01, 7.53062220e+02, ...,
#         3.37696063e+00, 0.00000000e+00, 5.06544094e+00],
#        ...,
#        [4.89142515e+02, 0.00000000e+00, 9.53339847e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 4.33829282e+00],
#        [3.69205853e+02, 0.00000000e+00, 8.28042066e+02, ...,
#         5.93578542e-01, 0.00000000e+00, 7.12294250e+00],
#        [3.59397780e+02, 0.00000000e+00, 8.11726911e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 2.27586984e+01]])

# %%
dds.layers['log2']=np.log2(dds.layers['normed_counts'] +1)
dds
# Out:
# AnnData object with n_obs × n_vars = 59 × 49239
#     obs: 'condition'
#     uns: 'trend_coeffs', 'disp_function_type', '_squared_logres', 'prior_disp_var'
#     obsm: 'design_matrix', 'size_factors', 'replaceable'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'refitted'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks', 'log2'

# %% [markdown]
# ### Clustermap de Valors normalitzats transformats a log2:

# %%
grapher=pd.DataFrame(dds.layers['log2'].T,
                    index=dds.var_names, columns=dds.obs_names) #dataframe con los valores filtrados de mayor expression i con los valores transformados a log +1.
grapher
# Out:
# Sample           IGT_counts  IGT_counts.1  IGT_counts.2  IGT_counts.3  \
# ENSG00000000003    9.143594      6.932324      8.905941      8.233972
# ENSG00000000005    0.000000      0.000000      0.883027      2.836299
# ENSG00000000419    9.385222      9.195102      9.558540      8.938385
# ENSG00000000457    8.330744      8.309162      7.916527      8.271324
# ENSG00000000460    5.818316      5.081083      5.221194      5.647742
# ...                     ...           ...           ...           ...
# ENSG00000285483    1.839155      0.000000      0.000000      0.000000
# ENSG00000285486    0.000000      0.000000      0.000000      0.000000
# ENSG00000285492    1.194719      0.000000      2.129929      3.527182
# ENSG00000285498    0.000000      0.000000      0.000000      0.000000
# ENSG00000285509    2.896274      0.000000      2.600613      2.173010
#
# Sample           IGT_counts.4  IGT_counts.5  IGT_counts.6  IGT_counts.7  \
# ENSG00000000003      7.370581      6.611131      8.513823      8.227440
# ENSG00000000005      1.484231      0.000000      0.000000      1.369989
# ENSG00000000419      9.091957      9.200637      9.320089      9.741363
# ENSG00000000457      7.547357      8.076095      7.896726      8.781222
# ENSG00000000460      5.681873      5.824177      5.738236      6.008708
# ...                       ...           ...           ...           ...
# ENSG00000285483      0.000000      0.000000      0.000000      1.369989
# ENSG00000285486      0.000000      0.000000      0.000000      0.000000
# ENSG00000285492      0.000000      0.000000      1.649833      1.369989
# ENSG00000285498      0.000000      0.000000      0.000000      0.000000
# ENSG00000285509      0.000000      2.806079      1.048924      1.369989
#
# Sample           IGT_counts.8  IGT_counts.9  ...  ND_counts.8  ND_counts.9  \
# ENSG00000000003      8.592124      7.558492  ...     7.388082     6.722946
# ENSG00000000005      0.000000      0.000000  ...     0.000000     0.000000
# ENSG00000000419      9.466332      9.156297  ...     8.934192     8.990921
# ENSG00000000457      8.085906      7.429444  ...     8.054731     7.817993
# ENSG00000000460      5.157217      5.368928  ...     6.396669     6.722946
# ...                       ...           ...  ...          ...          ...
# ENSG00000285483      0.000000      0.000000  ...     0.000000     0.000000
# ENSG00000285486      0.884370      4.711653  ...     0.000000     0.000000
# ENSG00000285492      0.000000      0.000000  ...     2.258296     0.000000
# ENSG00000285498      0.000000      0.000000  ...     2.258296     0.000000
# ENSG00000285509      2.386753      0.000000  ...     0.000000     2.838953
#
# Sample           ND_counts.10  ND_counts.11  ND_counts.12  ND_counts.13  \
# ENSG00000000003      7.114151      7.804748      8.506253      9.441254
# ENSG00000000005      0.000000      1.271010      0.000000      3.681754
# ENSG00000000419      9.507781      9.491183      9.621489      9.756202
# ENSG00000000457      8.134378      8.262004      8.571281      7.934024
# ENSG00000000460      4.675848      5.863910      6.385103      5.886976
# ...                       ...           ...           ...           ...
# ENSG00000285483      0.000000      1.271010      1.164670      0.000000
# ENSG00000285486      0.000000      0.000000      0.000000      0.000000
# ENSG00000285492      0.000000      1.641527      0.000000      0.000000
# ENSG00000285498      0.000000      0.000000      0.000000      0.000000
# ENSG00000285509      0.000000      2.879681      3.181393      3.566407
#
# Sample           ND_counts.14  ND_counts.15  ND_counts.16  ND_counts.17
# ENSG00000000003      8.154737      8.937057      8.532184      8.493446
# ENSG00000000005      0.000000      0.000000      0.000000      0.000000
# ENSG00000000419      9.354628      9.898359      9.695301      9.666627
# ENSG00000000457      8.281378      8.487475      8.463492      7.762931
# ENSG00000000460      5.735894      6.244802      5.651540      5.679728
# ...                       ...           ...           ...           ...
# ENSG00000285483      0.787685      1.664094      0.000000      0.000000
# ENSG00000285486      0.000000      0.000000      0.000000      0.000000
# ENSG00000285492      1.668530      0.000000      0.672270      0.000000
# ENSG00000285498      0.000000      0.000000      0.000000      0.000000
# ENSG00000285509      3.384316      2.416378      3.022002      4.570384
#
# [49239 rows x 59 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reorganizar las muestras
nd_samples = [col for col in grapher.columns if "ND" in col]
IGT_samples = [col for col in grapher.columns if "IGT" in col]

ordered_columns = nd_samples + IGT_samples

grapher_ordered = grapher[ordered_columns]

# Crear el clustermap utilizando seaborn
plt.figure(figsize=(14, 10))
clustermap = sns.clustermap(grapher_ordered, z_score=0, cmap="RdYlBu_r", col_cluster=False, cbar_kws={'label':'row Z-Score'})

clustermap.ax_heatmap.set_yticklabels([])
clustermap.ax_heatmap.set_ylabel('genes', fontsize=14)
clustermap.cax.yaxis.label.set_size(14)
# Hacer que las etiquetas del eje x sean más grandes
plt.setp(clustermap.ax_heatmap.xaxis.get_majorticklabels(), fontsize=12)

plt.show()
# Out:
# C:\Users\NOE\anaconda3\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# ### Clustermap dels gens més significatius:

# %%
dds_sigs=dds[:, sigs.index]
#dds_sigs.obs

# %%
grapher1=pd.DataFrame(dds_sigs.layers['log2'].T,
                    index=dds_sigs.var_names, columns=dds_sigs.obs_names) #dataframe con los valores filtrados de mayor expression i con los valores transformados a log +1.
grapher1
# Out:
# Sample           IGT_counts  IGT_counts.1  IGT_counts.2  IGT_counts.3  \
# ENSG00000009790    4.150318      4.559758      6.133968      3.731586
# ENSG00000010610    7.352390      7.125008      8.023376      1.461956
# ENSG00000011028    5.356110      4.428359      6.688643      0.000000
# ENSG00000019582   10.952884     10.926544     12.862155      8.484239
# ENSG00000026025   10.506797      9.159287     12.068944      7.463374
# ...                     ...           ...           ...           ...
# ENSG00000240065    6.805475      6.285256      7.767984      6.273040
# ENSG00000247809    5.309978      2.839832      6.866177      4.772004
# ENSG00000249751    5.262322      4.123085      7.158179      0.908742
# ENSG00000253755    0.000000      2.028458      5.375857      0.000000
# ENSG00000275832    4.810908      4.559758      6.373149      1.860853
#
# Sample           IGT_counts.4  IGT_counts.5  IGT_counts.6  IGT_counts.7  \
# ENSG00000009790      0.000000      0.000000      2.665604      4.535158
# ENSG00000010610      6.018315      3.495069      5.520341      7.492410
# ENSG00000011028      0.000000      0.892398      3.408831      4.583637
# ENSG00000019582      9.307847      7.895930      9.992478     11.812757
# ENSG00000026025      9.028811      6.708839      9.677322     10.295613
# ...                       ...           ...           ...           ...
# ENSG00000240065      4.552808      4.870687      6.284792      7.280835
# ENSG00000247809      3.943119      2.617663      0.000000      5.426070
# ENSG00000249751      1.886168      2.145689      0.000000      5.819260
# ENSG00000253755      0.000000      0.000000      1.649833      0.000000
# ENSG00000275832      5.020565      2.145689      2.399429      5.935886
#
# Sample           IGT_counts.8  IGT_counts.9  ...  ND_counts.8  ND_counts.9  \
# ENSG00000009790      5.407759      2.008754  ...     3.626765     0.000000
# ENSG00000010610      7.481002      4.534717  ...     4.012305     4.282812
# ENSG00000011028      5.318826      2.008754  ...     2.258296     2.027686
# ENSG00000019582     11.716189      8.216191  ...     8.637884    10.006868
# ENSG00000026025     10.649821      5.965669  ...     7.388082     7.091807
# ...                       ...           ...  ...          ...          ...
# ENSG00000240065      7.143935      4.596138  ...     5.649484     5.245269
# ENSG00000247809      6.376046      4.098439  ...     3.626765     0.000000
# ENSG00000249751      6.083866      3.010207  ...     2.258296     0.000000
# ENSG00000253755      3.861492      1.005842  ...     0.000000     2.027686
# ENSG00000275832      5.740102      4.010934  ...     3.626765     0.000000
#
# Sample           ND_counts.10  ND_counts.11  ND_counts.12  ND_counts.13  \
# ENSG00000009790      2.563674      4.939199      3.677765      3.887996
# ENSG00000010610      5.332598      6.526040      6.982123      7.098834
# ENSG00000011028      0.000000      3.011947      4.046381      4.934600
# ENSG00000019582      9.040554      9.844939     11.400120     11.071852
# ENSG00000026025      7.212992      9.084815      9.878138     10.075162
# ...                       ...           ...           ...           ...
# ENSG00000240065      5.905577      5.846298      6.931652      6.579869
# ENSG00000247809      0.000000      4.939199      5.280789      4.440104
# ENSG00000249751      0.000000      4.425790      5.732172      4.565558
# ENSG00000253755      0.000000      1.641527      0.696804      0.000000
# ENSG00000275832      0.000000      3.985474      4.425595      3.151935
#
# Sample           ND_counts.14  ND_counts.15  ND_counts.16  ND_counts.17
# ENSG00000009790      4.022575      3.566295      3.022002      3.928293
# ENSG00000010610      6.692212      6.419483      6.768598      7.538495
# ENSG00000011028      4.723589      4.197957      4.233225      4.733546
# ENSG00000019582     10.493111     11.195226     10.725110     10.462595
# ENSG00000026025     10.395360      9.880210     10.026150      9.858629
# ...                       ...           ...           ...           ...
# ENSG00000240065      6.661488      7.255881      7.522167      6.209794
# ENSG00000247809      5.591249      5.243193      3.930348      4.319443
# ENSG00000249751      5.134886      4.920459      5.097628      4.319443
# ENSG00000253755      0.787685      1.059752      1.129057      1.942923
# ENSG00000275832      5.793704      5.201278      4.993950      4.450363
#
# [135 rows x 59 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reorganizar las muestras
nd_samples1 = [col for col in grapher1.columns if "ND" in col]
igt_samples1 = [col for col in grapher1.columns if "IGT" in col]

ordered_columns1 = nd_samples1 + igt_samples1

grapher_ordered1 = grapher1[ordered_columns1]

# Crear el clustermap utilizando seaborn
plt.figure(figsize=(14, 10))
sns.clustermap(grapher_ordered1, z_score=0, cmap="RdYlBu_r", col_cluster=False, cbar_kws={'label':' row Z-Score'})

plt.show()

# %% [markdown]
# ### VolcanoPlot:

# %% [markdown]
# Amb la implementació del Volcano Plot i establint límits en el log2FoldChange i p-valor ajustat, visualitzarem els gens diferencialment regulats.

# %%
from sanbomics.plots import volcano
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  375.858358        0.207009  0.191833  1.079108  0.280540
# ENSG00000000419  760.691720       -0.018704  0.106511 -0.175606  0.860604
# ENSG00000000457  278.923873       -0.102330  0.088957 -1.150334  0.250006
# ENSG00000000460   59.355734       -0.482489  0.162198 -2.974696  0.002933
# ENSG00000000938   16.763865        0.844285  0.445082  1.896921  0.057838
# ...                     ...             ...       ...       ...       ...
# ENSG00000285410  175.887251        0.117698  0.106849  1.101532  0.270665
# ENSG00000285417   10.839996        0.375319  0.398097  0.942783  0.345792
# ENSG00000285437   17.103908       -0.006891  0.286204 -0.024078  0.980790
# ENSG00000285458   10.714553        0.234254  0.183663  1.275456  0.202148
# ENSG00000285476   33.157900       -0.840548  0.369684 -2.273693  0.022984
#
#                      padj      Symbol
# ENSG00000000003  0.732487      TSPAN6
# ENSG00000000419  0.973310        DPM1
# ENSG00000000457  0.706371       SCYL3
# ENSG00000000460  0.103487    C1orf112
# ENSG00000000938  0.409144         FGR
# ...                   ...         ...
# ENSG00000285410  0.724040  GABPB1-IT1
# ENSG00000285417  0.782133         NaN
# ENSG00000285437  0.998036     POLR2J3
# ENSG00000285458  0.663497         NaN
# ENSG00000285476  0.265916         NaN
#
# [17448 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Datos
t_results = pd.DataFrame({
    'gen': res['Symbol'],
    'p_value': res['pvalue'],
    'q_value': res['padj'],
    'Log2FC': res['log2FoldChange']
})

t_results['sign'] = 'NORMAL'
for idx, row in t_results.iterrows():
    if row['q_value'] < 0.05 and row['Log2FC'] > 1:
        t_results.loc[idx, 'sign'] = 'UP'
    elif row['q_value'] < 0.05 and row['Log2FC'] < -1:
        t_results.loc[idx, 'sign'] = 'DOWN'

t_sign = t_results[t_results['sign'] != 'NORMAL']

# Crear el Volcano Plot
plt.figure(figsize=(10, 6))
colors = {"NORMAL": "#D2D2D2", "UP": "#FF6462", "DOWN": "#62B8FF"}

sns.scatterplot(x=t_results['Log2FC'], y=-np.log10(t_results['q_value']), hue=t_results['sign'], palette=colors, alpha=0.7)
plt.axhline(-np.log10(0.05), color='k', linestyle='--', linewidth=1, label='THRESHOLD')
plt.axvline(1, color='k', linestyle='--', linewidth=1)
plt.axvline(-1, color='k', linestyle='--', linewidth=1)

# Etiquetas y título
plt.xlabel('Log2FC')
plt.ylabel('-log10(q-value)')
plt.title('DE OF IGT vs No Diabetes')
plt.legend()
plt.grid(True)

# Filtrar los genes UP más significativos
up_genes = t_results[t_results['sign'] == 'UP'].nsmallest(5, 'q_value')

for idx, row in up_genes.iterrows():
    plt.text(row['Log2FC'], -np.log10(row['q_value']), row['gen'], fontsize=8, ha='center', va='bottom')

# Filtrar los genes DOWN más significativos
down_genes = t_results[t_results['sign'] == 'DOWN'].nsmallest(5, 'q_value')

for idx, row in down_genes.iterrows():
    plt.text(row['Log2FC'], -np.log10(row['q_value']), row['gen'], fontsize=8, ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Gens diferencialment expressats:

# %%
print("Genes diferencialmente expresados con su q-value y dirección:")
de=t_sign[['gen', 'q_value', 'Log2FC', 'sign']]
de=de.sort_values(by='q_value', ascending=False)
de
# Out:
# Genes diferencialmente expresados con su q-value y dirección:
#                     gen   q_value    Log2FC sign
# ENSG00000165457   FOLR2  0.049761  1.775389   UP
# ENSG00000160255   ITGB2  0.049761  1.426936   UP
# ENSG00000167851  CD300A  0.049761  1.506706   UP
# ENSG00000213088   ACKR1  0.049761  2.785077   UP
# ENSG00000169184     MN1  0.049469  1.512893   UP
# ...                 ...       ...       ...  ...
# ENSG00000166278      C2  0.000744  1.943295   UP
# ENSG00000106483   SFRP4  0.000700  2.564473   UP
# ENSG00000134817   APLNR  0.000597  2.704823   UP
# ENSG00000148773   MKI67  0.000597  4.070988   UP
# ENSG00000173432    SAA1  0.000597  4.028587   UP
#
# [135 rows x 4 columns]

# %%
de.to_csv("C:/Users/NOE/Desktop/TFG_Study/Transcriptòmic_study/Gens Diferencialment Expressats/DiferentialExpresset_gens_IGT.csv", index=False)

# %% [markdown]
# ### Extracció dels gens down-regulated:

# %%
downregulated_genes = t_results[t_results['sign'] == 'DOWN']
downregulated_genes_df = pd.DataFrame(downregulated_genes)


print(downregulated_genes)
# Out:
#                      gen   p_value   q_value     LogFC  sign
# ENSG00000104760     FGL1  0.000078  0.022307 -2.044329  DOWN
# ENSG00000233913  RPL10P9  0.000020  0.017410 -1.522522  DOWN
# ENSG00000104760       FGL1
# ENSG00000233913    RPL10P9
# Name: gen, dtype: object

# %%
genes_downregulated = downregulated_genes_df['gen']
genes_downregulated
# Out:
# ENSG00000104760       FGL1
# ENSG00000233913    RPL10P9
# Name: gen, dtype: object

# %%
genes_downregulated.to_csv('C:/Users/NOE/Desktop/TFG-Example/Islet data/Genes downregulated/IGT_down.txt', index=False, header=False)
