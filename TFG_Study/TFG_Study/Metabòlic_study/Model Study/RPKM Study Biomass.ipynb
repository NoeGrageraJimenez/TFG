# %%
import glob
import os
import time
from scipy.io import loadmat
import cobra
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
directorio= 'C:/Users/NOE/Desktop/TFG-Example/Islet data/RPKM data/RPKM Models'



# Diccionario para almacenar los datos de los modelos cargados
modelos = {}

# Loop para cargar cada archivo .mat
for archivo in os.listdir(directorio):
    if archivo.endswith('.mat'):
        # Construir la ruta completa del archivo
        ruta_archivo = os.path.join(directorio, archivo)
        
        # Cargar el archivo .mat
        datos = cobra.io.load_matlab_model(ruta_archivo)
        
        # Guardar el nombre del modelo
        nombre_modelo = os.path.splitext(archivo)[0]  # Eliminar la extensión .mat del nombre del archivo
        
        
        # Almacenar los datos del modelo en el diccionario
        modelos[nombre_modelo] = datos
        
        # Opcional: Imprimir el nombre del modelo cargado
        print("Modelo cargado:", nombre_modelo)
# Out:
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009231_DP005
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009232_DP007
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009233_DP008
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009237_DP013
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009241_DP025
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009249_DP048
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009251_DP051
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009258_DP059
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009260_DP063
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009264_DP067
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009265_DP068
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009268_DP071
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009273_DP076
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009277_DP081
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009278_DP082
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009282_DP088
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009285_DP093
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009296_DP108
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009298_DP110
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009302_DP116
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009307_DP123
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009313_DP137
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009314_DP138
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009316_DP140
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009318_DP144
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009319_DP145
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009323_DP151
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009341_DP184
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009343_DP186
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009345_DP190
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009349_DP195
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009351_DP204
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009352_DP206
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009353_DP207
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009355_DP209
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009356_DP216
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009357_DP224
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009358_DP229
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009359_DP235
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009360_DP237
# No defined compartments in model ContextModel_IGT. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: IGTModel_IGT_GSM5009361_DP248
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009234_DP010
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009235_DP011
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009236_DP012
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009239_DP019
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009240_DP021
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009252_DP052
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009254_DP054
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009261_DP064
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009266_DP069
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009275_DP079
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009280_DP086
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009286_DP095
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009309_DP125
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009312_DP132
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009320_DP146
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009321_DP147
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009334_DP173
# No defined compartments in model ContextModel_ND. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: NDModel_ND_GSM5009340_DP181
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009230_DP003
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009243_DP030
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009244_DP034
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009247_DP042
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009250_DP049
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009255_DP055
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009257_DP058
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009267_DP070
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009279_DP083
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009281_DP087
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009288_DP097
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009289_DP099
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009290_DP102
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009291_DP103
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009292_DP104
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009293_DP105
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009295_DP107
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009297_DP109
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009299_DP111
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009304_DP118
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009306_DP122
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009308_DP124
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009310_DP126
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009311_DP129
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009315_DP139
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009317_DP143
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009322_DP150
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009325_DP157
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009327_DP161
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009329_DP163
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009330_DP166
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009337_DP177
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009338_DP179
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009342_DP185
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009344_DP187
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009346_DP192
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009347_DP193
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009348_DP194
# No defined compartments in model ContextModel_T2D. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T2DModel_T2D_GSM5009350_DP197
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009229_DP002
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009238_DP017
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009242_DP028
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009245_DP039
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009246_DP040
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009248_DP043
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009253_DP053
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009256_DP057
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009259_DP061
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009262_DP065
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009263_DP066
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009269_DP072
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009270_DP073
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009271_DP074
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009272_DP075
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009274_DP077
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009276_DP080
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009283_DP089
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009284_DP090
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009287_DP096
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009294_DP106
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009300_DP112
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009301_DP114
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009303_DP117
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009305_DP120
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009324_DP152
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009326_DP160
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009328_DP162
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009331_DP167
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009332_DP169
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009333_DP170
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009335_DP174
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009336_DP176
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009339_DP180
# No defined compartments in model ContextModel_T3cD. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# Modelo cargado: T3cDModel_T3cD_GSM5009354_DP208

# %%
resultados = {}

# Loop para optimizar cada modelo cargado
for nombre_modelo, modelo in modelos.items():
    # Llamar a la función optimize() en el modelo actual
    solucion = modelo.optimize()
    # Almacenar el resultado de la optimización en el diccionario
    resultados[nombre_modelo] = solucion
    # Imprimir el resultado de la optimización, si lo deseas
    print("Optimización del modelo", nombre_modelo, "completa. Estado:", modelo.solver.status)
# Out:
# Optimización del modelo IGTModel_IGT_GSM5009231_DP005 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009232_DP007 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009233_DP008 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009237_DP013 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009241_DP025 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009249_DP048 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009251_DP051 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009258_DP059 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009260_DP063 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009264_DP067 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009265_DP068 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009268_DP071 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009273_DP076 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009277_DP081 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009278_DP082 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009282_DP088 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009285_DP093 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009296_DP108 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009298_DP110 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009302_DP116 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009307_DP123 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009313_DP137 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009314_DP138 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009316_DP140 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009318_DP144 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009319_DP145 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009323_DP151 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009341_DP184 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009343_DP186 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009345_DP190 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009349_DP195 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009351_DP204 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009352_DP206 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009353_DP207 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009355_DP209 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009356_DP216 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009357_DP224 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009358_DP229 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009359_DP235 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009360_DP237 completa. Estado: optimal
# Optimización del modelo IGTModel_IGT_GSM5009361_DP248 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009234_DP010 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009235_DP011 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009236_DP012 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009239_DP019 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009240_DP021 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009252_DP052 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009254_DP054 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009261_DP064 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009266_DP069 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009275_DP079 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009280_DP086 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009286_DP095 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009309_DP125 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009312_DP132 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009320_DP146 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009321_DP147 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009334_DP173 completa. Estado: optimal
# Optimización del modelo NDModel_ND_GSM5009340_DP181 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009230_DP003 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009243_DP030 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009244_DP034 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009247_DP042 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009250_DP049 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009255_DP055 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009257_DP058 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009267_DP070 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009279_DP083 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009281_DP087 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009288_DP097 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009289_DP099 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009290_DP102 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009291_DP103 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009292_DP104 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009293_DP105 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009295_DP107 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009297_DP109 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009299_DP111 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009304_DP118 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009306_DP122 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009308_DP124 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009310_DP126 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009311_DP129 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009315_DP139 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009317_DP143 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009322_DP150 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009325_DP157 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009327_DP161 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009329_DP163 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009330_DP166 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009337_DP177 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009338_DP179 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009342_DP185 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009344_DP187 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009346_DP192 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009347_DP193 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009348_DP194 completa. Estado: optimal
# Optimización del modelo T2DModel_T2D_GSM5009350_DP197 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009229_DP002 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009238_DP017 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009242_DP028 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009245_DP039 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009246_DP040 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009248_DP043 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009253_DP053 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009256_DP057 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009259_DP061 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009262_DP065 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009263_DP066 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009269_DP072 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009270_DP073 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009271_DP074 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009272_DP075 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009274_DP077 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009276_DP080 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009283_DP089 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009284_DP090 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009287_DP096 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009294_DP106 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009300_DP112 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009301_DP114 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009303_DP117 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009305_DP120 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009324_DP152 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009326_DP160 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009328_DP162 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009331_DP167 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009332_DP169 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009333_DP170 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009335_DP174 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009336_DP176 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009339_DP180 completa. Estado: optimal
# Optimización del modelo T3cDModel_T3cD_GSM5009354_DP208 completa. Estado: optimal

# %%
biomassas = {}

# Loop para optimizar cada modelo cargado
for nombre_modelo, modelo in modelos.items():
    # Llamar a la función optimize() en el modelo actual
    solucion = modelo.optimize()
    
    # Calcular la biomasa a partir del valor objetivo del resultado de la optimización
    biomasa = solucion.objective_value
    
    # Almacenar la biomasa en el diccionario
    biomassas[nombre_modelo] = biomasa
    
    # Imprimir la biomasa calculada, si lo deseas
    print("Biomasa para el modelo", nombre_modelo, ":", biomasa)
# Out:
# Biomasa para el modelo IGTModel_IGT_GSM5009231_DP005 : 161.54446328806753
# Biomasa para el modelo IGTModel_IGT_GSM5009232_DP007 : 118.67326269922312
# Biomasa para el modelo IGTModel_IGT_GSM5009233_DP008 : 118.94917936805724
# Biomasa para el modelo IGTModel_IGT_GSM5009237_DP013 : 137.09129600620608
# Biomasa para el modelo IGTModel_IGT_GSM5009241_DP025 : 121.30173059885159
# Biomasa para el modelo IGTModel_IGT_GSM5009249_DP048 : 122.01828090618656
# Biomasa para el modelo IGTModel_IGT_GSM5009251_DP051 : 186.4228528091395
# Biomasa para el modelo IGTModel_IGT_GSM5009258_DP059 : 138.08990565876346
# Biomasa para el modelo IGTModel_IGT_GSM5009260_DP063 : 118.60613658554377
# Biomasa para el modelo IGTModel_IGT_GSM5009264_DP067 : 187.97611262632475
# Biomasa para el modelo IGTModel_IGT_GSM5009265_DP068 : 137.37100327449645
# Biomasa para el modelo IGTModel_IGT_GSM5009268_DP071 : 137.5969519488921
# Biomasa para el modelo IGTModel_IGT_GSM5009273_DP076 : 186.4477879883071
# Biomasa para el modelo IGTModel_IGT_GSM5009277_DP081 : 193.5807681636552
# Biomasa para el modelo IGTModel_IGT_GSM5009278_DP082 : 134.0720971485212
# Biomasa para el modelo IGTModel_IGT_GSM5009282_DP088 : 210.09892184505958
# Biomasa para el modelo IGTModel_IGT_GSM5009285_DP093 : 137.29491099595563
# Biomasa para el modelo IGTModel_IGT_GSM5009296_DP108 : 138.02050480953272
# Biomasa para el modelo IGTModel_IGT_GSM5009298_DP110 : 136.91239881395717
# Biomasa para el modelo IGTModel_IGT_GSM5009302_DP116 : 226.65874699418123
# Biomasa para el modelo IGTModel_IGT_GSM5009307_DP123 : 194.16898562416517
# Biomasa para el modelo IGTModel_IGT_GSM5009313_DP137 : 193.8552912898685
# Biomasa para el modelo IGTModel_IGT_GSM5009314_DP138 : 138.08990565876348
# Biomasa para el modelo IGTModel_IGT_GSM5009316_DP140 : 138.89106645229
# Biomasa para el modelo IGTModel_IGT_GSM5009318_DP144 : 154.99272874103443
# Biomasa para el modelo IGTModel_IGT_GSM5009319_DP145 : 140.34093708932122
# Biomasa para el modelo IGTModel_IGT_GSM5009323_DP151 : 165.99005867788472
# Biomasa para el modelo IGTModel_IGT_GSM5009341_DP184 : 149.6054677385836
# Biomasa para el modelo IGTModel_IGT_GSM5009343_DP186 : 140.17088869200623
# Biomasa para el modelo IGTModel_IGT_GSM5009345_DP190 : 182.80001339816567
# Biomasa para el modelo IGTModel_IGT_GSM5009349_DP195 : 163.62295039160807
# Biomasa para el modelo IGTModel_IGT_GSM5009351_DP204 : 136.57655714602615
# Biomasa para el modelo IGTModel_IGT_GSM5009352_DP206 : 143.60949470699993
# Biomasa para el modelo IGTModel_IGT_GSM5009353_DP207 : 156.30024935117748
# Biomasa para el modelo IGTModel_IGT_GSM5009355_DP209 : 137.31279379485747
# Biomasa para el modelo IGTModel_IGT_GSM5009356_DP216 : 205.5554123636819
# Biomasa para el modelo IGTModel_IGT_GSM5009357_DP224 : 140.1708886920063
# Biomasa para el modelo IGTModel_IGT_GSM5009358_DP229 : 203.50487657514702
# Biomasa para el modelo IGTModel_IGT_GSM5009359_DP235 : 130.65880209911944
# Biomasa para el modelo IGTModel_IGT_GSM5009360_DP237 : 140.129912323075
# Biomasa para el modelo IGTModel_IGT_GSM5009361_DP248 : 167.1536460411255
# Biomasa para el modelo NDModel_ND_GSM5009234_DP010 : 143.8075131818017
# Biomasa para el modelo NDModel_ND_GSM5009235_DP011 : 138.3719605850724
# Biomasa para el modelo NDModel_ND_GSM5009236_DP012 : 164.43027427390038
# Biomasa para el modelo NDModel_ND_GSM5009239_DP019 : 133.62634504146413
# Biomasa para el modelo NDModel_ND_GSM5009240_DP021 : 186.3421297567008
# Biomasa para el modelo NDModel_ND_GSM5009252_DP052 : 211.44575493043698
# Biomasa para el modelo NDModel_ND_GSM5009254_DP054 : 181.7199533089579
# Biomasa para el modelo NDModel_ND_GSM5009261_DP064 : 192.4375416110308
# Biomasa para el modelo NDModel_ND_GSM5009266_DP069 : 137.97232207044706
# Biomasa para el modelo NDModel_ND_GSM5009275_DP079 : 122.20026193662086
# Biomasa para el modelo NDModel_ND_GSM5009280_DP086 : 172.31986226795843
# Biomasa para el modelo NDModel_ND_GSM5009286_DP095 : 155.0121698562805
# Biomasa para el modelo NDModel_ND_GSM5009309_DP125 : 186.4228528091397
# Biomasa para el modelo NDModel_ND_GSM5009312_DP132 : 186.4228528091395
# Biomasa para el modelo NDModel_ND_GSM5009320_DP146 : 141.0740150889657
# Biomasa para el modelo NDModel_ND_GSM5009321_DP147 : 147.9540567535015
# Biomasa para el modelo NDModel_ND_GSM5009334_DP173 : 139.6166260898597
# Biomasa para el modelo NDModel_ND_GSM5009340_DP181 : 118.60613658554378
# Biomasa para el modelo T2DModel_T2D_GSM5009230_DP003 : 138.12914698231523
# Biomasa para el modelo T2DModel_T2D_GSM5009243_DP030 : 145.8329711139398
# Biomasa para el modelo T2DModel_T2D_GSM5009244_DP034 : 124.03240433925315
# Biomasa para el modelo T2DModel_T2D_GSM5009247_DP042 : 118.56142865400581
# Biomasa para el modelo T2DModel_T2D_GSM5009250_DP049 : 137.42925879429023
# Biomasa para el modelo T2DModel_T2D_GSM5009255_DP055 : 138.08990565876346
# Biomasa para el modelo T2DModel_T2D_GSM5009257_DP058 : 140.91119448904755
# Biomasa para el modelo T2DModel_T2D_GSM5009267_DP070 : 150.72256955274509
# Biomasa para el modelo T2DModel_T2D_GSM5009279_DP083 : 188.2130656129533
# Biomasa para el modelo T2DModel_T2D_GSM5009281_DP087 : 170.50762425653798
# Biomasa para el modelo T2DModel_T2D_GSM5009288_DP097 : 136.02242577835491
# Biomasa para el modelo T2DModel_T2D_GSM5009289_DP099 : 139.27862794563953
# Biomasa para el modelo T2DModel_T2D_GSM5009290_DP102 : 192.42345013585123
# Biomasa para el modelo T2DModel_T2D_GSM5009291_DP103 : 186.34212975670073
# Biomasa para el modelo T2DModel_T2D_GSM5009292_DP104 : 118.60613658554377
# Biomasa para el modelo T2DModel_T2D_GSM5009293_DP105 : 136.30074643758283
# Biomasa para el modelo T2DModel_T2D_GSM5009295_DP107 : 97.01822725093562
# Biomasa para el modelo T2DModel_T2D_GSM5009297_DP109 : 186.42285280913947
# Biomasa para el modelo T2DModel_T2D_GSM5009299_DP111 : 203.8097727023904
# Biomasa para el modelo T2DModel_T2D_GSM5009304_DP118 : 139.62803754249992
# Biomasa para el modelo T2DModel_T2D_GSM5009306_DP122 : 140.28715082548896
# Biomasa para el modelo T2DModel_T2D_GSM5009308_DP124 : 160.03851527481746
# Biomasa para el modelo T2DModel_T2D_GSM5009310_DP126 : 186.5286026284345
# Biomasa para el modelo T2DModel_T2D_GSM5009311_DP129 : 219.93509058240502
# Biomasa para el modelo T2DModel_T2D_GSM5009315_DP139 : 225.34404563126776
# Biomasa para el modelo T2DModel_T2D_GSM5009317_DP143 : 220.39952535635996
# Biomasa para el modelo T2DModel_T2D_GSM5009322_DP150 : 187.33431851282447
# Biomasa para el modelo T2DModel_T2D_GSM5009325_DP157 : 193.85335594568116
# Biomasa para el modelo T2DModel_T2D_GSM5009327_DP161 : 146.1933736844618
# Biomasa para el modelo T2DModel_T2D_GSM5009329_DP163 : 180.93041569674986
# Biomasa para el modelo T2DModel_T2D_GSM5009330_DP166 : 187.767564878164
# Biomasa para el modelo T2DModel_T2D_GSM5009337_DP177 : 228.78139754812676
# Biomasa para el modelo T2DModel_T2D_GSM5009338_DP179 : 138.0899056587635
# Biomasa para el modelo T2DModel_T2D_GSM5009342_DP185 : 218.90627323598875
# Biomasa para el modelo T2DModel_T2D_GSM5009344_DP187 : 221.70149606400796
# Biomasa para el modelo T2DModel_T2D_GSM5009346_DP192 : 140.12991232307502
# Biomasa para el modelo T2DModel_T2D_GSM5009347_DP193 : 187.94260432660525
# Biomasa para el modelo T2DModel_T2D_GSM5009348_DP194 : 132.43498400788192
# Biomasa para el modelo T2DModel_T2D_GSM5009350_DP197 : 175.71110216049303
# Biomasa para el modelo T3cDModel_T3cD_GSM5009229_DP002 : 141.35140537705914
# Biomasa para el modelo T3cDModel_T3cD_GSM5009238_DP017 : 186.42285280913944
# Biomasa para el modelo T3cDModel_T3cD_GSM5009242_DP028 : 218.6547768569694
# Biomasa para el modelo T3cDModel_T3cD_GSM5009245_DP039 : 137.37100327449647
# Biomasa para el modelo T3cDModel_T3cD_GSM5009246_DP040 : 138.71568138103584
# Biomasa para el modelo T3cDModel_T3cD_GSM5009248_DP043 : 138.08990565876346
# Biomasa para el modelo T3cDModel_T3cD_GSM5009253_DP053 : 155.2905877184495
# Biomasa para el modelo T3cDModel_T3cD_GSM5009256_DP057 : 138.03980424677005
# Biomasa para el modelo T3cDModel_T3cD_GSM5009259_DP061 : 145.52092180971692
# Biomasa para el modelo T3cDModel_T3cD_GSM5009262_DP065 : 137.3127937948575
# Biomasa para el modelo T3cDModel_T3cD_GSM5009263_DP066 : 193.58076816365522
# Biomasa para el modelo T3cDModel_T3cD_GSM5009269_DP072 : 201.67591288332974
# Biomasa para el modelo T3cDModel_T3cD_GSM5009270_DP073 : 137.28036181901714
# Biomasa para el modelo T3cDModel_T3cD_GSM5009271_DP074 : 137.8603795377425
# Biomasa para el modelo T3cDModel_T3cD_GSM5009272_DP075 : 138.88316890469682
# Biomasa para el modelo T3cDModel_T3cD_GSM5009274_DP077 : 165.6761504309183
# Biomasa para el modelo T3cDModel_T3cD_GSM5009276_DP080 : 243.67168617582328
# Biomasa para el modelo T3cDModel_T3cD_GSM5009283_DP089 : 139.75724507693428
# Biomasa para el modelo T3cDModel_T3cD_GSM5009284_DP090 : 219.57006998610518
# Biomasa para el modelo T3cDModel_T3cD_GSM5009287_DP096 : 135.5480752260517
# Biomasa para el modelo T3cDModel_T3cD_GSM5009294_DP106 : 186.34212975670084
# Biomasa para el modelo T3cDModel_T3cD_GSM5009300_DP112 : 132.222773238434
# Biomasa para el modelo T3cDModel_T3cD_GSM5009301_DP114 : 219.85084703520826
# Biomasa para el modelo T3cDModel_T3cD_GSM5009303_DP117 : 135.5348041703563
# Biomasa para el modelo T3cDModel_T3cD_GSM5009305_DP120 : 179.80685284244868
# Biomasa para el modelo T3cDModel_T3cD_GSM5009324_DP152 : 136.47702352539295
# Biomasa para el modelo T3cDModel_T3cD_GSM5009326_DP160 : 147.091431294761
# Biomasa para el modelo T3cDModel_T3cD_GSM5009328_DP162 : 209.8331076237506
# Biomasa para el modelo T3cDModel_T3cD_GSM5009331_DP167 : 159.09765180891236
# Biomasa para el modelo T3cDModel_T3cD_GSM5009332_DP169 : 139.8305347216891
# Biomasa para el modelo T3cDModel_T3cD_GSM5009333_DP170 : 133.66925257734283
# Biomasa para el modelo T3cDModel_T3cD_GSM5009335_DP174 : 119.0208433568219
# Biomasa para el modelo T3cDModel_T3cD_GSM5009336_DP176 : 206.1300067034285
# Biomasa para el modelo T3cDModel_T3cD_GSM5009339_DP180 : 139.02205254050864
# Biomasa para el modelo T3cDModel_T3cD_GSM5009354_DP208 : 136.38464735919518

# %%
df_biomassas = pd.DataFrame(list(biomassas.items()), columns=['Modelo', 'Biomasa'])
print(df_biomassas)
# Out:
#                               Modelo     Biomasa
# 0      IGTModel_IGT_GSM5009231_DP005  161.544463
# 1      IGTModel_IGT_GSM5009232_DP007  118.673263
# 2      IGTModel_IGT_GSM5009233_DP008  118.949179
# 3      IGTModel_IGT_GSM5009237_DP013  137.091296
# 4      IGTModel_IGT_GSM5009241_DP025  121.301731
# ..                               ...         ...
# 128  T3cDModel_T3cD_GSM5009333_DP170  133.669253
# 129  T3cDModel_T3cD_GSM5009335_DP174  119.020843
# 130  T3cDModel_T3cD_GSM5009336_DP176  206.130007
# 131  T3cDModel_T3cD_GSM5009339_DP180  139.022053
# 132  T3cDModel_T3cD_GSM5009354_DP208  136.384647
#
# [133 rows x 2 columns]

# %%
IGT_biomassa = {}
ND_biomassa = {}
T2D_biomassa = {}
T3cD_biomassa = {}

# Loop sobre el DataFrame de biomassas
for index, row in df_biomassas.iterrows():
    nombre_modelo = row['Modelo']
    biomasa = row['Biomasa']
    
    # Determinar el grupo al que pertenece el modelo
    if nombre_modelo.startswith('IGT'):
        IGT_biomassa[nombre_modelo] = biomasa
    elif nombre_modelo.startswith('ND'):
        ND_biomassa[nombre_modelo] = biomasa
    elif nombre_modelo.startswith('T2D'):
        T2D_biomassa[nombre_modelo] = biomasa
    elif nombre_modelo.startswith('T3cD'):
        T3cD_biomassa[nombre_modelo] = biomasa

# Imprimir los nombres de los modelos en cada grupo
print("IGT Models:", list(IGT_biomassa.keys()))
print("ND Models:", list(ND_biomassa.keys()))
print("T2D Models:", list(T2D_biomassa.keys()))
print("T3cD Models:", list(T3cD_biomassa.keys()))
# Out:
# IGT Models: ['IGTModel_IGT_GSM5009231_DP005', 'IGTModel_IGT_GSM5009232_DP007', 'IGTModel_IGT_GSM5009233_DP008', 'IGTModel_IGT_GSM5009237_DP013', 'IGTModel_IGT_GSM5009241_DP025', 'IGTModel_IGT_GSM5009249_DP048', 'IGTModel_IGT_GSM5009251_DP051', 'IGTModel_IGT_GSM5009258_DP059', 'IGTModel_IGT_GSM5009260_DP063', 'IGTModel_IGT_GSM5009264_DP067', 'IGTModel_IGT_GSM5009265_DP068', 'IGTModel_IGT_GSM5009268_DP071', 'IGTModel_IGT_GSM5009273_DP076', 'IGTModel_IGT_GSM5009277_DP081', 'IGTModel_IGT_GSM5009278_DP082', 'IGTModel_IGT_GSM5009282_DP088', 'IGTModel_IGT_GSM5009285_DP093', 'IGTModel_IGT_GSM5009296_DP108', 'IGTModel_IGT_GSM5009298_DP110', 'IGTModel_IGT_GSM5009302_DP116', 'IGTModel_IGT_GSM5009307_DP123', 'IGTModel_IGT_GSM5009313_DP137', 'IGTModel_IGT_GSM5009314_DP138', 'IGTModel_IGT_GSM5009316_DP140', 'IGTModel_IGT_GSM5009318_DP144', 'IGTModel_IGT_GSM5009319_DP145', 'IGTModel_IGT_GSM5009323_DP151', 'IGTModel_IGT_GSM5009341_DP184', 'IGTModel_IGT_GSM5009343_DP186', 'IGTModel_IGT_GSM5009345_DP190', 'IGTModel_IGT_GSM5009349_DP195', 'IGTModel_IGT_GSM5009351_DP204', 'IGTModel_IGT_GSM5009352_DP206', 'IGTModel_IGT_GSM5009353_DP207', 'IGTModel_IGT_GSM5009355_DP209', 'IGTModel_IGT_GSM5009356_DP216', 'IGTModel_IGT_GSM5009357_DP224', 'IGTModel_IGT_GSM5009358_DP229', 'IGTModel_IGT_GSM5009359_DP235', 'IGTModel_IGT_GSM5009360_DP237', 'IGTModel_IGT_GSM5009361_DP248']
# ND Models: ['NDModel_ND_GSM5009234_DP010', 'NDModel_ND_GSM5009235_DP011', 'NDModel_ND_GSM5009236_DP012', 'NDModel_ND_GSM5009239_DP019', 'NDModel_ND_GSM5009240_DP021', 'NDModel_ND_GSM5009252_DP052', 'NDModel_ND_GSM5009254_DP054', 'NDModel_ND_GSM5009261_DP064', 'NDModel_ND_GSM5009266_DP069', 'NDModel_ND_GSM5009275_DP079', 'NDModel_ND_GSM5009280_DP086', 'NDModel_ND_GSM5009286_DP095', 'NDModel_ND_GSM5009309_DP125', 'NDModel_ND_GSM5009312_DP132', 'NDModel_ND_GSM5009320_DP146', 'NDModel_ND_GSM5009321_DP147', 'NDModel_ND_GSM5009334_DP173', 'NDModel_ND_GSM5009340_DP181']
# T2D Models: ['T2DModel_T2D_GSM5009230_DP003', 'T2DModel_T2D_GSM5009243_DP030', 'T2DModel_T2D_GSM5009244_DP034', 'T2DModel_T2D_GSM5009247_DP042', 'T2DModel_T2D_GSM5009250_DP049', 'T2DModel_T2D_GSM5009255_DP055', 'T2DModel_T2D_GSM5009257_DP058', 'T2DModel_T2D_GSM5009267_DP070', 'T2DModel_T2D_GSM5009279_DP083', 'T2DModel_T2D_GSM5009281_DP087', 'T2DModel_T2D_GSM5009288_DP097', 'T2DModel_T2D_GSM5009289_DP099', 'T2DModel_T2D_GSM5009290_DP102', 'T2DModel_T2D_GSM5009291_DP103', 'T2DModel_T2D_GSM5009292_DP104', 'T2DModel_T2D_GSM5009293_DP105', 'T2DModel_T2D_GSM5009295_DP107', 'T2DModel_T2D_GSM5009297_DP109', 'T2DModel_T2D_GSM5009299_DP111', 'T2DModel_T2D_GSM5009304_DP118', 'T2DModel_T2D_GSM5009306_DP122', 'T2DModel_T2D_GSM5009308_DP124', 'T2DModel_T2D_GSM5009310_DP126', 'T2DModel_T2D_GSM5009311_DP129', 'T2DModel_T2D_GSM5009315_DP139', 'T2DModel_T2D_GSM5009317_DP143', 'T2DModel_T2D_GSM5009322_DP150', 'T2DModel_T2D_GSM5009325_DP157', 'T2DModel_T2D_GSM5009327_DP161', 'T2DModel_T2D_GSM5009329_DP163', 'T2DModel_T2D_GSM5009330_DP166', 'T2DModel_T2D_GSM5009337_DP177', 'T2DModel_T2D_GSM5009338_DP179', 'T2DModel_T2D_GSM5009342_DP185', 'T2DModel_T2D_GSM5009344_DP187', 'T2DModel_T2D_GSM5009346_DP192', 'T2DModel_T2D_GSM5009347_DP193', 'T2DModel_T2D_GSM5009348_DP194', 'T2DModel_T2D_GSM5009350_DP197']
# T3cD Models: ['T3cDModel_T3cD_GSM5009229_DP002', 'T3cDModel_T3cD_GSM5009238_DP017', 'T3cDModel_T3cD_GSM5009242_DP028', 'T3cDModel_T3cD_GSM5009245_DP039', 'T3cDModel_T3cD_GSM5009246_DP040', 'T3cDModel_T3cD_GSM5009248_DP043', 'T3cDModel_T3cD_GSM5009253_DP053', 'T3cDModel_T3cD_GSM5009256_DP057', 'T3cDModel_T3cD_GSM5009259_DP061', 'T3cDModel_T3cD_GSM5009262_DP065', 'T3cDModel_T3cD_GSM5009263_DP066', 'T3cDModel_T3cD_GSM5009269_DP072', 'T3cDModel_T3cD_GSM5009270_DP073', 'T3cDModel_T3cD_GSM5009271_DP074', 'T3cDModel_T3cD_GSM5009272_DP075', 'T3cDModel_T3cD_GSM5009274_DP077', 'T3cDModel_T3cD_GSM5009276_DP080', 'T3cDModel_T3cD_GSM5009283_DP089', 'T3cDModel_T3cD_GSM5009284_DP090', 'T3cDModel_T3cD_GSM5009287_DP096', 'T3cDModel_T3cD_GSM5009294_DP106', 'T3cDModel_T3cD_GSM5009300_DP112', 'T3cDModel_T3cD_GSM5009301_DP114', 'T3cDModel_T3cD_GSM5009303_DP117', 'T3cDModel_T3cD_GSM5009305_DP120', 'T3cDModel_T3cD_GSM5009324_DP152', 'T3cDModel_T3cD_GSM5009326_DP160', 'T3cDModel_T3cD_GSM5009328_DP162', 'T3cDModel_T3cD_GSM5009331_DP167', 'T3cDModel_T3cD_GSM5009332_DP169', 'T3cDModel_T3cD_GSM5009333_DP170', 'T3cDModel_T3cD_GSM5009335_DP174', 'T3cDModel_T3cD_GSM5009336_DP176', 'T3cDModel_T3cD_GSM5009339_DP180', 'T3cDModel_T3cD_GSM5009354_DP208']

# %%
# Definir los grupos de modelos y sus colores correspondientes
grupos = {'IGT': 'blue', 'ND': 'green', 'T2D': 'orange', 'T3cD': 'red'}

# Crear el histograma
plt.figure(figsize=(10, 6))
for grupo, color in grupos.items():
    # Filtrar los modelos por grupo
    modelos_grupo = df_biomassas[df_biomassas['Modelo'].str.startswith(grupo)]
    biomassas_grupo = modelos_grupo['Biomasa']
    # Tratar de rotar las etiquetas x para que sean más legibles
    plt.bar(modelos_grupo['Modelo'], biomassas_grupo, color=color, label=grupo)
plt.xlabel('Models')
plt.ylabel('Biomassa')
plt.title('Distribució de les Biomasses per Models agrupats')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Definir los grupos de modelos y sus colores correspondientes
grupos = {'IGT': 'blue', 'ND': 'green', 'T2D': 'orange', 'T3cD': 'red'}

# Crear el histograma
plt.figure(figsize=(10, 6))
for grupo, color in grupos.items():
    # Filtrar los modelos por grupo
    modelos_grupo = df_biomassas[df_biomassas['Modelo'].str.startswith(grupo)]
    biomassas_grupo = modelos_grupo['Biomasa']
    # Tratar de rotar las etiquetas x para que sean más legibles
    plt.bar(modelos_grupo.index, biomassas_grupo, color=color, label=grupo)
plt.xlabel('Models')
plt.ylabel('Biomassa')
plt.title('Distribució de les Biomasses per Models agruapats')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Crear el boxplot
plt.figure(figsize=(10, 6))
bp = plt.boxplot([list(IGT_biomassa.values()), list(ND_biomassa.values()), list(T2D_biomassa.values()), list(T3cD_biomassa.values())], labels=['IGT', 'ND', 'T2D', 'T3cD'], patch_artist=True)
colors = ['lightblue', 'lightgreen', 'lightgrey', 'lightyellow']

# Dar color a las cajas
for box, color in zip(bp['boxes'], colors):
    box.set_facecolor(color)
    box.set_alpha(0.7)

# Dar color a las rallas de mediana
for median in bp['medians']:
    median.set(color='red', linewidth=2)

# Poner el valor de las medianas
for i, median in enumerate(bp['medians']):
    plt.text(i + 1, median.get_ydata()[0], f'{median.get_ydata()[0]:.2f}', horizontalalignment='center', verticalalignment='bottom', fontsize=10, color='red')

plt.title('Boxplot de les Biomasses en les 4 Condicions')
plt.xlabel('Condicions')
plt.ylabel('Biomassa')
plt.grid(True)
plt.show()

# %%
from scipy.stats import f_oneway

# Calcular el estadístico F y el valor p
f_statistic, p_value = f_oneway(list(IGT_biomassa.values()), list(ND_biomassa.values()), list(T2D_biomassa.values()), list(T3cD_biomassa.values()))

# Imprimir los resultados
print("Estadístico F:", f_statistic)
print("Valor p:", p_value)

# Interpretar los resultados
if p_value < 0.05:
    print("Hay diferencias significativas entre al menos dos grupos.")
else:
    print("No hay diferencias significativas entre los grupos.")
# Out:
# Estadístico F: 0.7749875029809908
# Valor p: 0.5100066384667519
# No hay diferencias significativas entre los grupos.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Combinar todas las listas de biomasa en una sola lista
all_biomass = list(IGT_biomassa.values()) + list(ND_biomassa.values()) + list(T2D_biomassa.values()) + list(T3cD_biomassa.values())

# Etiquetas de grupo para cada valor de biomasa
group_labels = ['IGT'] * len(list(IGT_biomassa.values())) + ['ND'] * len(list(ND_biomassa.values())) + ['T2D'] * len(list(T2D_biomassa.values())) + ['T3cD'] * len(list(T3cD_biomassa.values()))

# Realizar el análisis de Tukey
tukey_results = pairwise_tukeyhsd(all_biomass, group_labels)

# Mostrar los resultados
print(tukey_results)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#    IGT     ND   3.4566 0.9807 -20.0085 26.9217  False
#    IGT    T2D  10.7488 0.4362  -7.8141 29.3117  False
#    IGT   T3cD   5.4537 0.8794  -13.645 24.5525  False
#     ND    T2D   7.2922 0.8531 -16.3557 30.9402  False
#     ND   T3cD   1.9971 0.9964 -22.0738  26.068  False
#    T2D   T3cD  -5.2951 0.8917 -24.6181 14.0279  False
# -----------------------------------------------------

# %%
from scipy.stats import f_oneway

# Realizar la prueba de ANOVA para cada par de grupos
f_statistic_IGT_ND, p_value_IGT_ND = f_oneway(list(IGT_biomassa.values()), list(ND_biomassa.values()))
f_statistic_IGT_T2D, p_value_IGT_T2D = f_oneway(list(IGT_biomassa.values()), list(T2D_biomassa.values()))
f_statistic_IGT_T3cD, p_value_IGT_T3cD = f_oneway(list(IGT_biomassa.values()), list(T3cD_biomassa.values()))

f_statistic_ND_T2D, p_value_ND_T2D = f_oneway(list(ND_biomassa.values()), list(T2D_biomassa.values()))
f_statistic_ND_T3cD, p_value_ND_T3cD = f_oneway(list(ND_biomassa.values()), list(T3cD_biomassa.values()))

f_statistic_T2D_T3cD, p_value_T2D_T3cD = f_oneway(list(T2D_biomassa.values()), list(T3cD_biomassa.values()))

# Número total de comparaciones
num_comparisons = 4

# Aplicar corrección de Bonferroni
alpha = 0.05
p_value_IGT_ND_corrected = p_value_IGT_ND * num_comparisons  # Número total de comparaciones
p_value_IGT_T2D_corrected = p_value_IGT_T2D * num_comparisons
p_value_IGT_T3cD_corrected = p_value_IGT_T3cD * num_comparisons
p_value_ND_T2D_corrected = p_value_ND_T2D * num_comparisons
p_value_ND_T3cD_corrected = p_value_ND_T3cD * num_comparisons
p_value_T2D_T3cD_corrected = p_value_T2D_T3cD * num_comparisons


# Imprimir los resultados ajustados
print("IGT vs ND - p-valor corregido:", p_value_IGT_ND_corrected)
print("IGT vs T2D - p-valor corregido:", p_value_IGT_T2D_corrected)
print("IGT vs T3cD - p-valor corregido:", p_value_IGT_T3cD_corrected)
print("ND vs T2D - p-valor corregido:", p_value_ND_T2D_corrected)
print("ND vs T3cD - p-valor corregido:", p_value_ND_T3cD_corrected)
print("T2D vs T3cD - p-valor corregido:", p_value_T2D_T3cD_corrected)
# Out:
# IGT vs ND - p-valor corregido: 2.6717638053307446
# IGT vs T2D - p-valor corregido: 0.5553854683924434
# IGT vs T3cD - p-valor corregido: 1.7942145721390093
# ND vs T2D - p-valor corregido: 1.7602027157104319
# ND vs T3cD - p-valor corregido: 3.3113015769637975
# T2D vs T3cD - p-valor corregido: 2.0438962072588422

# %%
fluxes_df = pd.DataFrame(index=[nombre_modelo for nombre_modelo in modelos])

for i, (nombre_modelo, solucion) in enumerate(resultados.items(), start=0):
    fluxes = solucion.fluxes
    
    for reaccion, flujo in fluxes.items():
        if reaccion not in fluxes_df.columns:
            fluxes_df[reaccion] = 0.0
        
        fluxes_df.at[nombre_modelo, reaccion] = flujo

fluxes_df.head()
# Out:
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# ...
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
# C:\Users\NOE\AppData\Local\Temp\ipykernel_9728\3764325649.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fluxes_df[reaccion] = 0.0
#                                10FTHFtm  13DAMPPOX  2HBO     2OXOADOXm  \
# IGTModel_IGT_GSM5009231_DP005       0.0        0.0   0.0  0.000000e+00
# IGTModel_IGT_GSM5009232_DP007       0.0        0.0   0.0  0.000000e+00
# IGTModel_IGT_GSM5009233_DP008       0.0        0.0   0.0  0.000000e+00
# IGTModel_IGT_GSM5009237_DP013       0.0        0.0   0.0 -6.310286e-30
# IGTModel_IGT_GSM5009241_DP025       0.0        0.0   0.0  0.000000e+00
#
#                                34DHOXPEGOX  34DHOXPEGt  34DHPHAMT  \
# IGTModel_IGT_GSM5009231_DP005          0.0         0.0        0.0
# IGTModel_IGT_GSM5009232_DP007          0.0         0.0        0.0
# IGTModel_IGT_GSM5009233_DP008          0.0         0.0        0.0
# IGTModel_IGT_GSM5009237_DP013          0.0         0.0        0.0
# IGTModel_IGT_GSM5009241_DP025          0.0         0.0        0.0
#
#                                34DHPLACOX_NADP_  34DHXMANDACOX_NADP_  34HPLFM  \
# IGTModel_IGT_GSM5009231_DP005               0.0                  0.0      0.0
# IGTModel_IGT_GSM5009232_DP007               0.0                  0.0      0.0
# IGTModel_IGT_GSM5009233_DP008               0.0                  0.0      0.0
# IGTModel_IGT_GSM5009237_DP013               0.0                  0.0      0.0
# IGTModel_IGT_GSM5009241_DP025               0.0                  0.0    750.0
#
#                                ...  SERATB0tc  TRPATB0tc  VALATB0tc  HSD3B12r  \
# IGTModel_IGT_GSM5009231_DP005  ...        0.0        0.0        0.0       0.0
# IGTModel_IGT_GSM5009232_DP007  ...        0.0        0.0        0.0       0.0
# IGTModel_IGT_GSM5009233_DP008  ...        0.0        0.0        0.0       0.0
# IGTModel_IGT_GSM5009237_DP013  ...        0.0        0.0        0.0       0.0
# IGTModel_IGT_GSM5009241_DP025  ...        0.0        0.0        0.0       0.0
#
#                                r0281  BTNt3ile  SPRMTDe  ANDRSTANDRte  \
# IGTModel_IGT_GSM5009231_DP005    0.0       0.0      0.0           0.0
# IGTModel_IGT_GSM5009232_DP007    0.0       0.0      0.0           0.0
# IGTModel_IGT_GSM5009233_DP008    0.0       0.0      0.0           0.0
# IGTModel_IGT_GSM5009237_DP013    0.0       0.0      0.0           0.0
# IGTModel_IGT_GSM5009241_DP025    0.0       0.0      0.0           0.0
#
#                                EX_andrstandn[e]  HMR_9638
# IGTModel_IGT_GSM5009231_DP005               0.0       0.0
# IGTModel_IGT_GSM5009232_DP007               0.0       0.0
# IGTModel_IGT_GSM5009233_DP008               0.0       0.0
# IGTModel_IGT_GSM5009237_DP013               0.0       0.0
# IGTModel_IGT_GSM5009241_DP025               0.0       0.0
#
# [5 rows x 6333 columns]

# %%
fluxes_df
# Out:
#                                  10FTHFtm  13DAMPPOX          2HBO  \
# IGTModel_IGT_GSM5009231_DP005         0.0        0.0  0.000000e+00
# IGTModel_IGT_GSM5009232_DP007         0.0        0.0  0.000000e+00
# IGTModel_IGT_GSM5009233_DP008         0.0        0.0  0.000000e+00
# IGTModel_IGT_GSM5009237_DP013         0.0        0.0  0.000000e+00
# IGTModel_IGT_GSM5009241_DP025         0.0        0.0  0.000000e+00
# ...                                   ...        ...           ...
# T3cDModel_T3cD_GSM5009333_DP170       0.0        0.0  2.702334e-14
# T3cDModel_T3cD_GSM5009335_DP174       0.0        0.0  0.000000e+00
# T3cDModel_T3cD_GSM5009336_DP176       0.0        0.0 -3.016254e-13
# T3cDModel_T3cD_GSM5009339_DP180       0.0        0.0  4.347081e+01
# T3cDModel_T3cD_GSM5009354_DP208       0.0        0.0 -6.532624e+02
#
#                                     2OXOADOXm  34DHOXPEGOX  34DHOXPEGt  \
# IGTModel_IGT_GSM5009231_DP005    0.000000e+00          0.0         0.0
# IGTModel_IGT_GSM5009232_DP007    0.000000e+00          0.0         0.0
# IGTModel_IGT_GSM5009233_DP008    0.000000e+00          0.0         0.0
# IGTModel_IGT_GSM5009237_DP013   -6.310286e-30          0.0         0.0
# IGTModel_IGT_GSM5009241_DP025    0.000000e+00          0.0         0.0
# ...                                       ...          ...         ...
# T3cDModel_T3cD_GSM5009333_DP170  0.000000e+00          0.0         0.0
# T3cDModel_T3cD_GSM5009335_DP174 -4.416764e-15          0.0         0.0
# T3cDModel_T3cD_GSM5009336_DP176 -6.281620e-14          0.0         0.0
# T3cDModel_T3cD_GSM5009339_DP180  0.000000e+00          0.0         0.0
# T3cDModel_T3cD_GSM5009354_DP208  0.000000e+00          0.0         0.0
#
#                                  34DHPHAMT  34DHPLACOX_NADP_  \
# IGTModel_IGT_GSM5009231_DP005          0.0               0.0
# IGTModel_IGT_GSM5009232_DP007          0.0               0.0
# IGTModel_IGT_GSM5009233_DP008          0.0               0.0
# IGTModel_IGT_GSM5009237_DP013          0.0               0.0
# IGTModel_IGT_GSM5009241_DP025          0.0               0.0
# ...                                    ...               ...
# T3cDModel_T3cD_GSM5009333_DP170        0.0               0.0
# T3cDModel_T3cD_GSM5009335_DP174        0.0               0.0
# T3cDModel_T3cD_GSM5009336_DP176        0.0               0.0
# T3cDModel_T3cD_GSM5009339_DP180        0.0               0.0
# T3cDModel_T3cD_GSM5009354_DP208        0.0               0.0
#
#                                  34DHXMANDACOX_NADP_     34HPLFM  ...  \
# IGTModel_IGT_GSM5009231_DP005                    0.0    0.000000  ...
# IGTModel_IGT_GSM5009232_DP007                    0.0    0.000000  ...
# IGTModel_IGT_GSM5009233_DP008                    0.0    0.000000  ...
# IGTModel_IGT_GSM5009237_DP013                    0.0    0.000000  ...
# IGTModel_IGT_GSM5009241_DP025                    0.0  750.000000  ...
# ...                                              ...         ...  ...
# T3cDModel_T3cD_GSM5009333_DP170                  0.0    0.000000  ...
# T3cDModel_T3cD_GSM5009335_DP174                  0.0    0.000000  ...
# T3cDModel_T3cD_GSM5009336_DP176                  0.0    0.000000  ...
# T3cDModel_T3cD_GSM5009339_DP180              -1000.0  606.547587  ...
# T3cDModel_T3cD_GSM5009354_DP208                  0.0    0.000000  ...
#
#                                  SERATB0tc  TRPATB0tc  VALATB0tc  HSD3B12r  \
# IGTModel_IGT_GSM5009231_DP005          0.0        0.0        0.0       0.0
# IGTModel_IGT_GSM5009232_DP007          0.0        0.0        0.0       0.0
# IGTModel_IGT_GSM5009233_DP008          0.0        0.0        0.0       0.0
# IGTModel_IGT_GSM5009237_DP013          0.0        0.0        0.0       0.0
# IGTModel_IGT_GSM5009241_DP025          0.0        0.0        0.0       0.0
# ...                                    ...        ...        ...       ...
# T3cDModel_T3cD_GSM5009333_DP170        0.0        0.0        0.0       0.0
# T3cDModel_T3cD_GSM5009335_DP174        0.0        0.0        0.0       0.0
# T3cDModel_T3cD_GSM5009336_DP176        0.0        0.0        0.0       0.0
# T3cDModel_T3cD_GSM5009339_DP180        0.0        0.0        0.0       0.0
# T3cDModel_T3cD_GSM5009354_DP208        0.0        0.0        0.0       0.0
#
#                                  r0281  BTNt3ile  SPRMTDe  ANDRSTANDRte  \
# IGTModel_IGT_GSM5009231_DP005      0.0       0.0      0.0           0.0
# IGTModel_IGT_GSM5009232_DP007      0.0       0.0      0.0           0.0
# IGTModel_IGT_GSM5009233_DP008      0.0       0.0      0.0           0.0
# IGTModel_IGT_GSM5009237_DP013      0.0       0.0      0.0           0.0
# IGTModel_IGT_GSM5009241_DP025      0.0       0.0      0.0           0.0
# ...                                ...       ...      ...           ...
# T3cDModel_T3cD_GSM5009333_DP170    0.0       0.0      0.0           0.0
# T3cDModel_T3cD_GSM5009335_DP174    0.0       0.0      0.0           0.0
# T3cDModel_T3cD_GSM5009336_DP176    0.0       0.0      0.0           0.0
# T3cDModel_T3cD_GSM5009339_DP180    0.0       0.0      0.0           0.0
# T3cDModel_T3cD_GSM5009354_DP208    0.0       0.0      0.0           0.0
#
#                                  EX_andrstandn[e]  HMR_9638
# IGTModel_IGT_GSM5009231_DP005                 0.0       0.0
# IGTModel_IGT_GSM5009232_DP007                 0.0       0.0
# IGTModel_IGT_GSM5009233_DP008                 0.0       0.0
# IGTModel_IGT_GSM5009237_DP013                 0.0       0.0
# IGTModel_IGT_GSM5009241_DP025                 0.0       0.0
# ...                                           ...       ...
# T3cDModel_T3cD_GSM5009333_DP170               0.0       0.0
# T3cDModel_T3cD_GSM5009335_DP174               0.0       0.0
# T3cDModel_T3cD_GSM5009336_DP176               0.0       0.0
# T3cDModel_T3cD_GSM5009339_DP180               0.0       0.0
# T3cDModel_T3cD_GSM5009354_DP208               0.0       0.0
#
# [133 rows x 6333 columns]

# %%
path_to_save = r'C:/Users/NOE/Desktop/TFG-Example/Islet data/RPKM data/DataFrame RPKM/dataframe_RPKM_fluxes.txt'

# Guardar el DataFrame en un archivo CSV
fluxes_df.to_csv(path_to_save, sep='\t')

print("DataFrame guardado exitosamente en:", path_to_save)
# Out:
# DataFrame guardado exitosamente en: C:/Users/NOE/Desktop/TFG-Example/Islet data/RPKM data/DataFrame RPKM/dataframe_RPKM_fluxes.txt
