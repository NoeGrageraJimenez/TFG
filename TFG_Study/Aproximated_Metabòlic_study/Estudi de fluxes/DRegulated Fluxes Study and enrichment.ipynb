# %%
import pandas as pd
import numpy as np

# %%
df_Cmodel = pd.read_csv(r'C:\Users\NOE\Desktop\TFG-Example\Islet data\Genes downregulated\Random Sampling 100\sample_Cmodel_100.csv')
df_Cmodel_T2D = pd.read_csv(r'C:\Users\NOE\Desktop\TFG-Example\Islet data\Genes downregulated\Random Sampling 100\sample_Cmodel_T2D_100.csv')
df_Cmodel_T3cD = pd.read_csv(r'C:\Users\NOE\Desktop\TFG-Example\Islet data\Genes downregulated\Random Sampling 100\sample_Cmodel_T3cD_100.csv')

# %%
print('El Cmodel:',df_Cmodel)
print('El Cmodel_T2D:',df_Cmodel_T2D)
print('El Cmodel_T3cD:',df_Cmodel_T3cD)
# Out:
# El Cmodel:     10FTHF5GLUtl  10FTHF5GLUtm  10FTHF6GLUtl  10FTHF6GLUtm  10FTHF7GLUtl  \
# 0       0.098460      0.057387      0.011941      0.011409      0.008584
# 1       0.106652      0.065579      0.011941      0.011410      0.009656
# 2       0.106086      0.065006      0.011944      0.011412      0.025566
# 3       0.108422      0.067047      0.011888      0.011356      0.025735
# 4       0.098349      0.061064      0.011888      0.011356      0.025803
# ..           ...           ...           ...           ...           ...
# 95      0.804612      0.350607      0.182401      0.170598      0.033232
# 96      0.831832      0.377536      0.162732      0.150925      0.033253
# 97      0.837712      0.382903      0.162258      0.150443      0.033291
# 98      1.026584      0.515360      0.227018      0.215223      0.047923
# 99      1.064360      0.553125      0.082674      0.070879      0.047924
#
#     10FTHF7GLUtm  10FTHFtl    10FTHFtm  11DOCRTSLtm  11DOCRTSLtr  ...  \
# 0       0.007472 -0.118984   10.073984     0.043644    -0.028545  ...
# 1       0.008544 -0.128249    9.984053     0.046221    -0.031595  ...
# 2       0.024455 -0.143596    9.848890     0.057623    -0.031496  ...
# 3       0.024624 -0.146045    9.779984     0.057970    -0.031491  ...
# 4       0.024692 -0.136041    9.509470     0.058194    -0.031491  ...
# ..           ...       ...         ...          ...          ...  ...
# 95      0.022964 -1.020244  261.328066     1.205687    -0.572257  ...
# 96      0.022980 -1.027817  261.640089     1.201227    -0.567598  ...
# 97      0.023009 -1.033262  258.404713     1.204061    -0.566387  ...
# 98      0.037664 -1.301525  263.648639     1.203675    -0.565950  ...
# 99      0.037664 -1.194957  263.091047     1.201344    -0.565953  ...
#
#      DM_btn[n]     DCMPtm  PROTEIN_BS  DM_PROTEIN     ATPS4mi  CYOR_u10mi  \
# 0   981.620658  -3.199046    4.178128    4.178128  999.864201  180.415922
# 1   981.826543  -3.093259    4.290990    4.290990  999.672514  180.221673
# 2   981.803378  -2.940641    4.228658    4.228658  999.661938  180.174825
# 3   981.621555  -3.087871    4.354171    4.354171  999.661522  180.195023
# 4   981.547682  -3.100824    4.273805    4.273805  999.663791  180.150037
# ..         ...        ...         ...         ...         ...         ...
# 95  565.593117  19.194070   65.892432   65.892432  998.288170  238.196721
# 96  564.937574  18.608634   66.093316   66.093316  998.289184  238.442315
# 97  574.974127  20.215297   69.334792   69.334792  998.275981  234.400419
# 98  569.934179  18.531262   68.960235   68.960235  997.529947  232.709976
# 99  569.120012  20.577569   68.249842   68.249842  997.673392  231.557003
#
#           Htmi  NADH2_u10mi     CYOOm3i    CYOOm2i
# 0   904.113195   106.515315  938.591869   0.369393
# 1   903.562586   106.501736  938.500948   0.338803
# 2   903.376802   106.563778  938.415551   0.351984
# 3   903.035945   106.571444  938.305903   0.348138
# 4   903.269540   106.662506  938.314682   0.353951
# ..         ...          ...         ...        ...
# 95  789.241635    79.911645  838.629448  38.860766
# 96  786.906228    80.557243  837.187109  38.829075
# 97  774.907931    80.093221  838.348824  39.160500
# 98  773.389739    79.340104  839.335457  39.491845
# 99  774.644519    79.441694  840.722765  39.613059
#
# [100 rows x 10600 columns]
# El Cmodel_T2D:     10FTHF5GLUtl  10FTHF5GLUtm  10FTHF6GLUtl  10FTHF6GLUtm  10FTHF7GLUtl  \
# 0       0.021564      0.015850      0.003779      0.003049      0.008576
# 1       0.022265      0.016552      0.002945      0.002215      0.009311
# 2       0.023355      0.017641      0.002944      0.002214      0.010408
# 3       0.023693      0.017661      0.002397      0.001986      0.012994
# 4       0.023693      0.017661      0.001996      0.001585      0.012553
# ..           ...           ...           ...           ...           ...
# 95      0.118107      0.056461      0.067343      0.041327      0.041871
# 96      0.114099      0.054213      0.066644      0.040634      0.041863
# 97      0.111205      0.051317      0.067746      0.041734      0.041359
# 98      0.091245      0.031371      0.065462      0.039461      0.037015
# 99      0.090757      0.031110      0.061641      0.035814      0.035361
#
#     10FTHF7GLUtm  10FTHFtl    10FTHFtm  11DOCRTSLtm  11DOCRTSLtr  ...  \
# 0       0.008019 -0.033918 -912.209557     0.010042    -0.006201  ...
# 1       0.008755 -0.034521 -911.989434     0.010571    -0.006730  ...
# 2       0.009851 -0.036707 -911.996043     0.010746    -0.006487  ...
# 3       0.012438 -0.039085 -912.097735     0.010746    -0.006487  ...
# 4       0.011997 -0.038243 -911.935869     0.010746    -0.006487  ...
# ..           ...       ...         ...          ...          ...  ...
# 95      0.040984 -0.227320 -843.796425     0.219169    -0.188371  ...
# 96      0.040976 -0.222606 -843.188734     0.219138    -0.188339  ...
# 97      0.040472 -0.220309 -844.093397     0.219147    -0.188348  ...
# 98      0.036129 -0.193722 -843.991964     0.237578    -0.195668  ...
# 99      0.034480 -0.187759 -842.368494     0.222353    -0.192551  ...
#
#      DM_btn[n]      DCMPtm  PROTEIN_BS  DM_PROTEIN     ATPS4mi  CYOR_u10mi  \
# 0   930.845139  845.088362   19.756543   19.756543  999.828304  377.732778
# 1   930.761048  845.147790   19.747152   19.747152  999.829333  377.724334
# 2   930.661742  845.134302   19.730055   19.730055  999.808384  377.709874
# 3   930.547113  845.198576   19.705499   19.705499  999.808381  377.739015
# 4   930.731711  845.238505   19.748417   19.748417  999.821952  377.761407
# ..         ...         ...         ...         ...         ...         ...
# 95  894.762176  817.061937   30.453507   30.453507  999.478924  369.865761
# 96  894.223885  816.495984   30.482001   30.482001  999.469093  369.964147
# 97  893.801879  815.882427   30.497465   30.497465  999.397810  369.957027
# 98  894.010923  815.341330   31.428594   31.428594  999.076771  369.175236
# 99  893.197687  807.882315   33.247905   33.247905  999.093733  370.111701
#
#           Htmi  NADH2_u10mi     CYOOm3i   CYOOm2i
# 0   966.497994     9.959750  851.113411  2.646864
# 1   966.428351     9.950544  851.119834  2.641709
# 2   966.463497    10.025449  851.048151  2.640785
# 3   966.479734    10.024107  851.029228  2.635966
# 4   966.389386    10.013464  851.017137  2.627290
# ..         ...          ...         ...       ...
# 95  909.130237    15.285038  839.269739  2.340946
# 96  908.756081    15.467178  838.884326  2.342463
# 97  908.622927    15.609704  838.678062  2.308748
# 98  908.355918    15.675809  838.972335  2.342371
# 99  901.368856    16.143016  835.899927  2.281304
#
# [100 rows x 10600 columns]
# El Cmodel_T3cD:     10FTHF5GLUtl  10FTHF5GLUtm  10FTHF6GLUtl  10FTHF6GLUtm  10FTHF7GLUtl  \
# 0       0.082654      0.061680      0.015893      0.015488      0.021715
# 1       0.097446      0.073422      0.015989      0.015584      0.021560
# 2       0.095517      0.072689      0.015990      0.015584      0.020429
# 3       0.090699      0.067871      0.015990      0.017477      0.020547
# 4       0.090697      0.067870      0.015376      0.016863      0.020546
# ..           ...           ...           ...           ...           ...
# 95      5.403203      2.017213      0.209691      0.235514      6.150625
# 96      5.401932      2.016150      0.209680      0.235503      6.145289
# 97      5.380967      1.995018      0.209689      0.235511      6.145477
# 98      5.001187      2.012211      0.184657      0.210479      6.145030
# 99      4.994450      2.001750      0.025261      0.051084      6.180011
#
#     10FTHF7GLUtm   10FTHFtl    10FTHFtm  11DOCRTSLtm  11DOCRTSLtr  ...  \
# 0       0.020834  -0.120263  -22.875848     0.049983    -0.022189  ...
# 1       0.020679  -0.134996  -22.062873     0.024906    -0.022255  ...
# 2       0.019548  -0.131936  -21.922604     0.029064    -0.022255  ...
# 3       0.017773  -0.127235  -14.218775     0.031191    -0.025243  ...
# 4       0.017773  -0.126619  -13.768364     0.035624    -0.025242  ...
# ..           ...        ...         ...          ...          ...  ...
# 95      6.122546 -11.763520  125.250054     1.197150    -0.151150  ...
# 96      6.117211 -11.756902  127.707383     1.197081    -0.151118  ...
# 97      6.117397 -11.736132  129.062359     1.197136    -0.151145  ...
# 98      6.116952 -11.330874  131.022057     1.296319    -0.151089  ...
# 99      6.151930 -11.199722  127.208416     1.287320    -0.151584  ...
#
#      DM_btn[n]      DCMPtm  PROTEIN_BS  DM_PROTEIN     ATPS4mi  CYOR_u10mi  \
# 0   115.906515  560.884651  135.251611  135.251611  999.804172  590.962523
# 1   116.217810  560.474408  134.585011  134.585011  999.818802  590.794781
# 2   115.927263  560.487955  134.831459  134.831459  999.815009  590.833681
# 3   106.632544  552.718089  134.842849  134.842849  999.805614  592.427631
# 4   106.794473  552.343471  134.763506  134.763506  999.809028  592.464243
# ..         ...         ...         ...         ...         ...         ...
# 95  493.710065 -116.714662  119.138767  119.138767  999.216373  298.648392
# 96  497.449221 -116.540416  119.791195  119.791195  999.388781  296.117782
# 97  498.405631 -112.408262  117.617590  117.617590  999.288118  295.212072
# 98  487.988317 -118.190959  120.859140  120.859140  999.162905  294.025731
# 99  488.392998 -115.216447  122.193551  122.193551  999.169793  291.429496
#
#           Htmi  NADH2_u10mi     CYOOm3i    CYOOm2i
# 0    76.168091    28.199673  395.091101   4.592898
# 1    77.108537    28.128438  395.574507   4.598210
# 2    76.918110    27.939711  395.680536   4.590609
# 3    73.199699    27.698912  393.849682   4.129314
# 4    73.067476    27.854077  393.645779   4.111797
# ..         ...          ...         ...        ...
# 95  484.307683    76.396774  732.664120  12.584008
# 96  484.841372    78.017917  733.590879  12.872545
# 97  486.185057    76.476994  736.185791  12.959526
# 98  483.593452    77.156667  736.145002  12.733868
# 99  479.104576    76.209228  738.507414  12.799798
#
# [100 rows x 10600 columns]

# %%
df_Cmodel.index = ['Cmodel_' + str(i) for i in range(1, len(df_Cmodel) + 1)]
df_Cmodel_T2D.index = ['Cmodel_T2D_' + str(i) for i in range(1, len(df_Cmodel_T2D) + 1)]
df_Cmodel_T3cD.index = ['Cmodel_T3cD_' + str(i) for i in range(1, len(df_Cmodel_T3cD) + 1)]
df_Cmodel_T3cD
# Out:
#                  10FTHF5GLUtl  10FTHF5GLUtm  10FTHF6GLUtl  10FTHF6GLUtm  \
# Cmodel_T3cD_1        0.082654      0.061680      0.015893      0.015488
# Cmodel_T3cD_2        0.097446      0.073422      0.015989      0.015584
# Cmodel_T3cD_3        0.095517      0.072689      0.015990      0.015584
# Cmodel_T3cD_4        0.090699      0.067871      0.015990      0.017477
# Cmodel_T3cD_5        0.090697      0.067870      0.015376      0.016863
# ...                       ...           ...           ...           ...
# Cmodel_T3cD_96       5.403203      2.017213      0.209691      0.235514
# Cmodel_T3cD_97       5.401932      2.016150      0.209680      0.235503
# Cmodel_T3cD_98       5.380967      1.995018      0.209689      0.235511
# Cmodel_T3cD_99       5.001187      2.012211      0.184657      0.210479
# Cmodel_T3cD_100      4.994450      2.001750      0.025261      0.051084
#
#                  10FTHF7GLUtl  10FTHF7GLUtm   10FTHFtl    10FTHFtm  \
# Cmodel_T3cD_1        0.021715      0.020834  -0.120263  -22.875848
# Cmodel_T3cD_2        0.021560      0.020679  -0.134996  -22.062873
# Cmodel_T3cD_3        0.020429      0.019548  -0.131936  -21.922604
# Cmodel_T3cD_4        0.020547      0.017773  -0.127235  -14.218775
# Cmodel_T3cD_5        0.020546      0.017773  -0.126619  -13.768364
# ...                       ...           ...        ...         ...
# Cmodel_T3cD_96       6.150625      6.122546 -11.763520  125.250054
# Cmodel_T3cD_97       6.145289      6.117211 -11.756902  127.707383
# Cmodel_T3cD_98       6.145477      6.117397 -11.736132  129.062359
# Cmodel_T3cD_99       6.145030      6.116952 -11.330874  131.022057
# Cmodel_T3cD_100      6.180011      6.151930 -11.199722  127.208416
#
#                  11DOCRTSLtm  11DOCRTSLtr  ...   DM_btn[n]      DCMPtm  \
# Cmodel_T3cD_1       0.049983    -0.022189  ...  115.906515  560.884651
# Cmodel_T3cD_2       0.024906    -0.022255  ...  116.217810  560.474408
# Cmodel_T3cD_3       0.029064    -0.022255  ...  115.927263  560.487955
# Cmodel_T3cD_4       0.031191    -0.025243  ...  106.632544  552.718089
# Cmodel_T3cD_5       0.035624    -0.025242  ...  106.794473  552.343471
# ...                      ...          ...  ...         ...         ...
# Cmodel_T3cD_96      1.197150    -0.151150  ...  493.710065 -116.714662
# Cmodel_T3cD_97      1.197081    -0.151118  ...  497.449221 -116.540416
# Cmodel_T3cD_98      1.197136    -0.151145  ...  498.405631 -112.408262
# Cmodel_T3cD_99      1.296319    -0.151089  ...  487.988317 -118.190959
# Cmodel_T3cD_100     1.287320    -0.151584  ...  488.392998 -115.216447
#
#                  PROTEIN_BS  DM_PROTEIN     ATPS4mi  CYOR_u10mi        Htmi  \
# Cmodel_T3cD_1    135.251611  135.251611  999.804172  590.962523   76.168091
# Cmodel_T3cD_2    134.585011  134.585011  999.818802  590.794781   77.108537
# Cmodel_T3cD_3    134.831459  134.831459  999.815009  590.833681   76.918110
# Cmodel_T3cD_4    134.842849  134.842849  999.805614  592.427631   73.199699
# Cmodel_T3cD_5    134.763506  134.763506  999.809028  592.464243   73.067476
# ...                     ...         ...         ...         ...         ...
# Cmodel_T3cD_96   119.138767  119.138767  999.216373  298.648392  484.307683
# Cmodel_T3cD_97   119.791195  119.791195  999.388781  296.117782  484.841372
# Cmodel_T3cD_98   117.617590  117.617590  999.288118  295.212072  486.185057
# Cmodel_T3cD_99   120.859140  120.859140  999.162905  294.025731  483.593452
# Cmodel_T3cD_100  122.193551  122.193551  999.169793  291.429496  479.104576
#
#                  NADH2_u10mi     CYOOm3i    CYOOm2i
# Cmodel_T3cD_1      28.199673  395.091101   4.592898
# Cmodel_T3cD_2      28.128438  395.574507   4.598210
# Cmodel_T3cD_3      27.939711  395.680536   4.590609
# Cmodel_T3cD_4      27.698912  393.849682   4.129314
# Cmodel_T3cD_5      27.854077  393.645779   4.111797
# ...                      ...         ...        ...
# Cmodel_T3cD_96     76.396774  732.664120  12.584008
# Cmodel_T3cD_97     78.017917  733.590879  12.872545
# Cmodel_T3cD_98     76.476994  736.185791  12.959526
# Cmodel_T3cD_99     77.156667  736.145002  12.733868
# Cmodel_T3cD_100    76.209228  738.507414  12.799798
#
# [100 rows x 10600 columns]

# %%
def flux_transformer(v):

    '''
    This function transforms fluxes into log2 scale with three additions:
    - zero values are kept.
    - values between 0 and 2 are adjusted to fit below one.
    - negative fluxes are considered. 
    '''

    def adjusted(v):
        new = (np.log2(v + 0.125) + 3) / 4
        return np.min([new, 1])

    if v == 0:
        vprime = 0
    elif v > 0:
        if v < 2:
            vprime = adjusted(v)
        else:
            vprime = np.log2(v)
    elif v < 0:
        v = np.abs(v)
        if v < 2:
            vprime = -adjusted(v)
        else:
            vprime = -np.log2(v)
    else:
        raise ValueError('found value not considered')

    return vprime

# %%
t_Cmodel=df_Cmodel.applymap(flux_transformer)
t_Cmodel_T2D= df_Cmodel_T2D.applymap(flux_transformer)
t_Cmodel_T3cD=df_Cmodel_T3cD.applymap(flux_transformer)
t_Cmodel_T3cD
# Out:
#                  10FTHF5GLUtl  10FTHF5GLUtm  10FTHF6GLUtl  10FTHF6GLUtm  \
# Cmodel_T3cD_1        0.183064      0.144659      0.043169      0.042129
# Cmodel_T3cD_2        0.207882      0.166661      0.043415      0.042376
# Cmodel_T3cD_3        0.204741      0.165326      0.043416      0.042377
# Cmodel_T3cD_4        0.196773      0.156427      0.043415      0.047199
# Cmodel_T3cD_5        0.196769      0.156424      0.041842      0.045643
# ...                       ...           ...           ...           ...
# Cmodel_T3cD_96       2.433815      1.012364      0.355226      0.382031
# Cmodel_T3cD_97       2.433476      1.011603      0.355214      0.382020
# Cmodel_T3cD_98       2.427865      1.000000      0.355223      0.382029
# Cmodel_T3cD_99       2.322271      1.008782      0.327186      0.356074
# Cmodel_T3cD_100      2.320326      1.001261      0.066386      0.123583
#
#                  10FTHF7GLUtl  10FTHF7GLUtm  10FTHFtl  10FTHFtm  11DOCRTSLtm  \
# Cmodel_T3cD_1        0.057772      0.055600 -0.243100 -4.515753     0.121321
# Cmodel_T3cD_2        0.057391      0.055217 -0.264140 -4.463549     0.065532
# Cmodel_T3cD_3        0.054596      0.052405 -0.259870 -4.454347     0.075401
# Cmodel_T3cD_4        0.054888      0.047949 -0.253210 -3.829725     0.080346
# Cmodel_T3cD_5        0.054887      0.047948 -0.252328 -3.783285     0.090441
# ...                       ...           ...       ...       ...          ...
# Cmodel_T3cD_96       2.620733      2.614132 -3.556248  6.968667     0.850721
# Cmodel_T3cD_97       2.619481      2.612874 -3.555436  6.996698     0.850703
# Cmodel_T3cD_98       2.619525      2.612918 -3.552885  7.011924     0.850718
# Cmodel_T3cD_99       2.619420      2.612813 -3.502187  7.033666     0.876808
# Cmodel_T3cD_100      2.627609      2.621039 -3.485391  6.991050     0.874517
#
#                  11DOCRTSLtr  ...  DM_btn[n]    DCMPtm  PROTEIN_BS  \
# Cmodel_T3cD_1      -0.058935  ...   6.856818  9.131560    7.079502
# Cmodel_T3cD_2      -0.059097  ...   6.860687  9.130505    7.072374
# Cmodel_T3cD_3      -0.059098  ...   6.857076  9.130540    7.075013
# Cmodel_T3cD_4      -0.066342  ...   6.736504  9.110400    7.075135
# Cmodel_T3cD_5      -0.066340  ...   6.738693  9.109422    7.074286
# ...                      ...  ...        ...       ...         ...
# Cmodel_T3cD_96     -0.285882  ...   8.947520 -6.866842    6.896499
# Cmodel_T3cD_97     -0.285839  ...   8.958405 -6.864687    6.904378
# Cmodel_T3cD_98     -0.285874  ...   8.961177 -6.812604    6.877960
# Cmodel_T3cD_99     -0.285801  ...   8.930703 -6.884976    6.917183
# Cmodel_T3cD_100    -0.286448  ...   8.931899 -6.848203    6.933024
#
#                  DM_PROTEIN   ATPS4mi  CYOR_u10mi      Htmi  NADH2_u10mi  \
# Cmodel_T3cD_1      7.079502  9.965502    9.206923  6.251115     4.817607
# Cmodel_T3cD_2      7.072374  9.965523    9.206513  6.268819     4.813958
# Cmodel_T3cD_3      7.075013  9.965517    9.206608  6.265251     4.804245
# Cmodel_T3cD_4      7.075135  9.965504    9.210495  6.193766     4.791757
# Cmodel_T3cD_5      7.074286  9.965509    9.210584  6.191157     4.799817
# ...                     ...       ...         ...       ...          ...
# Cmodel_T3cD_96     6.896499  9.964653    8.222304  8.919780     6.255440
# Cmodel_T3cD_97     6.904378  9.964902    8.210027  8.921369     6.285734
# Cmodel_T3cD_98     6.877960  9.964757    8.205608  8.925362     6.256954
# Cmodel_T3cD_99     6.917183  9.964576    8.199799  8.917651     6.269719
# Cmodel_T3cD_100    6.933024  9.964586    8.187003  8.904197     6.251894
#
#                   CYOOm3i   CYOOm2i
# Cmodel_T3cD_1    8.626042  2.199405
# Cmodel_T3cD_2    8.627806  2.201072
# Cmodel_T3cD_3    8.628192  2.198686
# Cmodel_T3cD_4    8.621501  2.045902
# Cmodel_T3cD_5    8.620754  2.039769
# ...                   ...       ...
# Cmodel_T3cD_96   9.517008  3.653520
# Cmodel_T3cD_97   9.518832  3.686225
# Cmodel_T3cD_98   9.523926  3.695941
# Cmodel_T3cD_99   9.523846  3.670599
# Cmodel_T3cD_100  9.528469  3.678049
#
# [100 rows x 10600 columns]

# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.stats import multitest
from statsmodels.stats.multitest import multipletests

t_statistic, p_values = stats.ttest_ind(t_Cmodel_T2D, t_Cmodel, axis = 0, nan_policy = 'omit')
fold_change = np.mean(t_Cmodel_T2D, axis=0) - np.mean(t_Cmodel, axis=0)
fold_change[np.isnan(fold_change)] = 0
p_values[np.isnan(p_values)] = 1.0  
reject,q_values, _, _ = multipletests(
    p_values,
    alpha=0.05,
    method='fdr_bh',  
    is_sorted=False,
    returnsorted=False)

t_results = pd.DataFrame({
    'reaction': t_Cmodel.columns,
    'p_value': p_values,
    'q_value': q_values,
    'Diferencia': fold_change
})

t_results['sign'] = 'NORMAL'
for idx, row in t_results.iterrows():
    if row['q_value'] < 0.05 and row['Diferencia'] > 1:
        t_results.loc[idx, 'sign'] = 'UP'
    elif row['q_value'] < 0.05 and row['Diferencia'] < -1:
        t_results.loc[idx, 'sign'] = 'DOWN'

t_fluxes_sign = t_results[t_results['sign'] != 'NORMAL']
print(t_fluxes_sign)
print(t_fluxes_sign['sign'].to_string(index=False))
# Out:
#                 reaction        p_value        q_value  Diferencia  sign
# 10FTHFtm        10FTHFtm  1.178617e-170  2.478838e-169  -17.528529  DOWN
# 13DAMPPOX      13DAMPPOX   8.529889e-20   1.241819e-19   -3.526180  DOWN
# 1PPDCRp          1PPDCRp   3.685816e-47   1.331163e-46   -5.451221  DOWN
# 24NPHte          24NPHte  6.613856e-178  1.498010e-176   -7.872201  DOWN
# 25HVITD3t      25HVITD3t   1.937615e-88   1.790646e-87    6.923229    UP
# ...                  ...            ...            ...         ...   ...
# DCMPtm            DCMPtm   3.672352e-32   7.620778e-32    4.609694    UP
# PROTEIN_BS    PROTEIN_BS   2.323197e-15   3.055701e-15   -2.117434  DOWN
# DM_PROTEIN    DM_PROTEIN   2.323197e-15   3.055701e-15   -2.117434  DOWN
# NADH2_u10mi  NADH2_u10mi   5.622986e-46   1.930170e-45   -2.090079  DOWN
# CYOOm2i          CYOOm2i   4.584304e-24   7.524563e-24   -2.305600  DOWN
#
# [5292 rows x 5 columns]
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN

# %%
import seaborn as sns
plt.figure(figsize = (10, 6))
colors = {"NORMAL":"#D2D2D2", "UP":"#FF6462", "DOWN":"#62B8FF"}

sns.scatterplot(x = t_results['Diferencia'], y = -np.log10(t_results['q_value']), hue = t_results['sign'], palette = colors, alpha = 0.7)
plt.axhline(-np.log10(0.05), color = 'k', linestyle = '--', linewidth = 1, label = 'THRESHOLD')
plt.axvline(1, color = 'k', linestyle = '--', linewidth = 1)
plt.axvline(-1, color = 'k', linestyle = '--', linewidth = 1)

plt.xlabel('Diferencia')
plt.ylabel('-log10(q-value)')
plt.title('Reaccions Diferencialment Regulades Cmodel_T2D vs Cmodel')
plt.legend()
plt.grid(True)


up_down_results = t_results[(t_results['q_value'] < 0.05) &
                            ((t_results['sign'] == 'UP') | (t_results['sign'] == 'DOWN'))]
top_10 = up_down_results.nsmallest(10, 'q_value')

# Agregar etiquetas de texto para el nombre de la reacción en los 10 puntos más significativos
for index, row in top_10.iterrows():
    plt.text(row['Diferencia'], -np.log10(row['q_value']), row['reaction'], fontsize=8, ha='center', va='center')

    
plt.show()
# Out:
# C:\Users\NOE\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\NOE\AppData\Local\Temp\ipykernel_1976\1606615544.py:23: RuntimeWarning: divide by zero encountered in log10
#   plt.text(row['Diferencia'], -np.log10(row['q_value']), row['reaction'], fontsize=8, ha='center', va='center')
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
T2D_results= t_fluxes_sign

# %%
up_values = t_fluxes_sign[t_fluxes_sign['sign'] == 'UP']
up_values
# Out:
#                                 reaction        p_value        q_value  \
# 25HVITD3t                      25HVITD3t   1.937615e-88   1.790646e-87
# 2HBt2                              2HBt2   1.586433e-22   2.489075e-22
# 2HCO3_NAt                      2HCO3_NAt   4.946832e-30   9.471896e-30
# 2MCITt                            2MCITt   7.923815e-89   7.387198e-88
# 2OXOADOXm                      2OXOADOXm   5.038091e-89   4.713483e-88
# ...                                  ...            ...            ...
# sink_asp_L[c]              sink_asp_L[c]  1.459754e-236  8.059060e-235
# DM_4glu56dihdind[c]  DM_4glu56dihdind[c]  4.590651e-149  7.384052e-148
# DM_CE4888[c]                DM_CE4888[c]   1.317132e-19   1.906802e-19
# DM_btn[n]                      DM_btn[n]   7.846412e-21   1.173419e-20
# DCMPtm                            DCMPtm   3.672352e-32   7.620778e-32
#
#                      Diferencia sign
# 25HVITD3t              6.923229   UP
# 2HBt2                  1.320946   UP
# 2HCO3_NAt              2.599321   UP
# 2MCITt                 5.794265   UP
# 2OXOADOXm              3.106978   UP
# ...                         ...  ...
# sink_asp_L[c]          3.107749   UP
# DM_4glu56dihdind[c]    2.026305   UP
# DM_CE4888[c]           1.137280   UP
# DM_btn[n]              1.584928   UP
# DCMPtm                 4.609694   UP
#
# [2108 rows x 5 columns]

# %%
down_values = t_fluxes_sign[t_fluxes_sign['sign'] == 'DOWN']
down_values
# Out:
#                 reaction        p_value        q_value  Diferencia  sign
# 10FTHFtm        10FTHFtm  1.178617e-170  2.478838e-169  -17.528529  DOWN
# 13DAMPPOX      13DAMPPOX   8.529889e-20   1.241819e-19   -3.526180  DOWN
# 1PPDCRp          1PPDCRp   3.685816e-47   1.331163e-46   -5.451221  DOWN
# 24NPHte          24NPHte  6.613856e-178  1.498010e-176   -7.872201  DOWN
# 2AMACHYD        2AMACHYD   9.587906e-49   3.705133e-48   -2.396073  DOWN
# ...                  ...            ...            ...         ...   ...
# DM_btn[m]      DM_btn[m]   4.644307e-32   9.549884e-32   -4.260463  DOWN
# PROTEIN_BS    PROTEIN_BS   2.323197e-15   3.055701e-15   -2.117434  DOWN
# DM_PROTEIN    DM_PROTEIN   2.323197e-15   3.055701e-15   -2.117434  DOWN
# NADH2_u10mi  NADH2_u10mi   5.622986e-46   1.930170e-45   -2.090079  DOWN
# CYOOm2i          CYOOm2i   4.584304e-24   7.524563e-24   -2.305600  DOWN
#
# [3184 rows x 5 columns]

# %%
subsystems_df=pd.read_csv('C:/Users/NOE/Desktop/TFG-Example/Islet data/RPKM data/Subsystems Recon 3D/df_subSystems.csv', index_col=0)
subsystems_df
# Out:
#                                                       Subsystem
# Reaction ID
# 10FTHF5GLUtl    [<Group Transport, lysosomal at 0x158deeed810>]
# 10FTHF5GLUtm  [<Group Transport, mitochondrial at 0x158deeed...
# 10FTHF6GLUtl    [<Group Transport, lysosomal at 0x158deeed810>]
# 10FTHF6GLUtm  [<Group Transport, mitochondrial at 0x158deeed...
# 10FTHF7GLUtl    [<Group Transport, lysosomal at 0x158deeed810>]
# ...                                                         ...
# CYOR_u10mi    [<Group Oxidative phosphorylation at 0x158deee...
# Htmi          [<Group Transport, mitochondrial at 0x158deeed...
# NADH2_u10mi   [<Group Oxidative phosphorylation at 0x158deee...
# CYOOm3i       [<Group Oxidative phosphorylation at 0x158deee...
# CYOOm2i       [<Group Oxidative phosphorylation at 0x158deee...
#
# [10600 rows x 1 columns]

# %% [markdown]
# sf(k, M, n, N, loc=0)
# k: El número de éxitos en la muestra.
# M: Número total de nombre d'objectes en la poblacion total. (valor númèric de la dimensió)
# n: El número de éxitos en la población total, nombre total de objectes Tipus I (random variate .
# N: El tamaño de la muestra.
# loc: (Opcional) Un parámetro de desplazamiento. Por defecto es 0.

# %%
import re
import math
from scipy.stats import hypergeom
#Aplicar Hypergeomètric test per cada un subsystem, la funció de normal només aplica per a un. 
#Per fer-ho  per tots el faré amb loop.
T2D_subsystems = subsystems_df[subsystems_df.index.isin(T2D_results.index)]
k = T2D_subsystems.groupby('Subsystem').size().sort_values(ascending=False)
n = subsystems_df.groupby('Subsystem').size().sort_values(ascending=False)

p_values = {}


for subsystem, k_values in k.items():
    # Total number of subsystems
    M = len(subsystems_df)
    
    # Count of occurrences of the subsystem in the entire dataset
    n_value = n.get(subsystem, 0)  # Handle cases where the subsystem is not present in n
    
    # Total number of subsystems in ts_subsystems
    N = len(T2D_subsystems)
    
    # Get the first element of k_value list and convert to integer
    k_value=int(k_values)
    
    expected_count = N * (k_value / M)
    
    # Enrichment score: observed count / expected count
    enrichment_score = k_value / expected_count
    
    
    # Calculate the p-value using the hypergeometric distribution
    p_value = hypergeom.sf(k_value -1 , M, n_value, N)
    
    # Store the p-value in a dictionary
    p_values[subsystem] = p_value

# Apply FDR correction
q_values = multipletests(list(p_values.values()), method='fdr_bh')[1]

log_q_values = [-math.log10(q) for q in q_values]
# Print or use the p-values as needed


df = pd.DataFrame({
    'Subsystems': list(p_values.keys()),
    'Counts':  [k[subsystem] for subsystem in p_values.keys()],
    'Enrichment_Score': list(log_q_values),
    'p_values': list(p_values.values()),
    'q_values': list(q_values)
})
filtered_df = df[df['q_values'] < 0.05]
filtered_df =filtered_df.sort_values(by='Enrichment_Score', ascending=False)



def extract_intermediate(subsystem):
    match = re.search(r'\[<Group (.*?) at 0x', subsystem)
    if match:
        return match.group(1)
    return subsystem

# Aplicar la función a la columna 'Subsystems'
filtered_df['Subsystems'] = filtered_df['Subsystems'].apply(extract_intermediate)
filtered_df
# Out:
#                                            Subsystems  Counts  \
# 0                            Transport, extracellular    1633
# 4                                  Peptide metabolism     191
# 1                            Exchange/demand reaction    1037
# 19                               Vitamin A metabolism      38
# 7                          Nucleotide interconversion     106
# 21                      Starch and sucrose metabolism      33
# 20  Glycine, serine, alanine, and threonine metabo...      35
# 8                                       Miscellaneous      93
# 22         Valine, leucine, and isoleucine metabolism      32
# 30                                  Lysine metabolism      23
#
#     Enrichment_Score      p_values      q_values
# 0          41.437407  3.927448e-44  3.652526e-42
# 4          18.635929  4.972998e-21  2.312444e-19
# 1          12.014305  3.121282e-14  9.675975e-13
# 19          3.574833  1.144837e-05  2.661745e-04
# 7           2.770109  9.128045e-05  1.697816e-03
# 21          2.704756  1.273247e-04  1.973533e-03
# 20          2.167346  5.119994e-04  6.802278e-03
# 8           1.477131  3.225730e-03  3.333255e-02
# 22          1.477131  3.150723e-03  3.333255e-02
# 30          1.319199  5.156061e-03  4.795136e-02

# %%
### import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# Transform q-values into their negative base-10 logarithms
neg_log_q_values = -np.log10(filtered_df['q_values'])

# Create dot plot
plt.figure(figsize=(9, 7))
scatter = plt.scatter(filtered_df['Enrichment_Score'], filtered_df['Subsystems'], s=filtered_df['Counts']*0.5, c=neg_log_q_values, alpha=0.6, cmap='plasma', vmin=0, vmax=20)
plt.xlabel('Enrichment Score')
plt.ylabel('Subsystems')
plt.title('Dot Plot of T2D Subsystems Enrichment')

# Create color bar legend for -log10(q_values) using plasma colormap
cbar_ax = plt.gca().inset_axes([1.05, 0.5, 0.03, 0.4])
color_legend = plt.colorbar(scatter, label='-log10(q_value)', cmap='plasma', shrink=0.5, orientation='vertical',cax=cbar_ax)
color_legend.set_label('-log10(q_value)')

# Calculate ranges based on Counts values
min_count = filtered_df['Counts'].min()
max_count = filtered_df['Counts'].max()
range_size = (max_count - min_count) // 4
count_ranges = [(min_count, min_count + range_size), 
                (min_count + range_size + 1, min_count + 2 * range_size), 
                (min_count + 2 * range_size + 1, min_count + 3 * range_size), 
                (min_count + 3 * range_size + 1, max_count)]


# Create size legend for counts using circles
size_legend = plt.legend(handles=[
    plt.scatter([], [], s=size*0.5, color='grey', alpha=0.6, label=f'{range[0]}-{range[1]}')
    for range, size in zip(count_ranges, legend_sizes)
], title='Count', loc='center left', bbox_to_anchor=(1.02, 0.2), prop={'size': 9},borderpad=1,handlelength=0.5,handletextpad=1.5,labelspacing=1.9)  # Adjust font size here
plt.gca().add_artist(size_legend)



plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ################################

# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.stats import multitest
from statsmodels.stats.multitest import multipletests

t_statistic, p_values = stats.ttest_ind(t_Cmodel_T3cD, t_Cmodel, axis = 0, nan_policy = 'omit')
fold_change = np.mean(t_Cmodel_T3cD, axis=0) - np.mean(t_Cmodel, axis=0)
fold_change[np.isnan(fold_change)] = 0
p_values[np.isnan(p_values)] = 1.0  
reject,q_values, _, _ = multipletests(
    p_values,
    alpha=0.05,
    method='fdr_bh',  
    is_sorted=False,
    returnsorted=False)

t_results = pd.DataFrame({
    'reaction': t_Cmodel.columns,
    'p_value': p_values,
    'q_value': q_values,
    'Diferencia': fold_change
})

t_results['sign'] = 'NORMAL'
for idx, row in t_results.iterrows():
    if row['q_value'] < 0.05 and row['Diferencia'] > 1:
        t_results.loc[idx, 'sign'] = 'UP'
    elif row['q_value'] < 0.05 and row['Diferencia'] < -1:
        t_results.loc[idx, 'sign'] = 'DOWN'

t_fluxes_sign_T3cD = t_results[t_results['sign'] != 'NORMAL']
print(t_fluxes_sign_T3cD)
print(t_fluxes_sign_T3cD['sign'].to_string(index=False))
# Out:
#                   reaction       p_value       q_value  Diferencia  sign
# 10FTHF7GLUtl  10FTHF7GLUtl  1.419771e-14  4.005743e-14    1.022673    UP
# 10FTHF7GLUtm  10FTHF7GLUtm  9.338662e-15  2.664598e-14    1.033526    UP
# 10FTHFtm          10FTHFtm  8.510955e-27  4.448527e-26   -8.602696  DOWN
# 13DAMPPOX        13DAMPPOX  3.891873e-18  1.354362e-17   -3.341129  DOWN
# 1PPDCRp            1PPDCRp  1.485420e-36  1.205624e-35   -4.626922  DOWN
# ...                    ...           ...           ...         ...   ...
# DM_tym[c]        DM_tym[c]  1.311192e-08  2.516501e-08   -2.015035  DOWN
# DM_Lkynr[c]    DM_Lkynr[c]  8.638238e-81  2.206393e-79    5.203754    UP
# DM_btn[m]        DM_btn[m]  5.387341e-29  3.129086e-28   -4.094235  DOWN
# DCMPtm              DCMPtm  1.501487e-10  3.259423e-10   -5.244512  DOWN
# Htmi                  Htmi  1.359373e-21  5.650725e-21   -1.645858  DOWN
#
# [4499 rows x 5 columns]
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
# DOWN
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
# DOWN
#   UP
# DOWN
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
#   UP
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
# DOWN
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN
# DOWN
# DOWN
#   UP
#   UP
#   UP
# DOWN
#   UP
#   UP
# DOWN
#   UP
# DOWN
# DOWN
# DOWN

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import seaborn as sns

plt.figure(figsize = (10, 6))
colors = {"NORMAL":"#D2D2D2", "UP":"#FF6462", "DOWN":"#62B8FF"}

sns.scatterplot(x = t_results['Diferencia'], y = -np.log10(t_results['q_value']), hue = t_results['sign'], palette = colors, alpha = 0.7)
plt.axhline(-np.log10(0.05), color = 'k', linestyle = '--', linewidth = 1, label = 'THRESHOLD')
plt.axvline(1, color = 'k', linestyle = '--', linewidth = 1)
plt.axvline(-1, color = 'k', linestyle = '--', linewidth = 1)

plt.xlabel('Diferencia')
plt.ylabel('-log10(q-value)')
plt.title('Reaccions Diferencialment Regulades Cmodel_T3cD vs Cmodel')
plt.legend()
plt.grid(True)


up_down_results = t_results[(t_results['q_value'] < 0.05) &
                            ((t_results['sign'] == 'UP') | (t_results['sign'] == 'DOWN'))]

#top_20 = up_down_results.nsmallest(20, 'q_value')

# Agregar etiquetas de texto para el nombre de la reacción en los 10 puntos más significativos
#for index, row in top_20.iterrows():
 #   plt.text(row['Diferencia'], -np.log10(row['q_value']), row['reaction'], fontsize=8, ha='center', va='center')

    
plt.show()
# Out:
# C:\Users\NOE\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
T3cD_results= t_fluxes_sign_T3cD
T3cD_results
# Out:
#                   reaction       p_value       q_value  Diferencia  sign
# 10FTHF7GLUtl  10FTHF7GLUtl  1.419771e-14  4.005743e-14    1.022673    UP
# 10FTHF7GLUtm  10FTHF7GLUtm  9.338662e-15  2.664598e-14    1.033526    UP
# 10FTHFtm          10FTHFtm  8.510955e-27  4.448527e-26   -8.602696  DOWN
# 13DAMPPOX        13DAMPPOX  3.891873e-18  1.354362e-17   -3.341129  DOWN
# 1PPDCRp            1PPDCRp  1.485420e-36  1.205624e-35   -4.626922  DOWN
# ...                    ...           ...           ...         ...   ...
# DM_tym[c]        DM_tym[c]  1.311192e-08  2.516501e-08   -2.015035  DOWN
# DM_Lkynr[c]    DM_Lkynr[c]  8.638238e-81  2.206393e-79    5.203754    UP
# DM_btn[m]        DM_btn[m]  5.387341e-29  3.129086e-28   -4.094235  DOWN
# DCMPtm              DCMPtm  1.501487e-10  3.259423e-10   -5.244512  DOWN
# Htmi                  Htmi  1.359373e-21  5.650725e-21   -1.645858  DOWN
#
# [4499 rows x 5 columns]

# %%
up_values_T3cD = t_fluxes_sign_T3cD[t_fluxes_sign_T3cD['sign'] == 'UP']
up_values_T3cD
# Out:
#                   reaction       p_value       q_value  Diferencia sign
# 10FTHF7GLUtl  10FTHF7GLUtl  1.419771e-14  4.005743e-14    1.022673   UP
# 10FTHF7GLUtm  10FTHF7GLUtm  9.338662e-15  2.664598e-14    1.033526   UP
# 2HBO                  2HBO  4.010633e-07  6.936321e-07    3.421228   UP
# 2MCITt              2MCITt  1.972033e-04  2.856457e-04    1.124390   UP
# 3HKYNAKGAT      3HKYNAKGAT  4.990153e-05  7.554360e-05    1.006787   UP
# ...                    ...           ...           ...         ...  ...
# DM_adrnl[c]    DM_adrnl[c]  2.060680e-19  7.675054e-19    2.397760   UP
# DM_ach[c]        DM_ach[c]  8.474127e-05  1.262839e-04    1.159197   UP
# DM_kynate[c]  DM_kynate[c]  2.155935e-38  1.896507e-37    1.781113   UP
# DM_nrpphr[c]  DM_nrpphr[c]  1.162159e-16  3.703814e-16    2.467137   UP
# DM_Lkynr[c]    DM_Lkynr[c]  8.638238e-81  2.206393e-79    5.203754   UP
#
# [2239 rows x 5 columns]

# %%
down_values_T3cD = t_fluxes_sign_T3cD[t_fluxes_sign_T3cD['sign'] == 'DOWN']
down_values_T3cD
# Out:
#                 reaction       p_value       q_value  Diferencia  sign
# 10FTHFtm        10FTHFtm  8.510955e-27  4.448527e-26   -8.602696  DOWN
# 13DAMPPOX      13DAMPPOX  3.891873e-18  1.354362e-17   -3.341129  DOWN
# 1PPDCRp          1PPDCRp  1.485420e-36  1.205624e-35   -4.626922  DOWN
# 25HVITD3t      25HVITD3t  2.216620e-20  8.660587e-20   -2.063880  DOWN
# 2AMADPTm        2AMADPTm  1.285874e-19  4.838573e-19   -1.488814  DOWN
# ...                  ...           ...           ...         ...   ...
# DM_hista[c]  DM_hista[c]  5.862768e-44  6.618247e-43   -4.782215  DOWN
# DM_tym[c]      DM_tym[c]  1.311192e-08  2.516501e-08   -2.015035  DOWN
# DM_btn[m]      DM_btn[m]  5.387341e-29  3.129086e-28   -4.094235  DOWN
# DCMPtm            DCMPtm  1.501487e-10  3.259423e-10   -5.244512  DOWN
# Htmi                Htmi  1.359373e-21  5.650725e-21   -1.645858  DOWN
#
# [2260 rows x 5 columns]

# %%
T3cD_subsystems = subsystems_df[subsystems_df.index.isin(T3cD_results.index)]
k = T3cD_subsystems.groupby('Subsystem').size().sort_values(ascending=False)
n = subsystems_df.groupby('Subsystem').size().sort_values(ascending=False)

p_values = {}


for subsystem, k_values in k.items():
    # Total number of subsystems
    M = len(subsystems_df)
    
    # Count of occurrences of the subsystem in the entire dataset
    n_value = n.get(subsystem, 0)  # Handle cases where the subsystem is not present in n
    
    # Total number of subsystems in ts_subsystems
    N = len(T3cD_subsystems)
    
    # Get the first element of k_value list and convert to integer
    k_value=int(k_values)
    
    expected_count = N * (k_value / M)
    
    # Enrichment score: observed count / expected count
    enrichment_score = k_value / expected_count
    
    
    # Calculate the p-value using the hypergeometric distribution
    p_value = hypergeom.sf(k_value -1 , M, n_value, N)
    
    # Store the p-value in a dictionary
    p_values[subsystem] = p_value

# Apply FDR correction
q_values = multipletests(list(p_values.values()), method='fdr_bh')[1]

log_q_values = [-math.log10(q) for q in q_values]


df = pd.DataFrame({
    'Subsystems': list(p_values.keys()),
    'Counts':  [k[subsystem] for subsystem in p_values.keys()],
    'Enrichment_Score': list(log_q_values),
    'p_values': list(p_values.values()),
    'q_values': list(q_values)
})
filtered_df = df[df['q_values'] < 0.05]
filtered_df =filtered_df.sort_values(by='Enrichment_Score', ascending=False)
def extract_intermediate(subsystem):
    match = re.search(r'\[<Group (.*?) at 0x', subsystem)
    if match:
        return match.group(1)
    return subsystem

# Aplicar la función a la columna 'Subsystems'
filtered_df['Subsystems'] = filtered_df['Subsystems'].apply(extract_intermediate)
filtered_df
# Out:
#                        Subsystems  Counts  Enrichment_Score      p_values  \
# 3              Peptide metabolism     206         41.186381  7.844069e-44
# 0        Transport, extracellular    1420         38.192991  1.545114e-40
# 1        Exchange/demand reaction     883          8.906779  4.479852e-11
# 17           Vitamin A metabolism      33          2.654397  1.068033e-04
# 18  Starch and sucrose metabolism      29          2.137203  4.392274e-04
#
#         q_values
# 3   6.510577e-42
# 0   6.412221e-39
# 1   1.239426e-09
# 17  2.216168e-03
# 18  7.291174e-03

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# Transform q-values into their negative base-10 logarithms
neg_log_q_values = -np.log10(filtered_df['q_values'])

# Create dot plot
plt.figure(figsize=(9, 7))
scatter = plt.scatter(filtered_df['Enrichment_Score'], filtered_df['Subsystems'], s=filtered_df['Counts']*0.5, c=neg_log_q_values, alpha=0.6, cmap='plasma', vmin=0, vmax=20)
plt.xlabel('Enrichment Score')
plt.ylabel('Subsystems')
plt.title('Dot Plot of T3cD Subsystems Enrichment')

# Create color bar legend for -log10(q_values) using plasma colormap
cbar_ax = plt.gca().inset_axes([1.05, 0.5, 0.03, 0.4])
color_legend = plt.colorbar(scatter, label='-log10(q_value)', cmap='plasma', shrink=0.5, orientation='vertical',cax=cbar_ax)
color_legend.set_label('-log10(q_value)')

# Calculate ranges based on Counts values
min_count = filtered_df['Counts'].min()
max_count = filtered_df['Counts'].max()
range_size = (max_count - min_count) // 4
count_ranges = [(min_count, min_count + range_size), 
                (min_count + range_size + 1, min_count + 2 * range_size), 
                (min_count + 2 * range_size + 1, min_count + 3 * range_size), 
                (min_count + 3 * range_size + 1, max_count)]


# Create size legend for counts using circles
size_legend = plt.legend(handles=[
    plt.scatter([], [], s=size*0.5, color='grey', alpha=0.6, label=f'{range[0]}-{range[1]}')
    for range, size in zip(count_ranges, legend_sizes)
], title='Count', loc='center left', bbox_to_anchor=(1.02, 0.2), prop={'size': 9},borderpad=1,handlelength=0.5,handletextpad=1.5,labelspacing=1.9)  # Adjust font size here
plt.gca().add_artist(size_legend)



plt.grid(True)
plt.tight_layout()
plt.show()
