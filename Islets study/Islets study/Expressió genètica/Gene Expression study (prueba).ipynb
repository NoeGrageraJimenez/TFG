# %%
import pandas as pd

# %pip install pydeseq2
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
# Out:
# Requirement already satisfied: pydeseq2 in c:\users\noe\anaconda3\lib\site-packages (0.4.8)
# Requirement already satisfied: anndata>=0.8.0 in c:\users\noe\anaconda3\lib\site-packages (from pydeseq2) (0.10.7)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\noe\anaconda3\lib\site-packages (from pydeseq2) (1.24.3)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\noe\anaconda3\lib\site-packages (from pydeseq2) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\noe\anaconda3\lib\site-packages (from pydeseq2) (1.3.0)
# Requirement already satisfied: scipy>=1.11.0 in c:\users\noe\anaconda3\lib\site-packages (from pydeseq2) (1.11.3)
# Requirement already satisfied: matplotlib>=3.6.2 in c:\users\noe\anaconda3\lib\site-packages (from pydeseq2) (3.7.2)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in c:\users\noe\anaconda3\lib\site-packages (from anndata>=0.8.0->pydeseq2) (1.6)
# Requirement already satisfied: h5py>=3.1 in c:\users\noe\anaconda3\lib\site-packages (from anndata>=0.8.0->pydeseq2) (3.9.0)
# Requirement already satisfied: natsort in c:\users\noe\anaconda3\lib\site-packages (from anndata>=0.8.0->pydeseq2) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\noe\anaconda3\lib\site-packages (from anndata>=0.8.0->pydeseq2) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\noe\anaconda3\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\noe\anaconda3\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\noe\anaconda3\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\noe\anaconda3\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\noe\anaconda3\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\noe\anaconda3\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\noe\anaconda3\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\noe\anaconda3\lib\site-packages (from pandas>=1.4.0->pydeseq2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\noe\anaconda3\lib\site-packages (from pandas>=1.4.0->pydeseq2) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\noe\anaconda3\lib\site-packages (from scikit-learn>=1.1.0->pydeseq2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\noe\anaconda3\lib\site-packages (from scikit-learn>=1.1.0->pydeseq2) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\noe\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->pydeseq2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
counts= pd.read_csv('C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/AllConditions_DataFrame.csv')
counts= counts.set_index('symbol')
counts
# Out:
#               IGT_GSM5009231_DP005  IGT_GSM5009232_DP007  \
# symbol
# TSPAN6                         438                   118
# TNMD                             0                     0
# DPM1                           518                   570
# SCYL3                          249                   308
# C1orf112                        43                    32
# ...                            ...                   ...
# TUSC2P1                          0                     0
# H2BK1                            1                     0
# LOC101928523                     2                     0
# LOC112267968                     1                     0
# MKKS                             0                     0
#
#               IGT_GSM5009233_DP008  IGT_GSM5009237_DP013  \
# symbol
# TSPAN6                         567                   342
# TNMD                             1                     7
# DPM1                           892                   558
# SCYL3                          285                   351
# C1orf112                        43                    56
# ...                            ...                   ...
# TUSC2P1                          0                     0
# H2BK1                            0                     0
# LOC101928523                     0                     0
# LOC112267968                     4                    12
# MKKS                             0                     0
#
#               IGT_GSM5009241_DP025  IGT_GSM5009249_DP048  \
# symbol
# TSPAN6                         183                   113
# TNMD                             2                     0
# DPM1                           606                   686
# SCYL3                          207                   314
# C1orf112                        56                    65
# ...                            ...                   ...
# TUSC2P1                          0                     0
# H2BK1                            0                     0
# LOC101928523                     0                     0
# LOC112267968                     0                     0
# MKKS                             0                     0
#
#               IGT_GSM5009251_DP051  IGT_GSM5009258_DP059  \
# symbol
# TSPAN6                         341                   377
# TNMD                             0                     2
# DPM1                           597                  1079
# SCYL3                          222                   554
# C1orf112                        49                    80
# ...                            ...                   ...
# TUSC2P1                          0                     0
# H2BK1                            0                     0
# LOC101928523                     0                     2
# LOC112267968                     2                     2
# MKKS                             0                     0
#
#               IGT_GSM5009260_DP063  IGT_GSM5009264_DP067  ...  \
# symbol                                                    ...
# TSPAN6                         455                   186  ...
# TNMD                             0                     0  ...
# DPM1                           835                   565  ...
# SCYL3                          320                   170  ...
# C1orf112                        41                    40  ...
# ...                            ...                   ...  ...
# TUSC2P1                          0                     0  ...
# H2BK1                            0                     0  ...
# LOC101928523                     0                     0  ...
# LOC112267968                     0                     0  ...
# MKKS                             0                     0  ...
#
#               T3cD_GSM5009324_DP152  T3cD_GSM5009326_DP160  \
# symbol
# TSPAN6                          311                    638
# TNMD                              1                      0
# DPM1                            914                   1365
# SCYL3                           217                    335
# C1orf112                         55                     37
# ...                             ...                    ...
# TUSC2P1                           0                      0
# H2BK1                             0                      0
# LOC101928523                      0                      0
# LOC112267968                      1                      8
# MKKS                              0                      0
#
#               T3cD_GSM5009328_DP162  T3cD_GSM5009331_DP167  \
# symbol
# TSPAN6                          884                    631
# TNMD                              3                      0
# DPM1                           1092                   1208
# SCYL3                           374                    348
# C1orf112                         71                     31
# ...                             ...                    ...
# TUSC2P1                           0                      0
# H2BK1                             0                      0
# LOC101928523                      0                      0
# LOC112267968                      0                      6
# MKKS                              0                      0
#
#               T3cD_GSM5009332_DP169  T3cD_GSM5009333_DP170  \
# symbol
# TSPAN6                          973                    717
# TNMD                              0                      0
# DPM1                            882                    868
# SCYL3                           344                    385
# C1orf112                         98                    111
# ...                             ...                    ...
# TUSC2P1                           0                      0
# H2BK1                             0                      0
# LOC101928523                      0                      0
# LOC112267968                      0                      5
# MKKS                              0                      0
#
#               T3cD_GSM5009335_DP174  T3cD_GSM5009336_DP176  \
# symbol
# TSPAN6                          285                    619
# TNMD                              4                      7
# DPM1                           1066                    940
# SCYL3                           298                    304
# C1orf112                         37                     24
# ...                             ...                    ...
# TUSC2P1                           0                      0
# H2BK1                             0                      0
# LOC101928523                      0                      6
# LOC112267968                      8                      4
# MKKS                              0                      0
#
#               T3cD_GSM5009339_DP180  T3cD_GSM5009354_DP208
# symbol
# TSPAN6                          422                    412
# TNMD                              0                      0
# DPM1                           1165                   1060
# SCYL3                           366                    306
# C1orf112                         59                     64
# ...                             ...                    ...
# TUSC2P1                           0                      0
# H2BK1                             0                      0
# LOC101928523                      0                      0
# LOC112267968                      1                      0
# MKKS                              0                      0
#
# [35089 rows x 133 columns]

# %%
counts= counts[counts.sum(axis=1) > 0]
counts
# Out:
#               IGT_GSM5009231_DP005  IGT_GSM5009232_DP007  \
# symbol
# TSPAN6                         438                   118
# TNMD                             0                     0
# DPM1                           518                   570
# SCYL3                          249                   308
# C1orf112                        43                    32
# ...                            ...                   ...
# C4orf36                         11                     6
# DHRS4L1                          1                     0
# H2BK1                            1                     0
# LOC101928523                     2                     0
# LOC112267968                     1                     0
#
#               IGT_GSM5009233_DP008  IGT_GSM5009237_DP013  \
# symbol
# TSPAN6                         567                   342
# TNMD                             1                     7
# DPM1                           892                   558
# SCYL3                          285                   351
# C1orf112                        43                    56
# ...                            ...                   ...
# C4orf36                         11                    13
# DHRS4L1                          1                    23
# H2BK1                            0                     0
# LOC101928523                     0                     0
# LOC112267968                     4                    12
#
#               IGT_GSM5009241_DP025  IGT_GSM5009249_DP048  \
# symbol
# TSPAN6                         183                   113
# TNMD                             2                     0
# DPM1                           606                   686
# SCYL3                          207                   314
# C1orf112                        56                    65
# ...                            ...                   ...
# C4orf36                         11                    15
# DHRS4L1                          7                     9
# H2BK1                            0                     0
# LOC101928523                     0                     0
# LOC112267968                     0                     0
#
#               IGT_GSM5009251_DP051  IGT_GSM5009258_DP059  \
# symbol
# TSPAN6                         341                   377
# TNMD                             0                     2
# DPM1                           597                  1079
# SCYL3                          222                   554
# C1orf112                        49                    80
# ...                            ...                   ...
# C4orf36                         14                    14
# DHRS4L1                          0                     2
# H2BK1                            0                     0
# LOC101928523                     0                     2
# LOC112267968                     2                     2
#
#               IGT_GSM5009260_DP063  IGT_GSM5009264_DP067  ...  \
# symbol                                                    ...
# TSPAN6                         455                   186  ...
# TNMD                             0                     0  ...
# DPM1                           835                   565  ...
# SCYL3                          320                   170  ...
# C1orf112                        41                    40  ...
# ...                            ...                   ...  ...
# C4orf36                         11                     6  ...
# DHRS4L1                          6                     7  ...
# H2BK1                            0                     0  ...
# LOC101928523                     0                     0  ...
# LOC112267968                     0                     0  ...
#
#               T3cD_GSM5009324_DP152  T3cD_GSM5009326_DP160  \
# symbol
# TSPAN6                          311                    638
# TNMD                              1                      0
# DPM1                            914                   1365
# SCYL3                           217                    335
# C1orf112                         55                     37
# ...                             ...                    ...
# C4orf36                           3                     14
# DHRS4L1                           1                     10
# H2BK1                             0                      0
# LOC101928523                      0                      0
# LOC112267968                      1                      8
#
#               T3cD_GSM5009328_DP162  T3cD_GSM5009331_DP167  \
# symbol
# TSPAN6                          884                    631
# TNMD                              3                      0
# DPM1                           1092                   1208
# SCYL3                           374                    348
# C1orf112                         71                     31
# ...                             ...                    ...
# C4orf36                          29                     20
# DHRS4L1                           9                     11
# H2BK1                             0                      0
# LOC101928523                      0                      0
# LOC112267968                      0                      6
#
#               T3cD_GSM5009332_DP169  T3cD_GSM5009333_DP170  \
# symbol
# TSPAN6                          973                    717
# TNMD                              0                      0
# DPM1                            882                    868
# SCYL3                           344                    385
# C1orf112                         98                    111
# ...                             ...                    ...
# C4orf36                          21                     16
# DHRS4L1                           7                      0
# H2BK1                             0                      0
# LOC101928523                      0                      0
# LOC112267968                      0                      5
#
#               T3cD_GSM5009335_DP174  T3cD_GSM5009336_DP176  \
# symbol
# TSPAN6                          285                    619
# TNMD                              4                      7
# DPM1                           1066                    940
# SCYL3                           298                    304
# C1orf112                         37                     24
# ...                             ...                    ...
# C4orf36                           8                      8
# DHRS4L1                           8                      0
# H2BK1                             0                      0
# LOC101928523                      0                      6
# LOC112267968                      8                      4
#
#               T3cD_GSM5009339_DP180  T3cD_GSM5009354_DP208
# symbol
# TSPAN6                          422                    412
# TNMD                              0                      0
# DPM1                           1165                   1060
# SCYL3                           366                    306
# C1orf112                         59                     64
# ...                             ...                    ...
# C4orf36                          15                     21
# DHRS4L1                           1                      3
# H2BK1                             0                      0
# LOC101928523                      0                      0
# LOC112267968                      1                      0
#
# [32060 rows x 133 columns]

# %%
counts=counts.T
counts['ARG2']
# Out:
# IGT_GSM5009231_DP005     381
# IGT_GSM5009232_DP007     721
# IGT_GSM5009233_DP008     404
# IGT_GSM5009237_DP013     812
# IGT_GSM5009241_DP025     707
#                         ...
# T3cD_GSM5009333_DP170    344
# T3cD_GSM5009335_DP174    849
# T3cD_GSM5009336_DP176    217
# T3cD_GSM5009339_DP180    344
# T3cD_GSM5009354_DP208    670
# Name: ARG2, Length: 133, dtype: int64

# %%
conditions = ['IGT'] * 41 + ['ND'] * 18 + ['T2D'] * 39 + ['T3cD'] * 35

# Crear un nuevo DataFrame basado en el DataFrame original
metadata = pd.DataFrame(zip(counts.index, conditions), columns=['Sample', 'condition'])
metadata
# Out:
#                     Sample condition
# 0     IGT_GSM5009231_DP005       IGT
# 1     IGT_GSM5009232_DP007       IGT
# 2     IGT_GSM5009233_DP008       IGT
# 3     IGT_GSM5009237_DP013       IGT
# 4     IGT_GSM5009241_DP025       IGT
# ..                     ...       ...
# 128  T3cD_GSM5009333_DP170      T3cD
# 129  T3cD_GSM5009335_DP174      T3cD
# 130  T3cD_GSM5009336_DP176      T3cD
# 131  T3cD_GSM5009339_DP180      T3cD
# 132  T3cD_GSM5009354_DP208      T3cD
#
# [133 rows x 2 columns]

# %%
metadata=metadata.set_index('Sample')
metadata
# Out:
#                       condition
# Sample
# IGT_GSM5009231_DP005        IGT
# IGT_GSM5009232_DP007        IGT
# IGT_GSM5009233_DP008        IGT
# IGT_GSM5009237_DP013        IGT
# IGT_GSM5009241_DP025        IGT
# ...                         ...
# T3cD_GSM5009333_DP170      T3cD
# T3cD_GSM5009335_DP174      T3cD
# T3cD_GSM5009336_DP176      T3cD
# T3cD_GSM5009339_DP180      T3cD
# T3cD_GSM5009354_DP208      T3cD
#
# [133 rows x 1 columns]

# %%
from pydeseq2.dds import DeseqDataSet
dds = DeseqDataSet(counts=counts,metadata=metadata,design_factors="condition")
dds
# Out:
# C:\Users\NOE\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 133 × 32060
#     obs: 'condition'
#     obsm: 'design_matrix'

# %%
dds.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.23 seconds.
#
# Fitting dispersions...
# ... done in 6.60 seconds.
#
# Fitting dispersion trend curve...
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 dds.deseq2()
#
# File ~\anaconda3\Lib\site-packages\pydeseq2\dds.py:446, in DeseqDataSet.deseq2(self)
#     443 self.fit_genewise_dispersions()
#     444 # Fit a parameterized trend curve for dispersions, of the form
#     445 # f(\mu) = \alpha_1/\mu + a_0
# --> 446 self.fit_dispersion_trend()
#     447 # Compute prior dispersion variance
#     448 self.fit_dispersion_prior()
#
# File ~\anaconda3\Lib\site-packages\pydeseq2\dds.py:590, in DeseqDataSet.fit_dispersion_trend(self)
#     587 self.varm["_normed_means"] = self.layers["normed_counts"].mean(0)
#     589 if self.trend_fit_type == "parametric":
# --> 590     self._fit_parametric_dispersion_trend()
#     591 elif self.trend_fit_type == "mean":
#     592     self._fit_mean_dispersion_trend()
#
# File ~\anaconda3\Lib\site-packages\pydeseq2\dds.py:884, in DeseqDataSet._fit_parametric_dispersion_trend(self)
#     878 r"""Fit the dispersion curve according to a parametric model.
#     879
#     880 :math:`f(\mu) = \alpha_1/\mu + a_0`.
#     881 """
#     882 # Exclude all-zero counts
#     883 targets = pd.Series(
# --> 884     self[:, self.non_zero_genes].varm["genewise_dispersions"].copy(),
#     885     index=self.non_zero_genes,
#     886 )
#     887 covariates = pd.Series(
#     888     1 / self[:, self.non_zero_genes].varm["_normed_means"],
#     889     index=self.non_zero_genes,
#     890 )
#     892 for gene in self.non_zero_genes:
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1085, in AnnData.__getitem__(self, index)
#    1083 def __getitem__(self, index: Index) -> AnnData:
#    1084     """Returns a sliced view of the object."""
# -> 1085     oidx, vidx = self._normalize_indices(index)
#    1086     return AnnData(self, oidx=oidx, vidx=vidx, asview=True)
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1066, in AnnData._normalize_indices(self, index)
#    1065 def _normalize_indices(self, index: Index | None) -> tuple[slice, slice]:
# -> 1066     return _normalize_indices(index, self.obs_names, self.var_names)
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\index.py:36, in _normalize_indices(index, names0, names1)
#      34 ax0, ax1 = unpack_index(index)
#      35 ax0 = _normalize_index(ax0, names0)
# ---> 36 ax1 = _normalize_index(ax1, names1)
#      37 return ax0, ax1
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\index.py:97, in _normalize_index(indexer, index)
#      95     return indexer
#      96 else:  # indexer should be string array
# ---> 97     positions = index.get_indexer(indexer)
#      98     if np.any(positions < 0):
#      99         not_found = indexer[positions < 0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3732, in Index.get_indexer(self, target, method, limit, tolerance)
#    3729 self._check_indexing_method(method, limit, tolerance)
#    3731 if not self._index_as_unique:
# -> 3732     raise InvalidIndexError(self._requires_unique_msg)
#    3734 if len(target) == 0:
#    3735     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
dds
# Out:
# AnnData object with n_obs × n_vars = 133 × 32060
#     obs: 'condition'
#     obsm: 'design_matrix', 'size_factors'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means'
#     layers: 'normed_counts', '_mu_hat'

# %%
from pydeseq2.default_inference import DefaultInference
inference = DefaultInference(n_cpus=8)

# %%
stat_res=DeseqStats(dds, inference=inference, contrast=('condition','ND','T2D'))
stat_res.summary()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 stat_res=DeseqStats(dds, inference=inference, contrast=('condition','ND','T2D'))
#       2 stat_res.summary()
#
# File ~\anaconda3\Lib\site-packages\pydeseq2\ds.py:152, in DeseqStats.__init__(self, dds, contrast, alpha, cooks_filter, independent_filter, prior_LFC_var, lfc_null, alt_hypothesis, inference, quiet)
#     136 def __init__(
#     137     self,
#     138     dds: DeseqDataSet,
#    (...)
#     149     quiet: bool = False,
#     150 ) -> None:
#     151     assert (
# --> 152         "LFC" in dds.varm
#     153     ), "Please provide a fitted DeseqDataSet by first running the `deseq2` method."
#     155     self.dds = dds
#     157     self.alpha = alpha
#
# AssertionError: Please provide a fitted DeseqDataSet by first running the `deseq2` method.

# %% [markdown]
# ## -----------------------------------------------------------

# %% [markdown]
# # _____________________________________________________-

# %%
counts= pd.read_csv('C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/SSConditions_DataFrame.csv')
counts= counts.set_index('ensembl')
counts
# Out:
#                     IGT_counts  IGT_counts.1  IGT_counts.2  IGT_counts.3  \
# ensembl
# ENSG00000000003.14         438           118           567           342
# ENSG00000000005.5            0             0             1             7
# ENSG00000000419.12         518           570           892           558
# ENSG00000000457.13         249           308           285           351
# ENSG00000000460.16          43            32            43            56
# ...                        ...           ...           ...           ...
# ENSG00000285498.1            0             0             0             0
# ENSG00000285505.1            0             0             0             0
# ENSG00000285508.1            0             0             0             0
# ENSG00000285509.1            5             0             6             4
# ENSG00000285513.1            0             0             0             0
#
#                     IGT_counts.4  IGT_counts.5  IGT_counts.6  IGT_counts.7  \
# ensembl
# ENSG00000000003.14           183           113           341           377
# ENSG00000000005.5              2             0             0             2
# ENSG00000000419.12           606           686           597          1079
# ENSG00000000457.13           207           314           222           554
# ENSG00000000460.16            56            65            49            80
# ...                          ...           ...           ...           ...
# ENSG00000285498.1              0             0             0             0
# ENSG00000285505.1              0             0             0             0
# ENSG00000285508.1              0             0             0             0
# ENSG00000285509.1              0             7             1             2
# ENSG00000285513.1              0             0             0             0
#
#                     IGT_counts.8  IGT_counts.9  ...  T3cD_counts.25  \
# ensembl                                         ...
# ENSG00000000003.14           455           186  ...             311
# ENSG00000000005.5              0             0  ...               1
# ENSG00000000419.12           835           565  ...             914
# ENSG00000000457.13           320           170  ...             217
# ENSG00000000460.16            41            40  ...              55
# ...                          ...           ...  ...             ...
# ENSG00000285498.1              0             0  ...               0
# ENSG00000285505.1              0             0  ...               0
# ENSG00000285508.1              0             0  ...               0
# ENSG00000285509.1              5             0  ...               5
# ENSG00000285513.1              0             0  ...               0
#
#                     T3cD_counts.26  T3cD_counts.27  T3cD_counts.28  \
# ensembl
# ENSG00000000003.14             638             884             631
# ENSG00000000005.5                0               3               0
# ENSG00000000419.12            1365            1092            1208
# ENSG00000000457.13             335             374             348
# ENSG00000000460.16              37              71              31
# ...                            ...             ...             ...
# ENSG00000285498.1                0               0               5
# ENSG00000285505.1                0               0               0
# ENSG00000285508.1                0               0               0
# ENSG00000285509.1               14               0               1
# ENSG00000285513.1                0               0               0
#
#                     T3cD_counts.29  T3cD_counts.30  T3cD_counts.31  \
# ensembl
# ENSG00000000003.14             973             717             285
# ENSG00000000005.5                0               0               4
# ENSG00000000419.12             882             868            1066
# ENSG00000000457.13             344             385             298
# ENSG00000000460.16              98             111              37
# ...                            ...             ...             ...
# ENSG00000285498.1                0               0               0
# ENSG00000285505.1                0               0               0
# ENSG00000285508.1                0               0               0
# ENSG00000285509.1               22               2               0
# ENSG00000285513.1                0               0               0
#
#                     T3cD_counts.32  T3cD_counts.33  T3cD_counts.34
# ensembl
# ENSG00000000003.14             619             422             412
# ENSG00000000005.5                7               0               0
# ENSG00000000419.12             940            1165            1060
# ENSG00000000457.13             304             366             306
# ENSG00000000460.16              24              59              64
# ...                            ...             ...             ...
# ENSG00000285498.1                0               0               0
# ENSG00000285505.1                0               0               0
# ENSG00000285508.1                0               0               0
# ENSG00000285509.1                3               2               8
# ENSG00000285513.1                0               0               0
#
# [58381 rows x 133 columns]

# %%
counts= counts[counts.sum(axis=1) > 0]
counts
# Out:
#                     IGT_counts  IGT_counts.1  IGT_counts.2  IGT_counts.3  \
# ensembl
# ENSG00000000003.14         438           118           567           342
# ENSG00000000005.5            0             0             1             7
# ENSG00000000419.12         518           570           892           558
# ENSG00000000457.13         249           308           285           351
# ENSG00000000460.16          43            32            43            56
# ...                        ...           ...           ...           ...
# ENSG00000285483.1            2             0             0             0
# ENSG00000285486.1            0             0             0             0
# ENSG00000285492.1            1             0             4            12
# ENSG00000285498.1            0             0             0             0
# ENSG00000285509.1            5             0             6             4
#
#                     IGT_counts.4  IGT_counts.5  IGT_counts.6  IGT_counts.7  \
# ensembl
# ENSG00000000003.14           183           113           341           377
# ENSG00000000005.5              2             0             0             2
# ENSG00000000419.12           606           686           597          1079
# ENSG00000000457.13           207           314           222           554
# ENSG00000000460.16            56            65            49            80
# ...                          ...           ...           ...           ...
# ENSG00000285483.1              0             0             0             2
# ENSG00000285486.1              0             0             0             0
# ENSG00000285492.1              0             0             2             2
# ENSG00000285498.1              0             0             0             0
# ENSG00000285509.1              0             7             1             2
#
#                     IGT_counts.8  IGT_counts.9  ...  T3cD_counts.25  \
# ensembl                                         ...
# ENSG00000000003.14           455           186  ...             311
# ENSG00000000005.5              0             0  ...               1
# ENSG00000000419.12           835           565  ...             914
# ENSG00000000457.13           320           170  ...             217
# ENSG00000000460.16            41            40  ...              55
# ...                          ...           ...  ...             ...
# ENSG00000285483.1              0             0  ...               0
# ENSG00000285486.1              1            25  ...               0
# ENSG00000285492.1              0             0  ...               1
# ENSG00000285498.1              0             0  ...               0
# ENSG00000285509.1              5             0  ...               5
#
#                     T3cD_counts.26  T3cD_counts.27  T3cD_counts.28  \
# ensembl
# ENSG00000000003.14             638             884             631
# ENSG00000000005.5                0               3               0
# ENSG00000000419.12            1365            1092            1208
# ENSG00000000457.13             335             374             348
# ENSG00000000460.16              37              71              31
# ...                            ...             ...             ...
# ENSG00000285483.1                0               0               0
# ENSG00000285486.1                0               0               0
# ENSG00000285492.1                8               0               6
# ENSG00000285498.1                0               0               5
# ENSG00000285509.1               14               0               1
#
#                     T3cD_counts.29  T3cD_counts.30  T3cD_counts.31  \
# ensembl
# ENSG00000000003.14             973             717             285
# ENSG00000000005.5                0               0               4
# ENSG00000000419.12             882             868            1066
# ENSG00000000457.13             344             385             298
# ENSG00000000460.16              98             111              37
# ...                            ...             ...             ...
# ENSG00000285483.1                0               0               0
# ENSG00000285486.1                0               0               0
# ENSG00000285492.1                0               5               8
# ENSG00000285498.1                0               0               0
# ENSG00000285509.1               22               2               0
#
#                     T3cD_counts.32  T3cD_counts.33  T3cD_counts.34
# ensembl
# ENSG00000000003.14             619             422             412
# ENSG00000000005.5                7               0               0
# ENSG00000000419.12             940            1165            1060
# ENSG00000000457.13             304             366             306
# ENSG00000000460.16              24              59              64
# ...                            ...             ...             ...
# ENSG00000285483.1                6               0               0
# ENSG00000285486.1                0               0               0
# ENSG00000285492.1                4               1               0
# ENSG00000285498.1                0               0               0
# ENSG00000285509.1                3               2               8
#
# [51914 rows x 133 columns]

# %%
counts=counts.T
counts
# Out:
# ensembl         ENSG00000000003.14  ENSG00000000005.5  ENSG00000000419.12  \
# IGT_counts                     438                  0                 518
# IGT_counts.1                   118                  0                 570
# IGT_counts.2                   567                  1                 892
# IGT_counts.3                   342                  7                 558
# IGT_counts.4                   183                  2                 606
# ...                            ...                ...                 ...
# T3cD_counts.30                 717                  0                 868
# T3cD_counts.31                 285                  4                1066
# T3cD_counts.32                 619                  7                 940
# T3cD_counts.33                 422                  0                1165
# T3cD_counts.34                 412                  0                1060
#
# ensembl         ENSG00000000457.13  ENSG00000000460.16  ENSG00000000938.12  \
# IGT_counts                     249                  43                   2
# IGT_counts.1                   308                  32                   2
# IGT_counts.2                   285                  43                  63
# IGT_counts.3                   351                  56                   0
# IGT_counts.4                   207                  56                   0
# ...                            ...                 ...                 ...
# T3cD_counts.30                 385                 111                  26
# T3cD_counts.31                 298                  37                  44
# T3cD_counts.32                 304                  24                  25
# T3cD_counts.33                 366                  59                 205
# T3cD_counts.34                 306                  64                  15
#
# ensembl         ENSG00000000971.15  ENSG00000001036.13  ENSG00000001084.11  \
# IGT_counts                     283                 426                 324
# IGT_counts.1                   186                 426                 471
# IGT_counts.2                  1287                1011                 446
# IGT_counts.3                   130                 516                 369
# IGT_counts.4                    57                 525                 396
# ...                            ...                 ...                 ...
# T3cD_counts.30                2456                 856                 455
# T3cD_counts.31                 571                 807                 393
# T3cD_counts.32                1080                 802                 366
# T3cD_counts.33                1011                1082                 475
# T3cD_counts.34                1217                1054                 857
#
# ensembl         ENSG00000001167.14  ...  ENSG00000285467.1  ENSG00000285471.1  \
# IGT_counts                     252  ...                  1                  0
# IGT_counts.1                   236  ...                  0                  0
# IGT_counts.2                   237  ...                  1                  0
# IGT_counts.3                   250  ...                 23                  0
# IGT_counts.4                   251  ...                  7                  0
# ...                            ...  ...                ...                ...
# T3cD_counts.30                 345  ...                  0                  0
# T3cD_counts.31                 278  ...                  8                  0
# T3cD_counts.32                 172  ...                  0                  0
# T3cD_counts.33                 332  ...                  1                  0
# T3cD_counts.34                 478  ...                  3                  0
#
# ensembl         ENSG00000285473.1  ENSG00000285476.1  ENSG00000285480.1  \
# IGT_counts                      0                 18                  1
# IGT_counts.1                    0                 14                  0
# IGT_counts.2                    0                  5                  0
# IGT_counts.3                    0                  2                  0
# IGT_counts.4                    0                  0                  0
# ...                           ...                ...                ...
# T3cD_counts.30                  0                 22                  0
# T3cD_counts.31                  0                135                  0
# T3cD_counts.32                  0                 71                  0
# T3cD_counts.33                  0                  2                  0
# T3cD_counts.34                  0                 64                  0
#
# ensembl         ENSG00000285483.1  ENSG00000285486.1  ENSG00000285492.1  \
# IGT_counts                      2                  0                  1
# IGT_counts.1                    0                  0                  0
# IGT_counts.2                    0                  0                  4
# IGT_counts.3                    0                  0                 12
# IGT_counts.4                    0                  0                  0
# ...                           ...                ...                ...
# T3cD_counts.30                  0                  0                  5
# T3cD_counts.31                  0                  0                  8
# T3cD_counts.32                  6                  0                  4
# T3cD_counts.33                  0                  0                  1
# T3cD_counts.34                  0                  0                  0
#
# ensembl         ENSG00000285498.1  ENSG00000285509.1
# IGT_counts                      0                  5
# IGT_counts.1                    0                  0
# IGT_counts.2                    0                  6
# IGT_counts.3                    0                  4
# IGT_counts.4                    0                  0
# ...                           ...                ...
# T3cD_counts.30                  0                  2
# T3cD_counts.31                  0                  0
# T3cD_counts.32                  0                  3
# T3cD_counts.33                  0                  2
# T3cD_counts.34                  0                  8
#
# [133 rows x 51914 columns]

# %%
counts.columns = [col.split('.')[0] for col in counts.columns]
counts
# Out:
#                 ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# IGT_counts                  438                0              518
# IGT_counts.1                118                0              570
# IGT_counts.2                567                1              892
# IGT_counts.3                342                7              558
# IGT_counts.4                183                2              606
# ...                         ...              ...              ...
# T3cD_counts.30              717                0              868
# T3cD_counts.31              285                4             1066
# T3cD_counts.32              619                7              940
# T3cD_counts.33              422                0             1165
# T3cD_counts.34              412                0             1060
#
#                 ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# IGT_counts                  249               43                2
# IGT_counts.1                308               32                2
# IGT_counts.2                285               43               63
# IGT_counts.3                351               56                0
# IGT_counts.4                207               56                0
# ...                         ...              ...              ...
# T3cD_counts.30              385              111               26
# T3cD_counts.31              298               37               44
# T3cD_counts.32              304               24               25
# T3cD_counts.33              366               59              205
# T3cD_counts.34              306               64               15
#
#                 ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# IGT_counts                  283              426              324
# IGT_counts.1                186              426              471
# IGT_counts.2               1287             1011              446
# IGT_counts.3                130              516              369
# IGT_counts.4                 57              525              396
# ...                         ...              ...              ...
# T3cD_counts.30             2456              856              455
# T3cD_counts.31              571              807              393
# T3cD_counts.32             1080              802              366
# T3cD_counts.33             1011             1082              475
# T3cD_counts.34             1217             1054              857
#
#                 ENSG00000001167  ...  ENSG00000285467  ENSG00000285471  \
# IGT_counts                  252  ...                1                0
# IGT_counts.1                236  ...                0                0
# IGT_counts.2                237  ...                1                0
# IGT_counts.3                250  ...               23                0
# IGT_counts.4                251  ...                7                0
# ...                         ...  ...              ...              ...
# T3cD_counts.30              345  ...                0                0
# T3cD_counts.31              278  ...                8                0
# T3cD_counts.32              172  ...                0                0
# T3cD_counts.33              332  ...                1                0
# T3cD_counts.34              478  ...                3                0
#
#                 ENSG00000285473  ENSG00000285476  ENSG00000285480  \
# IGT_counts                    0               18                1
# IGT_counts.1                  0               14                0
# IGT_counts.2                  0                5                0
# IGT_counts.3                  0                2                0
# IGT_counts.4                  0                0                0
# ...                         ...              ...              ...
# T3cD_counts.30                0               22                0
# T3cD_counts.31                0              135                0
# T3cD_counts.32                0               71                0
# T3cD_counts.33                0                2                0
# T3cD_counts.34                0               64                0
#
#                 ENSG00000285483  ENSG00000285486  ENSG00000285492  \
# IGT_counts                    2                0                1
# IGT_counts.1                  0                0                0
# IGT_counts.2                  0                0                4
# IGT_counts.3                  0                0               12
# IGT_counts.4                  0                0                0
# ...                         ...              ...              ...
# T3cD_counts.30                0                0                5
# T3cD_counts.31                0                0                8
# T3cD_counts.32                6                0                4
# T3cD_counts.33                0                0                1
# T3cD_counts.34                0                0                0
#
#                 ENSG00000285498  ENSG00000285509
# IGT_counts                    0                5
# IGT_counts.1                  0                0
# IGT_counts.2                  0                6
# IGT_counts.3                  0                4
# IGT_counts.4                  0                0
# ...                         ...              ...
# T3cD_counts.30                0                2
# T3cD_counts.31                0                0
# T3cD_counts.32                0                3
# T3cD_counts.33                0                2
# T3cD_counts.34                0                8
#
# [133 rows x 51914 columns]

# %%
conditions = ['IGT'] * 41 + ['ND'] * 18 + ['T2D'] * 39 + ['T3cD'] * 35

# Crear un nuevo DataFrame basado en el DataFrame original
metadata = pd.DataFrame(zip(counts.index, conditions), columns=['Sample', 'condition'])
metadata
# Out:
#              Sample condition
# 0        IGT_counts       IGT
# 1      IGT_counts.1       IGT
# 2      IGT_counts.2       IGT
# 3      IGT_counts.3       IGT
# 4      IGT_counts.4       IGT
# ..              ...       ...
# 128  T3cD_counts.30      T3cD
# 129  T3cD_counts.31      T3cD
# 130  T3cD_counts.32      T3cD
# 131  T3cD_counts.33      T3cD
# 132  T3cD_counts.34      T3cD
#
# [133 rows x 2 columns]

# %%
metadata=metadata.set_index('Sample')
metadata
# Out:
#                condition
# Sample
# IGT_counts           IGT
# IGT_counts.1         IGT
# IGT_counts.2         IGT
# IGT_counts.3         IGT
# IGT_counts.4         IGT
# ...                  ...
# T3cD_counts.30      T3cD
# T3cD_counts.31      T3cD
# T3cD_counts.32      T3cD
# T3cD_counts.33      T3cD
# T3cD_counts.34      T3cD
#
# [133 rows x 1 columns]

# %%
from pydeseq2.dds import DeseqDataSet
dds = DeseqDataSet(counts=counts,metadata=metadata,design_factors="condition")
dds
# Out:
# AnnData object with n_obs × n_vars = 133 × 51914
#     obs: 'condition'
#     obsm: 'design_matrix'

# %%
dds.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.46 seconds.
#
# Fitting dispersions...
# ... done in 9.99 seconds.
#
# Fitting dispersion trend curve...
# ... done in 1.22 seconds.
#
# Fitting MAP dispersions...
# ... done in 11.49 seconds.
#
# Fitting LFCs...
# ... done in 7.57 seconds.
#
# Replacing 962 outlier genes.
#
# Fitting dispersions...
# ... done in 0.26 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.24 seconds.
#
# Fitting LFCs...
# ... done in 0.23 seconds.

# %%
dds
# Out:
# AnnData object with n_obs × n_vars = 133 × 51914
#     obs: 'condition'
#     uns: 'trend_coeffs', 'disp_function_type', '_squared_logres', 'prior_disp_var'
#     obsm: 'design_matrix', 'size_factors', 'replaceable'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'refitted'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks'

# %%
from pydeseq2.default_inference import DefaultInference
inference = DefaultInference(n_cpus=8)

# %%
stat_res=DeseqStats(dds, inference=inference, contrast=('condition','ND','T2D'))
stat_res.summary()
# Out:
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition ND vs T2D
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  423.168518       -0.481972  0.196593 -2.451616  0.014222
# ENSG00000000005    1.951471        0.168038  1.062234  0.158193  0.874305
# ENSG00000000419  728.822488        0.132445  0.110622  1.197274  0.231200
# ENSG00000000457  264.608717        0.127863  0.099369  1.286743  0.198184
# ENSG00000000460   54.177897        0.430646  0.190799  2.257067  0.024004
# ...                     ...             ...       ...       ...       ...
# ENSG00000285483    0.371292        0.406132  1.514685  0.268130  0.788600
# ENSG00000285486    0.971617        0.700816  1.319483  0.531129  0.595329
# ENSG00000285492    2.618170       -0.878835  0.799561 -1.099147  0.271704
# ENSG00000285498    0.111417        0.119636  3.907557  0.030617  0.975575
# ENSG00000285509    4.444022        0.335369  0.580373  0.577850  0.563366
#
#                      padj
# ENSG00000000003  0.081520
# ENSG00000000005       NaN
# ENSG00000000419  0.446008
# ENSG00000000457  0.406174
# ENSG00000000460  0.112024
# ...                   ...
# ENSG00000285483       NaN
# ENSG00000285486       NaN
# ENSG00000285492       NaN
# ENSG00000285498       NaN
# ENSG00000285509  0.745283
#
# [51914 rows x 6 columns]
# ... done in 3.57 seconds.

# %%
res =stat_res.results_df
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  423.168518       -0.481972  0.196593 -2.451616  0.014222
# ENSG00000000005    1.951471        0.168038  1.062234  0.158193  0.874305
# ENSG00000000419  728.822488        0.132445  0.110622  1.197274  0.231200
# ENSG00000000457  264.608717        0.127863  0.099369  1.286743  0.198184
# ENSG00000000460   54.177897        0.430646  0.190799  2.257067  0.024004
# ...                     ...             ...       ...       ...       ...
# ENSG00000285483    0.371292        0.406132  1.514685  0.268130  0.788600
# ENSG00000285486    0.971617        0.700816  1.319483  0.531129  0.595329
# ENSG00000285492    2.618170       -0.878835  0.799561 -1.099147  0.271704
# ENSG00000285498    0.111417        0.119636  3.907557  0.030617  0.975575
# ENSG00000285509    4.444022        0.335369  0.580373  0.577850  0.563366
#
#                      padj
# ENSG00000000003  0.081520
# ENSG00000000005       NaN
# ENSG00000000419  0.446008
# ENSG00000000457  0.406174
# ENSG00000000460  0.112024
# ...                   ...
# ENSG00000285483       NaN
# ENSG00000285486       NaN
# ENSG00000285492       NaN
# ENSG00000285498       NaN
# ENSG00000285509  0.745283
#
# [51914 rows x 6 columns]

# %%
from sanbomics.tools import id_map

# %%
mapper = id_map(species='human')

# %%
res['Symbol'] = res.index.map(mapper.mapper)

# %%
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  423.168518       -0.481972  0.196593 -2.451616  0.014222
# ENSG00000000005    1.951471        0.168038  1.062234  0.158193  0.874305
# ENSG00000000419  728.822488        0.132445  0.110622  1.197274  0.231200
# ENSG00000000457  264.608717        0.127863  0.099369  1.286743  0.198184
# ENSG00000000460   54.177897        0.430646  0.190799  2.257067  0.024004
# ...                     ...             ...       ...       ...       ...
# ENSG00000285483    0.371292        0.406132  1.514685  0.268130  0.788600
# ENSG00000285486    0.971617        0.700816  1.319483  0.531129  0.595329
# ENSG00000285492    2.618170       -0.878835  0.799561 -1.099147  0.271704
# ENSG00000285498    0.111417        0.119636  3.907557  0.030617  0.975575
# ENSG00000285509    4.444022        0.335369  0.580373  0.577850  0.563366
#
#                      padj       Symbol
# ENSG00000000003  0.081520       TSPAN6
# ENSG00000000005       NaN         TNMD
# ENSG00000000419  0.446008         DPM1
# ENSG00000000457  0.406174        SCYL3
# ENSG00000000460  0.112024     C1orf112
# ...                   ...          ...
# ENSG00000285483       NaN   AL590381.1
# ENSG00000285486       NaN   AC003043.2
# ENSG00000285492       NaN   AL356417.3
# ENSG00000285498       NaN          NaN
# ENSG00000285509  0.745283  TBCEL-TECTA
#
# [51914 rows x 7 columns]

# %%
res=res[res.baseMean>= 10]
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  423.168518       -0.481972  0.196593 -2.451616  0.014222
# ENSG00000000419  728.822488        0.132445  0.110622  1.197274  0.231200
# ENSG00000000457  264.608717        0.127863  0.099369  1.286743  0.198184
# ENSG00000000460   54.177897        0.430646  0.190799  2.257067  0.024004
# ENSG00000000938   20.869001       -1.131127  0.462904 -2.443546  0.014544
# ...                     ...             ...       ...       ...       ...
# ENSG00000285410  181.797094       -0.260386  0.133914 -1.944431  0.051844
# ENSG00000285417   12.508412       -0.761434  0.374819 -2.031469  0.042207
# ENSG00000285437   17.435526       -0.165695  0.278002 -0.596021  0.551161
# ENSG00000285458   10.527549       -0.240349  0.218792 -1.098527  0.271974
# ENSG00000285476   36.690945        0.040974  0.352739  0.116160  0.907526
#
#                      padj      Symbol
# ENSG00000000003  0.081520      TSPAN6
# ENSG00000000419  0.446008        DPM1
# ENSG00000000457  0.406174       SCYL3
# ENSG00000000460  0.112024    C1orf112
# ENSG00000000938  0.082714         FGR
# ...                   ...         ...
# ENSG00000285410  0.179600  GABPB1-IT1
# ENSG00000285417  0.158327         NaN
# ENSG00000285437  0.737077     POLR2J3
# ENSG00000285458  0.492466         NaN
# ENSG00000285476  0.954326         NaN
#
# [17665 rows x 7 columns]

# %%
sigs =res[(res.padj < 0.05) & (abs(res.log2FoldChange) > 0.5)]
sigs
# Out:
#                     baseMean  log2FoldChange     lfcSE      stat  \
# ENSG00000000971   487.112674       -1.092121  0.380544 -2.869891
# ENSG00000002726    21.497832       -1.247520  0.429037 -2.907723
# ENSG00000002933  1150.136502       -0.731038  0.179913 -4.063279
# ENSG00000003096    57.970247       -0.959573  0.306619 -3.129529
# ENSG00000004059   661.192629        0.526424  0.160234  3.285336
# ...                      ...             ...       ...       ...
# ENSG00000284642    19.805269       -0.653811  0.239076 -2.734741
# ENSG00000284653    19.710489       -5.789334  0.707370 -8.184310
# ENSG00000284691    43.143609       -0.703086  0.197759 -3.555264
# ENSG00000285103    42.789607       -0.794425  0.254154 -3.125765
# ENSG00000285280    12.820467       -0.860969  0.304847 -2.824271
#
#                        pvalue          padj      Symbol
# ENSG00000000971  4.106133e-03  3.872191e-02         CFH
# ENSG00000002726  3.640705e-03  3.608136e-02        AOC1
# ENSG00000002933  4.838807e-05  2.415399e-03    TMEM176A
# ENSG00000003096  1.750868e-03  2.258694e-02      KLHL13
# ENSG00000004059  1.018608e-03  1.643799e-02        ARF5
# ...                       ...           ...         ...
# ENSG00000284642  6.242946e-03  4.985632e-02  AL139424.2
# ENSG00000284653  2.738679e-16  1.982256e-12  AL357509.1
# ENSG00000284691  3.775991e-04  9.181620e-03  AC073111.4
# ENSG00000285103  1.773432e-03  2.274560e-02  AL451123.1
# ENSG00000285280  4.738827e-03  4.213714e-02  AL390957.1
#
# [1285 rows x 7 columns]

# %%
import scanpy as sc

# %%
#PCA
sc.tl.pca(dds)
sc.pl.pca(dds, color='condition',size=200)

# %%
#GSEA
import gseapy as gp
from gseapy.plot import gseaplot

# %%
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  423.168518       -0.481972  0.196593 -2.451616  0.014222
# ENSG00000000419  728.822488        0.132445  0.110622  1.197274  0.231200
# ENSG00000000457  264.608717        0.127863  0.099369  1.286743  0.198184
# ENSG00000000460   54.177897        0.430646  0.190799  2.257067  0.024004
# ENSG00000000938   20.869001       -1.131127  0.462904 -2.443546  0.014544
# ...                     ...             ...       ...       ...       ...
# ENSG00000285410  181.797094       -0.260386  0.133914 -1.944431  0.051844
# ENSG00000285417   12.508412       -0.761434  0.374819 -2.031469  0.042207
# ENSG00000285437   17.435526       -0.165695  0.278002 -0.596021  0.551161
# ENSG00000285458   10.527549       -0.240349  0.218792 -1.098527  0.271974
# ENSG00000285476   36.690945        0.040974  0.352739  0.116160  0.907526
#
#                      padj      Symbol
# ENSG00000000003  0.081520      TSPAN6
# ENSG00000000419  0.446008        DPM1
# ENSG00000000457  0.406174       SCYL3
# ENSG00000000460  0.112024    C1orf112
# ENSG00000000938  0.082714         FGR
# ...                   ...         ...
# ENSG00000285410  0.179600  GABPB1-IT1
# ENSG00000285417  0.158327         NaN
# ENSG00000285437  0.737077     POLR2J3
# ENSG00000285458  0.492466         NaN
# ENSG00000285476  0.954326         NaN
#
# [17665 rows x 7 columns]

# %%
ranking = res[['Symbol', 'stat']].dropna().sort_values('stat', ascending = False)
ranking
# Out:
#                      Symbol      stat
# ENSG00000081181        ARG2  8.948774
# ENSG00000145907       G3BP1  8.356582
# ENSG00000163581      SLC2A2  8.140868
# ENSG00000127870        RNF6  7.591096
# ENSG00000165195        PIGA  7.461532
# ...                     ...       ...
# ENSG00000170509    HSD17B13 -6.972711
# ENSG00000050165        DKK3 -6.977280
# ENSG00000136872       ALDOB -7.573799
# ENSG00000069424      KCNAB2 -7.950458
# ENSG00000284653  AL357509.1 -8.184310
#
# [17142 rows x 2 columns]

# %%
ranking=ranking.drop_duplicates('Symbol')
ranking
# Out:
#                      Symbol      stat
# ENSG00000081181        ARG2  8.948774
# ENSG00000145907       G3BP1  8.356582
# ENSG00000163581      SLC2A2  8.140868
# ENSG00000127870        RNF6  7.591096
# ENSG00000165195        PIGA  7.461532
# ...                     ...       ...
# ENSG00000170509    HSD17B13 -6.972711
# ENSG00000050165        DKK3 -6.977280
# ENSG00000136872       ALDOB -7.573799
# ENSG00000069424      KCNAB2 -7.950458
# ENSG00000284653  AL357509.1 -8.184310
#
# [17139 rows x 2 columns]

# %%
manual_set = {'things':['ARG2','G3BP1','SLC2A2','RNF6','PIGA']}
manual_set
# Out:
# {'things': ['ARG2', 'G3BP1', 'SLC2A2', 'RNF6', 'PIGA']}

# %%
gp.get_library_name()
# Out:
# ['ARCHS4_Cell-lines',
#  'ARCHS4_IDG_Coexp',
#  'ARCHS4_Kinases_Coexp',
#  'ARCHS4_TFs_Coexp',
#  'ARCHS4_Tissues',
#  'Achilles_fitness_decrease',
#  'Achilles_fitness_increase',
#  'Aging_Perturbations_from_GEO_down',
#  'Aging_Perturbations_from_GEO_up',
#  'Allen_Brain_Atlas_10x_scRNA_2021',
#  'Allen_Brain_Atlas_down',
#  'Allen_Brain_Atlas_up',
#  'Azimuth_2023',
#  'Azimuth_Cell_Types_2021',
#  'BioCarta_2013',
#  'BioCarta_2015',
#  'BioCarta_2016',
#  'BioPlanet_2019',
#  'BioPlex_2017',
#  'CCLE_Proteomics_2020',
#  'CORUM',
#  'COVID-19_Related_Gene_Sets',
#  'COVID-19_Related_Gene_Sets_2021',
#  'Cancer_Cell_Line_Encyclopedia',
#  'CellMarker_2024',
#  'CellMarker_Augmented_2021',
#  'ChEA_2013',
#  'ChEA_2015',
#  'ChEA_2016',
#  'ChEA_2022',
#  'Chromosome_Location',
#  'Chromosome_Location_hg19',
#  'ClinVar_2019',
#  'DSigDB',
#  'Data_Acquisition_Method_Most_Popular_Genes',
#  'DepMap_WG_CRISPR_Screens_Broad_CellLines_2019',
#  'DepMap_WG_CRISPR_Screens_Sanger_CellLines_2019',
#  'Descartes_Cell_Types_and_Tissue_2021',
#  'Diabetes_Perturbations_GEO_2022',
#  'DisGeNET',
#  'Disease_Perturbations_from_GEO_down',
#  'Disease_Perturbations_from_GEO_up',
#  'Disease_Signatures_from_GEO_down_2014',
#  'Disease_Signatures_from_GEO_up_2014',
#  'DrugMatrix',
#  'Drug_Perturbations_from_GEO_2014',
#  'Drug_Perturbations_from_GEO_down',
#  'Drug_Perturbations_from_GEO_up',
#  'ENCODE_Histone_Modifications_2013',
#  'ENCODE_Histone_Modifications_2015',
#  'ENCODE_TF_ChIP-seq_2014',
#  'ENCODE_TF_ChIP-seq_2015',
#  'ENCODE_and_ChEA_Consensus_TFs_from_ChIP-X',
#  'ESCAPE',
#  'Elsevier_Pathway_Collection',
#  'Enrichr_Libraries_Most_Popular_Genes',
#  'Enrichr_Submissions_TF-Gene_Coocurrence',
#  'Enrichr_Users_Contributed_Lists_2020',
#  'Epigenomics_Roadmap_HM_ChIP-seq',
#  'FANTOM6_lncRNA_KD_DEGs',
#  'GO_Biological_Process_2013',
#  'GO_Biological_Process_2015',
#  'GO_Biological_Process_2017',
#  'GO_Biological_Process_2017b',
#  'GO_Biological_Process_2018',
#  'GO_Biological_Process_2021',
#  'GO_Biological_Process_2023',
#  'GO_Cellular_Component_2013',
#  'GO_Cellular_Component_2015',
#  'GO_Cellular_Component_2017',
#  'GO_Cellular_Component_2017b',
#  'GO_Cellular_Component_2018',
#  'GO_Cellular_Component_2021',
#  'GO_Cellular_Component_2023',
#  'GO_Molecular_Function_2013',
#  'GO_Molecular_Function_2015',
#  'GO_Molecular_Function_2017',
#  'GO_Molecular_Function_2017b',
#  'GO_Molecular_Function_2018',
#  'GO_Molecular_Function_2021',
#  'GO_Molecular_Function_2023',
#  'GTEx_Aging_Signatures_2021',
#  'GTEx_Tissue_Expression_Down',
#  'GTEx_Tissue_Expression_Up',
#  'GTEx_Tissues_V8_2023',
#  'GWAS_Catalog_2019',
#  'GWAS_Catalog_2023',
#  'GeDiPNet_2023',
#  'GeneSigDB',
#  'Gene_Perturbations_from_GEO_down',
#  'Gene_Perturbations_from_GEO_up',
#  'Genes_Associated_with_NIH_Grants',
#  'Genome_Browser_PWMs',
#  'GlyGen_Glycosylated_Proteins_2022',
#  'HDSigDB_Human_2021',
#  'HDSigDB_Mouse_2021',
#  'HMDB_Metabolites',
#  'HMS_LINCS_KinomeScan',
#  'HomoloGene',
#  'HuBMAP_ASCT_plus_B_augmented_w_RNAseq_Coexpression',
#  'HuBMAP_ASCTplusB_augmented_2022',
#  'HumanCyc_2015',
#  'HumanCyc_2016',
#  'Human_Gene_Atlas',
#  'Human_Phenotype_Ontology',
#  'IDG_Drug_Targets_2022',
#  'InterPro_Domains_2019',
#  'Jensen_COMPARTMENTS',
#  'Jensen_DISEASES',
#  'Jensen_TISSUES',
#  'KEA_2013',
#  'KEA_2015',
#  'KEGG_2013',
#  'KEGG_2015',
#  'KEGG_2016',
#  'KEGG_2019_Human',
#  'KEGG_2019_Mouse',
#  'KEGG_2021_Human',
#  'KOMP2_Mouse_Phenotypes_2022',
#  'Kinase_Perturbations_from_GEO_down',
#  'Kinase_Perturbations_from_GEO_up',
#  'L1000_Kinase_and_GPCR_Perturbations_down',
#  'L1000_Kinase_and_GPCR_Perturbations_up',
#  'LINCS_L1000_CRISPR_KO_Consensus_Sigs',
#  'LINCS_L1000_Chem_Pert_Consensus_Sigs',
#  'LINCS_L1000_Chem_Pert_down',
#  'LINCS_L1000_Chem_Pert_up',
#  'LINCS_L1000_Ligand_Perturbations_down',
#  'LINCS_L1000_Ligand_Perturbations_up',
#  'Ligand_Perturbations_from_GEO_down',
#  'Ligand_Perturbations_from_GEO_up',
#  'MAGMA_Drugs_and_Diseases',
#  'MAGNET_2023',
#  'MCF7_Perturbations_from_GEO_down',
#  'MCF7_Perturbations_from_GEO_up',
#  'MGI_Mammalian_Phenotype_2013',
#  'MGI_Mammalian_Phenotype_2017',
#  'MGI_Mammalian_Phenotype_Level_3',
#  'MGI_Mammalian_Phenotype_Level_4',
#  'MGI_Mammalian_Phenotype_Level_4_2019',
#  'MGI_Mammalian_Phenotype_Level_4_2021',
#  'MSigDB_Computational',
#  'MSigDB_Hallmark_2020',
#  'MSigDB_Oncogenic_Signatures',
#  'Metabolomics_Workbench_Metabolites_2022',
#  'Microbe_Perturbations_from_GEO_down',
#  'Microbe_Perturbations_from_GEO_up',
#  'MoTrPAC_2023',
#  'Mouse_Gene_Atlas',
#  'NCI-60_Cancer_Cell_Lines',
#  'NCI-Nature_2015',
#  'NCI-Nature_2016',
#  'NIH_Funded_PIs_2017_AutoRIF_ARCHS4_Predictions',
#  'NIH_Funded_PIs_2017_GeneRIF_ARCHS4_Predictions',
#  'NIH_Funded_PIs_2017_Human_AutoRIF',
#  'NIH_Funded_PIs_2017_Human_GeneRIF',
#  'NURSA_Human_Endogenous_Complexome',
#  'OMIM_Disease',
#  'OMIM_Expanded',
#  'Old_CMAP_down',
#  'Old_CMAP_up',
#  'Orphanet_Augmented_2021',
#  'PFOCR_Pathways',
#  'PFOCR_Pathways_2023',
#  'PPI_Hub_Proteins',
#  'PanglaoDB_Augmented_2021',
#  'Panther_2015',
#  'Panther_2016',
#  'Pfam_Domains_2019',
#  'Pfam_InterPro_Domains',
#  'PheWeb_2019',
#  'PhenGenI_Association_2021',
#  'Phosphatase_Substrates_from_DEPOD',
#  'ProteomicsDB_2020',
#  'Proteomics_Drug_Atlas_2023',
#  'RNA-Seq_Disease_Gene_and_Drug_Signatures_from_GEO',
#  'RNAseq_Automatic_GEO_Signatures_Human_Down',
#  'RNAseq_Automatic_GEO_Signatures_Human_Up',
#  'RNAseq_Automatic_GEO_Signatures_Mouse_Down',
#  'RNAseq_Automatic_GEO_Signatures_Mouse_Up',
#  'Rare_Diseases_AutoRIF_ARCHS4_Predictions',
#  'Rare_Diseases_AutoRIF_Gene_Lists',
#  'Rare_Diseases_GeneRIF_ARCHS4_Predictions',
#  'Rare_Diseases_GeneRIF_Gene_Lists',
#  'Reactome_2013',
#  'Reactome_2015',
#  'Reactome_2016',
#  'Reactome_2022',
#  'Rummagene_kinases',
#  'Rummagene_signatures',
#  'Rummagene_transcription_factors',
#  'SILAC_Phosphoproteomics',
#  'SubCell_BarCode',
#  'SynGO_2022',
#  'SynGO_2024',
#  'SysMyo_Muscle_Gene_Sets',
#  'TF-LOF_Expression_from_GEO',
#  'TF_Perturbations_Followed_by_Expression',
#  'TG_GATES_2020',
#  'TRANSFAC_and_JASPAR_PWMs',
#  'TRRUST_Transcription_Factors_2019',
#  'Table_Mining_of_CRISPR_Studies',
#  'Tabula_Muris',
#  'Tabula_Sapiens',
#  'TargetScan_microRNA',
#  'TargetScan_microRNA_2017',
#  'The_Kinase_Library_2023',
#  'Tissue_Protein_Expression_from_Human_Proteome_Map',
#  'Tissue_Protein_Expression_from_ProteomicsDB',
#  'Transcription_Factor_PPIs',
#  'UK_Biobank_GWAS_v1',
#  'Virus-Host_PPI_P-HIPSTer_2020',
#  'VirusMINT',
#  'Virus_Perturbations_from_GEO_down',
#  'Virus_Perturbations_from_GEO_up',
#  'WikiPathway_2021_Human',
#  'WikiPathway_2023_Human',
#  'WikiPathways_2013',
#  'WikiPathways_2015',
#  'WikiPathways_2016',
#  'WikiPathways_2019_Human',
#  'WikiPathways_2019_Mouse',
#  'dbGaP',
#  'huMAP',
#  'lncHUB_lncRNA_Co-Expression',
#  'miRTarBase_2017']

# %%
pre_res=gp.prerank(rnk=ranking,
                  gene_sets=['GO_Biological_Process_2023', manual_set],
                  seed=6, permutation_num=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 pre_res=gp.prerank(rnk=ranking,
#       2                   gene_sets=['GO_Biological_Process_2023', manual_set],
#       3                   seed=6, permutation_num=100)
#
# File ~\anaconda3\Lib\site-packages\gseapy\__init__.py:396, in prerank(rnk, gene_sets, outdir, pheno_pos, pheno_neg, min_size, max_size, permutation_num, weight, ascending, threads, figsize, format, graph_num, no_plot, seed, verbose, *arg, **kwargs)
#     375     weight = kwargs["weighted_score_type"]
#     377 pre = Prerank(
#     378     rnk,
#     379     gene_sets,
#    (...)
#     394     verbose,
#     395 )
# --> 396 pre.run()
#     397 return pre
#
# File ~\anaconda3\Lib\site-packages\gseapy\gsea.py:444, in Prerank.run(self)
#     441 assert self.min_size <= self.max_size
#     443 # parsing rankings
# --> 444 dat2 = self.load_ranking()
#     445 assert len(dat2) > 1
#     446 self.ranking = dat2
#
# File ~\anaconda3\Lib\site-packages\gseapy\gsea.py:418, in Prerank.load_ranking(self)
#     415 rank_metric = self._load_data(self.rnk)  # gene id is the first column
#     416 if rank_metric.select_dtypes(np.number).shape[1] == 1:
#     417     # return series
# --> 418     return self._load_ranking(rank_metric)
#     419 ## In case the input type multi-column ranking dataframe
#     420 # drop na gene id values
#     421 rank_metric = rank_metric.dropna(subset=rank_metric.columns[0])
#
# File ~\anaconda3\Lib\site-packages\gseapy\gsea.py:388, in Prerank._load_ranking(self, rank_metric)
#     386 # reset ranking index, because you have sort values and drop duplicates.
#     387 rank_metric.reset_index(drop=True, inplace=True)
# --> 388 rank_metric.columns = ["gene_name", "prerank"]
#     389 rankser = rank_metric.set_index("gene_name", drop=True).squeeze()
#     391 # check whether contains infinity values
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
#     726 This is called from the cython code when we set the `index` attribute
#     727 directly, e.g. `series.index = [1, 2, 3]`.
#     728 """
#     729 labels = ensure_index(labels)
# --> 730 self._mgr.set_axis(axis, labels)
#     731 self._clear_item_cache()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:225, in BaseBlockManager.set_axis(self, axis, new_labels)
#     223 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224     # Caller is responsible for ensuring we have an Index object.
# --> 225     self._validate_set_axis(axis, new_labels)
#     226     self.axes[axis] = new_labels
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 2 elements

# %%
import numpy as np
import seaborn as sns

# %%
dds.layers['normed_counts']
# Out:
# array([[5.51826897e+02, 0.00000000e+00, 6.52617197e+02, ...,
#         1.25987876e+00, 0.00000000e+00, 6.29939380e+00],
#        [1.18806387e+02, 0.00000000e+00, 5.73895259e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.67815215e+02, 8.25070926e-01, 7.35963266e+02, ...,
#         3.30028370e+00, 0.00000000e+00, 4.95042556e+00],
#        ...,
#        [5.37465542e+02, 6.07796251e+00, 8.16183537e+02, ...,
#         3.47312143e+00, 0.00000000e+00, 2.60484107e+00],
#        [3.20112451e+02, 0.00000000e+00, 8.83722761e+02, ...,
#         7.58560310e-01, 0.00000000e+00, 1.51712062e+00],
#        [3.14753487e+02, 0.00000000e+00, 8.09802662e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 6.11171820e+00]])

# %%
dds.layers['log1p']=np.log1p(dds.layers['normed_counts'])
dds
# Out:
# AnnData object with n_obs × n_vars = 133 × 51914
#     obs: 'condition'
#     uns: 'trend_coeffs', 'disp_function_type', '_squared_logres', 'prior_disp_var', 'pca', 'condition_colors'
#     obsm: 'design_matrix', 'size_factors', 'replaceable', 'X_pca'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'refitted', 'PCs'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks', 'log1p'

# %%
dds_sigs=dds[:, sigs.index]
dds_sigs.obs
# Out:
#                condition
# Sample
# IGT_counts           IGT
# IGT_counts.1         IGT
# IGT_counts.2         IGT
# IGT_counts.3         IGT
# IGT_counts.4         IGT
# ...                  ...
# T3cD_counts.30      T3cD
# T3cD_counts.31      T3cD
# T3cD_counts.32      T3cD
# T3cD_counts.33      T3cD
# T3cD_counts.34      T3cD
#
# [133 rows x 1 columns]

# %%
grapher=pd.DataFrame(dds_sigs.layers['log1p'].T,
                    index=dds_sigs.var_names, columns=dds_sigs.obs_names) #dataframe con los valores filtrados de mayor expression i con los valores transformados a log +1.
grapher
# Out:
# Sample           IGT_counts  IGT_counts.1  IGT_counts.2  IGT_counts.3  \
# ENSG00000000971    5.879263      5.237883      6.968725      4.725862
# ENSG00000002726    1.258392      1.797438      3.310626      3.542358
# ENSG00000002933    6.512897      6.761407      7.589359      6.657539
# ENSG00000003096    3.836343      3.644218      3.501880      3.437447
# ENSG00000004059    6.482522      6.922527      6.564893      7.108655
# ...                     ...           ...           ...           ...
# ENSG00000284642    2.855229      3.302396      3.073932      3.320226
# ENSG00000284653    2.698583      2.085403      0.000000      0.000000
# ENSG00000284691    3.216381      3.976974      3.836845      2.692151
# ENSG00000285103    3.357501      4.181093      3.938262      3.256024
# ENSG00000285280    1.798324      2.085403      2.310135      1.948975
#
# Sample           IGT_counts.4  IGT_counts.5  IGT_counts.6  IGT_counts.7  \
# ENSG00000000971      3.926414      2.538014      4.992398      6.167106
# ENSG00000002726      2.439593      3.582506      2.605580      3.437978
# ENSG00000002933      7.114900      6.310695      6.885513      6.740538
# ENSG00000003096      2.645143      2.396948      3.539147      4.641796
# ENSG00000004059      7.176770      7.129991      6.561551      6.475512
# ...                       ...           ...           ...           ...
# ENSG00000284642      0.000000      3.156003      3.133030      1.857370
# ENSG00000284653      0.627202      2.035976      0.000000      0.000000
# ENSG00000284691      3.088163      2.318175      3.409755      3.185207
# ENSG00000285103      3.909067      3.432979      3.756466      3.980127
# ENSG00000285280      0.000000      1.641387      2.117996      1.408456
#
# Sample           IGT_counts.8  IGT_counts.9  ...  T3cD_counts.25  \
# ENSG00000000971      5.969111      3.696265  ...        6.003987
# ENSG00000002726      3.117206      0.000000  ...        2.846649
# ENSG00000002933      6.858902      6.586225  ...        6.352932
# ENSG00000003096      3.602648      4.727344  ...        3.281897
# ENSG00000004059      6.962325      7.020178  ...        5.579542
# ...                       ...           ...  ...             ...
# ENSG00000284642      3.079755      2.816522  ...        2.685622
# ENSG00000284653      2.033526      0.000000  ...        2.161928
# ENSG00000284691      3.646899      2.622592  ...        4.093350
# ENSG00000285103      3.877783      3.350169  ...        3.457940
# ENSG00000285280      2.033526      1.930721  ...        3.535557
#
# Sample           T3cD_counts.26  T3cD_counts.27  T3cD_counts.28  \
# ENSG00000000971        6.183067        7.278085        6.579641
# ENSG00000002726        2.142992        3.829222        3.039021
# ENSG00000002933        7.123454        7.389103        7.027217
# ENSG00000003096        4.164098        4.073123        3.656163
# ENSG00000004059        6.168727        6.091902        6.077005
# ...                         ...             ...             ...
# ENSG00000284642        2.775697        2.354709        2.819632
# ENSG00000284653        1.058216        2.537971        3.932899
# ENSG00000284691        3.971184        3.895997        3.946240
# ENSG00000285103        3.261285        3.732631        3.162412
# ENSG00000285280        2.142992        2.248722        1.869562
#
# Sample           T3cD_counts.29  T3cD_counts.30  T3cD_counts.31  \
# ENSG00000000971        7.070359        7.467107        6.109560
# ENSG00000002726        2.646700        4.034802        3.350974
# ENSG00000002933        7.039244        7.158232        6.987080
# ENSG00000003096        4.972325        4.660188        3.550283
# ENSG00000004059        6.391192        6.242831        6.637522
# ...                         ...             ...             ...
# ENSG00000284642        2.646700        3.227088        2.345551
# ENSG00000284653        3.519528        3.475859        0.000000
# ENSG00000284691        3.847504        3.041397        3.907378
# ENSG00000285103        4.066372        3.710370        2.989616
# ENSG00000285280        2.945632        2.676006        1.422227
#
# Sample           T3cD_counts.32  T3cD_counts.33  T3cD_counts.34
# ENSG00000000971        6.844542        6.643665        6.835985
# ENSG00000002726        4.836539        4.554524        2.241094
# ENSG00000002933        7.689643        7.006647        6.752126
# ENSG00000003096        3.551424        2.575430        4.165255
# ENSG00000004059        5.884992        6.231420        5.676995
# ...                         ...             ...             ...
# ENSG00000284642        3.083685        2.829073        3.037981
# ENSG00000284653        0.000000        2.993931        1.719868
# ENSG00000284691        3.473769        3.772287        3.236593
# ENSG00000285103        3.389572        3.601477        3.813527
# ENSG00000285280        2.435311        2.735188        2.581991
#
# [1285 rows x 133 columns]

# %%
sns.clustermap(grapher, z_score=0, cmap='RdYlBu_r')
# Out:
# C:\Users\NOE\anaconda3\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# C:\Users\NOE\anaconda3\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
#VolcanoPlot:
from sanbomics.plots import volcano

# %%
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  423.168518       -0.481972  0.196593 -2.451616  0.014222
# ENSG00000000419  728.822488        0.132445  0.110622  1.197274  0.231200
# ENSG00000000457  264.608717        0.127863  0.099369  1.286743  0.198184
# ENSG00000000460   54.177897        0.430646  0.190799  2.257067  0.024004
# ENSG00000000938   20.869001       -1.131127  0.462904 -2.443546  0.014544
# ...                     ...             ...       ...       ...       ...
# ENSG00000285410  181.797094       -0.260386  0.133914 -1.944431  0.051844
# ENSG00000285417   12.508412       -0.761434  0.374819 -2.031469  0.042207
# ENSG00000285437   17.435526       -0.165695  0.278002 -0.596021  0.551161
# ENSG00000285458   10.527549       -0.240349  0.218792 -1.098527  0.271974
# ENSG00000285476   36.690945        0.040974  0.352739  0.116160  0.907526
#
#                      padj      Symbol
# ENSG00000000003  0.081520      TSPAN6
# ENSG00000000419  0.446008        DPM1
# ENSG00000000457  0.406174       SCYL3
# ENSG00000000460  0.112024    C1orf112
# ENSG00000000938  0.082714         FGR
# ...                   ...         ...
# ENSG00000285410  0.179600  GABPB1-IT1
# ENSG00000285417  0.158327         NaN
# ENSG00000285437  0.737077     POLR2J3
# ENSG00000285458  0.492466         NaN
# ENSG00000285476  0.954326         NaN
#
# [17665 rows x 7 columns]

# %%
volcano(res, symbol='Symbol')

# %%
grapher
grapher.index=grapher.index.map(mapper.mapper)
grapher
# Out:
# Sample      IGT_counts  IGT_counts.1  IGT_counts.2  IGT_counts.3  \
# CFH           5.879263      5.237883      6.968725      4.725862
# AOC1          1.258392      1.797438      3.310626      3.542358
# TMEM176A      6.512897      6.761407      7.589359      6.657539
# KLHL13        3.836343      3.644218      3.501880      3.437447
# ARF5          6.482522      6.922527      6.564893      7.108655
# ...                ...           ...           ...           ...
# AL139424.2    2.855229      3.302396      3.073932      3.320226
# AL357509.1    2.698583      2.085403      0.000000      0.000000
# AC073111.4    3.216381      3.976974      3.836845      2.692151
# AL451123.1    3.357501      4.181093      3.938262      3.256024
# AL390957.1    1.798324      2.085403      2.310135      1.948975
#
# Sample      IGT_counts.4  IGT_counts.5  IGT_counts.6  IGT_counts.7  \
# CFH             3.926414      2.538014      4.992398      6.167106
# AOC1            2.439593      3.582506      2.605580      3.437978
# TMEM176A        7.114900      6.310695      6.885513      6.740538
# KLHL13          2.645143      2.396948      3.539147      4.641796
# ARF5            7.176770      7.129991      6.561551      6.475512
# ...                  ...           ...           ...           ...
# AL139424.2      0.000000      3.156003      3.133030      1.857370
# AL357509.1      0.627202      2.035976      0.000000      0.000000
# AC073111.4      3.088163      2.318175      3.409755      3.185207
# AL451123.1      3.909067      3.432979      3.756466      3.980127
# AL390957.1      0.000000      1.641387      2.117996      1.408456
#
# Sample      IGT_counts.8  IGT_counts.9  ...  T3cD_counts.25  T3cD_counts.26  \
# CFH             5.969111      3.696265  ...        6.003987        6.183067
# AOC1            3.117206      0.000000  ...        2.846649        2.142992
# TMEM176A        6.858902      6.586225  ...        6.352932        7.123454
# KLHL13          3.602648      4.727344  ...        3.281897        4.164098
# ARF5            6.962325      7.020178  ...        5.579542        6.168727
# ...                  ...           ...  ...             ...             ...
# AL139424.2      3.079755      2.816522  ...        2.685622        2.775697
# AL357509.1      2.033526      0.000000  ...        2.161928        1.058216
# AC073111.4      3.646899      2.622592  ...        4.093350        3.971184
# AL451123.1      3.877783      3.350169  ...        3.457940        3.261285
# AL390957.1      2.033526      1.930721  ...        3.535557        2.142992
#
# Sample      T3cD_counts.27  T3cD_counts.28  T3cD_counts.29  T3cD_counts.30  \
# CFH               7.278085        6.579641        7.070359        7.467107
# AOC1              3.829222        3.039021        2.646700        4.034802
# TMEM176A          7.389103        7.027217        7.039244        7.158232
# KLHL13            4.073123        3.656163        4.972325        4.660188
# ARF5              6.091902        6.077005        6.391192        6.242831
# ...                    ...             ...             ...             ...
# AL139424.2        2.354709        2.819632        2.646700        3.227088
# AL357509.1        2.537971        3.932899        3.519528        3.475859
# AC073111.4        3.895997        3.946240        3.847504        3.041397
# AL451123.1        3.732631        3.162412        4.066372        3.710370
# AL390957.1        2.248722        1.869562        2.945632        2.676006
#
# Sample      T3cD_counts.31  T3cD_counts.32  T3cD_counts.33  T3cD_counts.34
# CFH               6.109560        6.844542        6.643665        6.835985
# AOC1              3.350974        4.836539        4.554524        2.241094
# TMEM176A          6.987080        7.689643        7.006647        6.752126
# KLHL13            3.550283        3.551424        2.575430        4.165255
# ARF5              6.637522        5.884992        6.231420        5.676995
# ...                    ...             ...             ...             ...
# AL139424.2        2.345551        3.083685        2.829073        3.037981
# AL357509.1        0.000000        0.000000        2.993931        1.719868
# AC073111.4        3.907378        3.473769        3.772287        3.236593
# AL451123.1        2.989616        3.389572        3.601477        3.813527
# AL390957.1        1.422227        2.435311        2.735188        2.581991
#
# [1285 rows x 133 columns]

# %%
grapher.index
# Out:
# Index([       'CFH',       'AOC1',   'TMEM176A',     'KLHL13',       'ARF5',
#            'PLXND1',        'ARX',     'RPUSD1',      'CYTH3',       'MPND',
#        ...
#                 nan, 'AL645929.2',  'HSP90AB4P',     'PRNCR1', 'AP002851.1',
#        'AL139424.2', 'AL357509.1', 'AC073111.4', 'AL451123.1', 'AL390957.1'],
#       dtype='object', length=1285)

# %%
volcano(res, symbol='Symbol',to_label=grapher.index)
