# %%
import pandas as pd
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

# %%
counts= pd.read_csv('C:/Users/NOE/Desktop/TFG-Example/Islet data/DataFrames/SSConditions_DataFrame.csv')

#Possar com a index la columna entre parentesi:
counts= counts.set_index('ensembl')

#Del dataFrame quedar-nos amb les columnes que comencen per ND i IGT:
counts= counts.filter(regex='^(ND|T3cD)')
counts
# Out:
#                     ND_counts  ND_counts.1  ND_counts.2  ND_counts.3  \
# ensembl
# ENSG00000000003.14        188          198          343          214
# ENSG00000000005.5           0            0            0            0
# ENSG00000000419.12        697          595          503          683
# ENSG00000000457.13        232          229          140          300
# ENSG00000000460.16        119           85           27          101
# ...                       ...          ...          ...          ...
# ENSG00000285498.1           0            0            0            0
# ENSG00000285505.1           0            0            0            0
# ENSG00000285508.1           0            0            0            0
# ENSG00000285509.1           2            0            0            8
# ENSG00000285513.1           0            0            0            0
#
#                     ND_counts.4  ND_counts.5  ND_counts.6  ND_counts.7  \
# ensembl
# ENSG00000000003.14          400          528          536          246
# ENSG00000000005.5            21            0            0            0
# ENSG00000000419.12          552         1609         1007          461
# ENSG00000000457.13          188          347          424          347
# ENSG00000000460.16           46           35          125          105
# ...                         ...          ...          ...          ...
# ENSG00000285498.1             0            0            0            0
# ENSG00000285505.1             0            0            0            0
# ENSG00000285508.1             0            0            0            0
# ENSG00000285509.1            17           11            5            0
# ENSG00000285513.1             0            0            0            0
#
#                     ND_counts.8  ND_counts.9  ...  T3cD_counts.25  \
# ensembl                                       ...
# ENSG00000000003.14           44           34  ...             311
# ENSG00000000005.5             0            0  ...               1
# ENSG00000000419.12          129          165  ...             914
# ENSG00000000457.13           70           73  ...             217
# ENSG00000000460.16           22           34  ...              55
# ...                         ...          ...  ...             ...
# ENSG00000285498.1             1            0  ...               0
# ENSG00000285505.1             0            0  ...               0
# ENSG00000285508.1             0            0  ...               0
# ENSG00000285509.1             0            2  ...               5
# ENSG00000285513.1             0            0  ...               0
#
#                     T3cD_counts.26  T3cD_counts.27  T3cD_counts.28  \
# ensembl
# ENSG00000000003.14             638             884             631
# ENSG00000000005.5                0               3               0
# ENSG00000000419.12            1365            1092            1208
# ENSG00000000457.13             335             374             348
# ENSG00000000460.16              37              71              31
# ...                            ...             ...             ...
# ENSG00000285498.1                0               0               5
# ENSG00000285505.1                0               0               0
# ENSG00000285508.1                0               0               0
# ENSG00000285509.1               14               0               1
# ENSG00000285513.1                0               0               0
#
#                     T3cD_counts.29  T3cD_counts.30  T3cD_counts.31  \
# ensembl
# ENSG00000000003.14             973             717             285
# ENSG00000000005.5                0               0               4
# ENSG00000000419.12             882             868            1066
# ENSG00000000457.13             344             385             298
# ENSG00000000460.16              98             111              37
# ...                            ...             ...             ...
# ENSG00000285498.1                0               0               0
# ENSG00000285505.1                0               0               0
# ENSG00000285508.1                0               0               0
# ENSG00000285509.1               22               2               0
# ENSG00000285513.1                0               0               0
#
#                     T3cD_counts.32  T3cD_counts.33  T3cD_counts.34
# ensembl
# ENSG00000000003.14             619             422             412
# ENSG00000000005.5                7               0               0
# ENSG00000000419.12             940            1165            1060
# ENSG00000000457.13             304             366             306
# ENSG00000000460.16              24              59              64
# ...                            ...             ...             ...
# ENSG00000285498.1                0               0               0
# ENSG00000285505.1                0               0               0
# ENSG00000285508.1                0               0               0
# ENSG00000285509.1                3               2               8
# ENSG00000285513.1                0               0               0
#
# [58381 rows x 53 columns]

# %%
# Del DataFrame filtrar les columnes que tinguin tots els valors 0 (no expressió), i dels ensmbl treure decimals:
counts1= counts[counts.sum(axis=1) > 0]

counts1.index = [col.split('.')[0] for col in counts1.index]
counts1
# Out:
#                  ND_counts  ND_counts.1  ND_counts.2  ND_counts.3  \
# ENSG00000000003        188          198          343          214
# ENSG00000000005          0            0            0            0
# ENSG00000000419        697          595          503          683
# ENSG00000000457        232          229          140          300
# ENSG00000000460        119           85           27          101
# ...                    ...          ...          ...          ...
# ENSG00000285483          0            0            0            0
# ENSG00000285486          1            0            0            2
# ENSG00000285492          0            5            0            5
# ENSG00000285498          0            0            0            0
# ENSG00000285509          2            0            0            8
#
#                  ND_counts.4  ND_counts.5  ND_counts.6  ND_counts.7  \
# ENSG00000000003          400          528          536          246
# ENSG00000000005           21            0            0            0
# ENSG00000000419          552         1609         1007          461
# ENSG00000000457          188          347          424          347
# ENSG00000000460           46           35          125          105
# ...                      ...          ...          ...          ...
# ENSG00000285483            0            0            6            0
# ENSG00000285486            0            0            0           17
# ENSG00000285492            0            4            4           10
# ENSG00000285498            0            0            0            0
# ENSG00000285509           17           11            5            0
#
#                  ND_counts.8  ND_counts.9  ...  T3cD_counts.25  \
# ENSG00000000003           44           34  ...             311
# ENSG00000000005            0            0  ...               1
# ENSG00000000419          129          165  ...             914
# ENSG00000000457           70           73  ...             217
# ENSG00000000460           22           34  ...              55
# ...                      ...          ...  ...             ...
# ENSG00000285483            0            0  ...               0
# ENSG00000285486            0            0  ...               0
# ENSG00000285492            1            0  ...               1
# ENSG00000285498            1            0  ...               0
# ENSG00000285509            0            2  ...               5
#
#                  T3cD_counts.26  T3cD_counts.27  T3cD_counts.28  \
# ENSG00000000003             638             884             631
# ENSG00000000005               0               3               0
# ENSG00000000419            1365            1092            1208
# ENSG00000000457             335             374             348
# ENSG00000000460              37              71              31
# ...                         ...             ...             ...
# ENSG00000285483               0               0               0
# ENSG00000285486               0               0               0
# ENSG00000285492               8               0               6
# ENSG00000285498               0               0               5
# ENSG00000285509              14               0               1
#
#                  T3cD_counts.29  T3cD_counts.30  T3cD_counts.31  \
# ENSG00000000003             973             717             285
# ENSG00000000005               0               0               4
# ENSG00000000419             882             868            1066
# ENSG00000000457             344             385             298
# ENSG00000000460              98             111              37
# ...                         ...             ...             ...
# ENSG00000285483               0               0               0
# ENSG00000285486               0               0               0
# ENSG00000285492               0               5               8
# ENSG00000285498               0               0               0
# ENSG00000285509              22               2               0
#
#                  T3cD_counts.32  T3cD_counts.33  T3cD_counts.34
# ENSG00000000003             619             422             412
# ENSG00000000005               7               0               0
# ENSG00000000419             940            1165            1060
# ENSG00000000457             304             366             306
# ENSG00000000460              24              59              64
# ...                         ...             ...             ...
# ENSG00000285483               6               0               0
# ENSG00000285486               0               0               0
# ENSG00000285492               4               1               0
# ENSG00000285498               0               0               0
# ENSG00000285509               3               2               8
#
# [48221 rows x 53 columns]

# %%
#Transposar DataFrame:
counts=counts1.T
counts
# Out:
#                 ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# ND_counts                   188                0              697
# ND_counts.1                 198                0              595
# ND_counts.2                 343                0              503
# ND_counts.3                 214                0              683
# ND_counts.4                 400               21              552
# ND_counts.5                 528                0             1609
# ND_counts.6                 536                0             1007
# ND_counts.7                 246                0              461
# ND_counts.8                  44                0              129
# ND_counts.9                  34                0              165
# ND_counts.10                 28                0              148
# ND_counts.11                315                2             1017
# ND_counts.12                584                0             1267
# ND_counts.13                704               12              876
# ND_counts.14                391                0              900
# ND_counts.15                451                0              879
# ND_counts.16                622                0             1395
# ND_counts.17                379                0              856
# T3cD_counts                 529                0              412
# T3cD_counts.1               365                0              479
# T3cD_counts.2               118                0              422
# T3cD_counts.3               373                4              393
# T3cD_counts.4               453                5              594
# T3cD_counts.5               161                0              956
# T3cD_counts.6               552                0             1119
# T3cD_counts.7               458                2              797
# T3cD_counts.8                38                0              189
# T3cD_counts.9               586                0              649
# T3cD_counts.10              475                3             1151
# T3cD_counts.11             1178                0              740
# T3cD_counts.12              304                0              546
# T3cD_counts.13              590                7             1129
# T3cD_counts.14              394                0              960
# T3cD_counts.15              714                0              910
# T3cD_counts.16              967                0              590
# T3cD_counts.17               87                0              183
# T3cD_counts.18              570                0              769
# T3cD_counts.19              430                0             1476
# T3cD_counts.20              650                0             1087
# T3cD_counts.21              569                0              897
# T3cD_counts.22              961                0              995
# T3cD_counts.23              338                8              915
# T3cD_counts.24              587                0             1143
# T3cD_counts.25              311                1              914
# T3cD_counts.26              638                0             1365
# T3cD_counts.27              884                3             1092
# T3cD_counts.28              631                0             1208
# T3cD_counts.29              973                0              882
# T3cD_counts.30              717                0              868
# T3cD_counts.31              285                4             1066
# T3cD_counts.32              619                7              940
# T3cD_counts.33              422                0             1165
# T3cD_counts.34              412                0             1060
#
#                 ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# ND_counts                   232              119               18
# ND_counts.1                 229               85                1
# ND_counts.2                 140               27               26
# ND_counts.3                 300              101                8
# ND_counts.4                 188               46                0
# ND_counts.5                 347               35                4
# ND_counts.6                 424              125               10
# ND_counts.7                 347              105                1
# ND_counts.8                  70               22                1
# ND_counts.9                  73               34                2
# ND_counts.10                 57                5                0
# ND_counts.11                433               81               10
# ND_counts.12                611              133                8
# ND_counts.13                247               59               20
# ND_counts.14                427               72               31
# ND_counts.15                330               69               18
# ND_counts.16                593               83               40
# ND_counts.17                228               53                8
# T3cD_counts                 274               37               42
# T3cD_counts.1               223               87              116
# T3cD_counts.2               426               16                0
# T3cD_counts.3               297               49                3
# T3cD_counts.4               165               18                3
# T3cD_counts.5               131               72               18
# T3cD_counts.6               323               55               19
# T3cD_counts.7               335               66               57
# T3cD_counts.8                76               22                2
# T3cD_counts.9               334               66               30
# T3cD_counts.10              484              111               41
# T3cD_counts.11              187               11                5
# T3cD_counts.12              412               55               21
# T3cD_counts.13              490              128               17
# T3cD_counts.14              309               64               13
# T3cD_counts.15              252               87               67
# T3cD_counts.16              236               37               28
# T3cD_counts.17               41                5                0
# T3cD_counts.18              348               81               26
# T3cD_counts.19              189               73               11
# T3cD_counts.20              239               53               43
# T3cD_counts.21              231               41                2
# T3cD_counts.22              232               46               22
# T3cD_counts.23              265               17               15
# T3cD_counts.24              434               89               27
# T3cD_counts.25              217               55               22
# T3cD_counts.26              335               37                6
# T3cD_counts.27              374               71               34
# T3cD_counts.28              348               31               70
# T3cD_counts.29              344               98               26
# T3cD_counts.30              385              111               26
# T3cD_counts.31              298               37               44
# T3cD_counts.32              304               24               25
# T3cD_counts.33              366               59              205
# T3cD_counts.34              306               64               15
#
#                 ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# ND_counts                    29              612              318
# ND_counts.1                 121              468              226
# ND_counts.2                 472              556              317
# ND_counts.3                  23              582              402
# ND_counts.4                  42              383              196
# ND_counts.5                 217              767              354
# ND_counts.6                 301              570              341
# ND_counts.7                   3              431              173
# ND_counts.8                   2              149               62
# ND_counts.9                   7              151              106
# ND_counts.10                  5              101               50
# ND_counts.11                294              611              468
# ND_counts.12               1109              775              590
# ND_counts.13                203              554              317
# ND_counts.14                368              722              529
# ND_counts.15                221              494              719
# ND_counts.16                633              939              673
# ND_counts.17                404              613              362
# T3cD_counts                 396              451              283
# T3cD_counts.1               206              812              355
# T3cD_counts.2                12              736              257
# T3cD_counts.3               434              550              211
# T3cD_counts.4                87              324              318
# T3cD_counts.5               586              653              368
# T3cD_counts.6               490              526              290
# T3cD_counts.7               587              971              421
# T3cD_counts.8                20              240               92
# T3cD_counts.9               825              675              360
# T3cD_counts.10              770              980              537
# T3cD_counts.11             1520              613              512
# T3cD_counts.12              322              598              512
# T3cD_counts.13              966              549              384
# T3cD_counts.14              826              594              308
# T3cD_counts.15             1359              687              421
# T3cD_counts.16              824              473              265
# T3cD_counts.17               16              193               64
# T3cD_counts.18              863              609              590
# T3cD_counts.19              375              800              340
# T3cD_counts.20              337              711              419
# T3cD_counts.21              267              587              246
# T3cD_counts.22              653              675              484
# T3cD_counts.23              276              811              408
# T3cD_counts.24             1480             1308              836
# T3cD_counts.25              473              820              726
# T3cD_counts.26              771              842              598
# T3cD_counts.27             2732             1442              651
# T3cD_counts.28             1049             1034              691
# T3cD_counts.29             1435              591              387
# T3cD_counts.30             2456              856              455
# T3cD_counts.31              571              807              393
# T3cD_counts.32             1080              802              366
# T3cD_counts.33             1011             1082              475
# T3cD_counts.34             1217             1054              857
#
#                 ENSG00000001167  ...  ENSG00000285462  ENSG00000285467  \
# ND_counts                   298  ...                0                5
# ND_counts.1                 180  ...                0                3
# ND_counts.2                 246  ...                0                6
# ND_counts.3                 402  ...                0               10
# ND_counts.4                 323  ...                0                2
# ND_counts.5                 269  ...                0                2
# ND_counts.6                 329  ...                0                8
# ND_counts.7                 199  ...                1                5
# ND_counts.8                  70  ...                0                3
# ND_counts.9                  69  ...                0                1
# ND_counts.10                 47  ...                0                2
# ND_counts.11                426  ...                0                9
# ND_counts.12                477  ...                0                3
# ND_counts.13                243  ...                0                7
# ND_counts.14                379  ...                0                3
# ND_counts.15                299  ...                0                0
# ND_counts.16                466  ...                0                5
# ND_counts.17                304  ...                0                0
# T3cD_counts                 264  ...                0                6
# T3cD_counts.1               400  ...                0                6
# T3cD_counts.2               214  ...                0                6
# T3cD_counts.3               206  ...                0                6
# T3cD_counts.4               192  ...                0                3
# T3cD_counts.5               489  ...                0               22
# T3cD_counts.6               366  ...                0                2
# T3cD_counts.7               231  ...                0                6
# T3cD_counts.8                88  ...                0                3
# T3cD_counts.9               342  ...                0                0
# T3cD_counts.10              480  ...                0                7
# T3cD_counts.11              123  ...                0                0
# T3cD_counts.12              325  ...                0                2
# T3cD_counts.13              404  ...                0                3
# T3cD_counts.14              345  ...                0                0
# T3cD_counts.15              246  ...                0                4
# T3cD_counts.16              219  ...                0               11
# T3cD_counts.17               84  ...                0                6
# T3cD_counts.18              403  ...                0                5
# T3cD_counts.19              232  ...                0                3
# T3cD_counts.20              253  ...                0                4
# T3cD_counts.21              145  ...                0                0
# T3cD_counts.22              158  ...                0                6
# T3cD_counts.23              225  ...                0                0
# T3cD_counts.24              377  ...                0                4
# T3cD_counts.25              345  ...                0                1
# T3cD_counts.26              371  ...                0               10
# T3cD_counts.27              312  ...                0                9
# T3cD_counts.28              314  ...                0               11
# T3cD_counts.29              292  ...                0                7
# T3cD_counts.30              345  ...                0                0
# T3cD_counts.31              278  ...                0                8
# T3cD_counts.32              172  ...                0                0
# T3cD_counts.33              332  ...                0                1
# T3cD_counts.34              478  ...                0                3
#
#                 ENSG00000285473  ENSG00000285476  ENSG00000285480  \
# ND_counts                     0               69                0
# ND_counts.1                   0               30                0
# ND_counts.2                   0               13                0
# ND_counts.3                   0               64                0
# ND_counts.4                   0               19                0
# ND_counts.5                   0               44                0
# ND_counts.6                   0               41                0
# ND_counts.7                   1              112                0
# ND_counts.8                   0                8                0
# ND_counts.9                   0               19                0
# ND_counts.10                  0               30                0
# ND_counts.11                  0               45                0
# ND_counts.12                  0               23                0
# ND_counts.13                  0               27                0
# ND_counts.14                  0               32                0
# ND_counts.15                  0               24                0
# ND_counts.16                  0               55                0
# ND_counts.17                  0               68                0
# T3cD_counts                   0               12                0
# T3cD_counts.1                 0               76                0
# T3cD_counts.2                 0               13                0
# T3cD_counts.3                 0               63                0
# T3cD_counts.4                 0               28                0
# T3cD_counts.5                 0               16                0
# T3cD_counts.6                 0               11                0
# T3cD_counts.7                 0               19                0
# T3cD_counts.8                 0               12                0
# T3cD_counts.9                 0               23                0
# T3cD_counts.10                0                8                0
# T3cD_counts.11                1               53                0
# T3cD_counts.12                0               44                0
# T3cD_counts.13                0               45                0
# T3cD_counts.14                0               30                0
# T3cD_counts.15                0               40                0
# T3cD_counts.16                0               15                1
# T3cD_counts.17                1               13                0
# T3cD_counts.18                0               49                0
# T3cD_counts.19                0               10                0
# T3cD_counts.20                0               35                0
# T3cD_counts.21                0                4                0
# T3cD_counts.22                0               31                0
# T3cD_counts.23                0               12                0
# T3cD_counts.24                0               77                0
# T3cD_counts.25                0               64                0
# T3cD_counts.26                0               86                0
# T3cD_counts.27                0              165                0
# T3cD_counts.28                0               59                0
# T3cD_counts.29                0               21                0
# T3cD_counts.30                0               22                0
# T3cD_counts.31                0              135                0
# T3cD_counts.32                0               71                0
# T3cD_counts.33                0                2                0
# T3cD_counts.34                0               64                0
#
#                 ENSG00000285483  ENSG00000285486  ENSG00000285492  \
# ND_counts                     0                1                0
# ND_counts.1                   0                0                5
# ND_counts.2                   0                0                0
# ND_counts.3                   0                2                5
# ND_counts.4                   0                0                0
# ND_counts.5                   0                0                4
# ND_counts.6                   6                0                4
# ND_counts.7                   0               17               10
# ND_counts.8                   0                0                1
# ND_counts.9                   0                0                0
# ND_counts.10                  0                0                0
# ND_counts.11                  2                0                3
# ND_counts.12                  2                0                0
# ND_counts.13                  0                0                0
# ND_counts.14                  1                0                3
# ND_counts.15                  2                0                0
# ND_counts.16                  0                0                1
# ND_counts.17                  0                0                0
# T3cD_counts                   0                0                0
# T3cD_counts.1                 0                1               25
# T3cD_counts.2                 0                2                0
# T3cD_counts.3                 0                0                0
# T3cD_counts.4                 0                0                0
# T3cD_counts.5                 0                0                0
# T3cD_counts.6                 0                0                1
# T3cD_counts.7                 0                0                0
# T3cD_counts.8                 0                1                2
# T3cD_counts.9                 0                0                0
# T3cD_counts.10                1                0                4
# T3cD_counts.11                0                0                0
# T3cD_counts.12                0                0                0
# T3cD_counts.13                0                0               15
# T3cD_counts.14                0                0                0
# T3cD_counts.15                0                1                6
# T3cD_counts.16                0                0                0
# T3cD_counts.17                0                0                1
# T3cD_counts.18                0                2                8
# T3cD_counts.19                0                0                0
# T3cD_counts.20                0                0                0
# T3cD_counts.21                0                0                0
# T3cD_counts.22                0                0                0
# T3cD_counts.23                0                0                6
# T3cD_counts.24                0                1                7
# T3cD_counts.25                0                0                1
# T3cD_counts.26                0                0                8
# T3cD_counts.27                0                0                0
# T3cD_counts.28                0                0                6
# T3cD_counts.29                0                0                0
# T3cD_counts.30                0                0                5
# T3cD_counts.31                0                0                8
# T3cD_counts.32                6                0                4
# T3cD_counts.33                0                0                1
# T3cD_counts.34                0                0                0
#
#                 ENSG00000285498  ENSG00000285509
# ND_counts                     0                2
# ND_counts.1                   0                0
# ND_counts.2                   0                0
# ND_counts.3                   0                8
# ND_counts.4                   0               17
# ND_counts.5                   0               11
# ND_counts.6                   0                5
# ND_counts.7                   0                0
# ND_counts.8                   1                0
# ND_counts.9                   0                2
# ND_counts.10                  0                0
# ND_counts.11                  0                9
# ND_counts.12                  0               13
# ND_counts.13                  0               11
# ND_counts.14                  0               13
# ND_counts.15                  0                4
# ND_counts.16                  0               12
# ND_counts.17                  0               24
# T3cD_counts                   0                0
# T3cD_counts.1                 0                0
# T3cD_counts.2                 0                0
# T3cD_counts.3                 0                0
# T3cD_counts.4                 0                0
# T3cD_counts.5                 0                0
# T3cD_counts.6                 1               13
# T3cD_counts.7                 0                2
# T3cD_counts.8                 0                1
# T3cD_counts.9                 0               26
# T3cD_counts.10                0                5
# T3cD_counts.11                0                1
# T3cD_counts.12                0               10
# T3cD_counts.13                0                0
# T3cD_counts.14                0                1
# T3cD_counts.15                0                3
# T3cD_counts.16                0                0
# T3cD_counts.17                0                0
# T3cD_counts.18                0                1
# T3cD_counts.19                0                9
# T3cD_counts.20                0               14
# T3cD_counts.21                0                0
# T3cD_counts.22                0                3
# T3cD_counts.23                2                0
# T3cD_counts.24                0                5
# T3cD_counts.25                0                5
# T3cD_counts.26                0               14
# T3cD_counts.27                0                0
# T3cD_counts.28                5                1
# T3cD_counts.29                0               22
# T3cD_counts.30                0                2
# T3cD_counts.31                0                0
# T3cD_counts.32                0                3
# T3cD_counts.33                0                2
# T3cD_counts.34                0                8
#
# [53 rows x 48221 columns]

# %% [markdown]
# # Preparar les dades per fer DEG:

# %%
#Definir les condicions, marcant el numero de files a les que correspon:
conditions = ['ND'] * 18 + ['T3cD'] * 35

# Crear un dataframe composat per el nom de les mostres i a quina condició patològica té:
metadata = pd.DataFrame(zip(counts.index, conditions), columns=['Sample', 'condition'])

#En el dataframe metadata establir la columna sample com index:
metadata=metadata.set_index('Sample')
metadata
# Out:
#                condition
# Sample
# ND_counts             ND
# ND_counts.1           ND
# ND_counts.2           ND
# ND_counts.3           ND
# ND_counts.4           ND
# ND_counts.5           ND
# ND_counts.6           ND
# ND_counts.7           ND
# ND_counts.8           ND
# ND_counts.9           ND
# ND_counts.10          ND
# ND_counts.11          ND
# ND_counts.12          ND
# ND_counts.13          ND
# ND_counts.14          ND
# ND_counts.15          ND
# ND_counts.16          ND
# ND_counts.17          ND
# T3cD_counts         T3cD
# T3cD_counts.1       T3cD
# T3cD_counts.2       T3cD
# T3cD_counts.3       T3cD
# T3cD_counts.4       T3cD
# T3cD_counts.5       T3cD
# T3cD_counts.6       T3cD
# T3cD_counts.7       T3cD
# T3cD_counts.8       T3cD
# T3cD_counts.9       T3cD
# T3cD_counts.10      T3cD
# T3cD_counts.11      T3cD
# T3cD_counts.12      T3cD
# T3cD_counts.13      T3cD
# T3cD_counts.14      T3cD
# T3cD_counts.15      T3cD
# T3cD_counts.16      T3cD
# T3cD_counts.17      T3cD
# T3cD_counts.18      T3cD
# T3cD_counts.19      T3cD
# T3cD_counts.20      T3cD
# T3cD_counts.21      T3cD
# T3cD_counts.22      T3cD
# T3cD_counts.23      T3cD
# T3cD_counts.24      T3cD
# T3cD_counts.25      T3cD
# T3cD_counts.26      T3cD
# T3cD_counts.27      T3cD
# T3cD_counts.28      T3cD
# T3cD_counts.29      T3cD
# T3cD_counts.30      T3cD
# T3cD_counts.31      T3cD
# T3cD_counts.32      T3cD
# T3cD_counts.33      T3cD
# T3cD_counts.34      T3cD

# %%
from pydeseq2.dds import DeseqDataSet

# Creació de dds: objecte amb informació informació necessaria per fer DEG.
dds = DeseqDataSet(counts=counts,metadata=metadata,design_factors="condition")
dds
# Out:
# AnnData object with n_obs × n_vars = 53 × 48221
#     obs: 'condition'
#     obsm: 'design_matrix'

# %%
#Calcularà els valors estadístics (resultats) com: log2FoldChange, Pvalue, Pvalue asj (equival a qvalue)...
dds.deseq2()
dds
# Out:
# Fitting size factors...
# ... done in 0.15 seconds.
#
# Fitting dispersions...
# ... done in 9.04 seconds.
#
# Fitting dispersion trend curve...
# ... done in 1.22 seconds.
#
# Fitting MAP dispersions...
# ... done in 9.55 seconds.
#
# Fitting LFCs...
# ... done in 6.44 seconds.
#
# Replacing 1203 outlier genes.
#
# Fitting dispersions...
# ... done in 0.26 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.24 seconds.
#
# Fitting LFCs...
# ... done in 0.23 seconds.
# AnnData object with n_obs × n_vars = 53 × 48221
#     obs: 'condition'
#     uns: 'trend_coeffs', 'disp_function_type', '_squared_logres', 'prior_disp_var'
#     obsm: 'design_matrix', 'size_factors', 'replaceable'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'refitted'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks'

# %% [markdown]
# # Veure si estan les dades normalitzades:

# %% [markdown]
# ## 1. Boxplot abans de normalitzar:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))  # Ajusta el tamaño de la figura

counts1.boxplot()
plt.title('Boxplot of Counts before normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### TRANSFORMAR LES DADES PER VISUALITZAR-HO MILLOR: Log1P

# %%
import numpy as np
counts1_t= np.log1p(counts1)
counts1_t

plt.figure(figsize=(12, 8))  # Ajusta el tamaño de la figura

counts1_t.boxplot(patch_artist=True, boxprops = dict(facecolor = "lightblue"))
plt.title('Boxplot of Counts before normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Reduïr la densitat de mostres per veure millor: 20 mostres

# %%
columns_T3cD = [col for col in counts1_t.columns if col.startswith('T3cD')]
columns_ND = [col for col in counts1_t.columns if col.startswith('ND')]

counts1_t_20 = counts1_t[columns_T3cD[:10] + columns_ND[:10]]

plt.figure(figsize=(12, 8))  # Ajusta el tamaño de la figura

bp=counts1_t_20.boxplot(patch_artist=True, boxprops = dict(facecolor = "lightblue"))

plt.title('Boxplot of Counts before normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 2. Boxplot desrés normalitzar:

# %% [markdown]
# #### 2.1 Construcció dataframe normalitzat:

# %%
normalized_data=dds.layers['normed_counts']
normalized_data
# Out:
# array([[2.04358515e+02, 0.00000000e+00, 7.57648325e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 2.17402676e+00],
#        [2.49917706e+02, 0.00000000e+00, 7.51015329e+02, ...,
#         6.31105319e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.27797770e+02, 0.00000000e+00, 6.27353581e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [5.30186095e+02, 5.99564243e+00, 8.05129127e+02, ...,
#         3.42608139e+00, 0.00000000e+00, 2.56956104e+00],
#        [3.15758986e+02, 0.00000000e+00, 8.71704308e+02, ...,
#         7.48244041e-01, 0.00000000e+00, 1.49648808e+00],
#        [3.11756175e+02, 0.00000000e+00, 8.02091130e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 6.05351796e+00]])

# %%
normalized_df = pd.DataFrame(dds.layers['normed_counts'].T, index=dds.var_names, columns=dds.obs_names)
normalized_df
# Out:
# Sample            ND_counts  ND_counts.1  ND_counts.2  ND_counts.3  \
# ENSG00000000003  204.358515   249.917706   427.797770   207.140421
# ENSG00000000005    0.000000     0.000000     0.000000     0.000000
# ENSG00000000419  757.648325   751.015329   627.353581   661.107044
# ENSG00000000457  252.187104   289.046236   174.611335   290.383768
# ENSG00000000460  129.354592   107.287904    33.675043    97.762535
# ...                     ...          ...          ...          ...
# ENSG00000285483    0.000000     0.000000     0.000000     0.000000
# ENSG00000285486    1.087013     0.000000     0.000000     1.935892
# ENSG00000285492    0.000000     6.311053     0.000000     4.839729
# ENSG00000285498    0.000000     0.000000     0.000000     0.000000
# ENSG00000285509    2.174027     0.000000     0.000000     7.743567
#
# Sample           ND_counts.4  ND_counts.5  ND_counts.6  ND_counts.7  \
# ENSG00000000003   625.627545   449.397442   409.058291   236.383978
# ENSG00000000005    32.845446     0.000000     0.000000     0.000000
# ENSG00000000419   863.366012  1369.470613   768.510633   442.979730
# ENSG00000000457   294.044946   295.342637   323.583424   333.435936
# ENSG00000000460    71.947168    29.789603    95.396057   100.895600
# ...                      ...          ...          ...          ...
# ENSG00000285483     0.000000     0.000000     4.579011     0.000000
# ENSG00000285486     0.000000     0.000000     0.000000    16.335478
# ENSG00000285492     0.000000     3.404526     3.052674     9.609105
# ENSG00000285498     0.000000     0.000000     0.000000     0.000000
# ENSG00000285509    26.589171     9.362447     3.815842     0.000000
#
# Sample           ND_counts.8  ND_counts.9  ...  T3cD_counts.25  \
# ENSG00000000003   160.498157   101.163504  ...      261.171656
# ENSG00000000005     0.000000     0.000000  ...        0.839780
# ENSG00000000419   470.551415   490.940532  ...      767.559142
# ENSG00000000457   255.337977   217.203993  ...      182.232313
# ENSG00000000460    80.249078   101.163504  ...       46.187913
# ...                      ...          ...  ...             ...
# ENSG00000285483     0.000000     0.000000  ...        0.000000
# ENSG00000285486     0.000000     0.000000  ...        0.000000
# ENSG00000285492     3.647685     0.000000  ...        0.839780
# ENSG00000285498     3.647685     0.000000  ...        0.000000
# ENSG00000285509     0.000000     5.950794  ...        4.198901
#
# Sample           T3cD_counts.26  T3cD_counts.27  T3cD_counts.28  \
# ENSG00000000003      393.406923      459.899625      426.138809
# ENSG00000000005        0.000000        1.560745        0.000000
# ENSG00000000419      841.693495      568.111302      815.809321
# ENSG00000000457      206.569466      194.572918      235.017917
# ENSG00000000460       22.815135       36.937640       20.935504
# ...                         ...             ...             ...
# ENSG00000285483        0.000000        0.000000        0.000000
# ENSG00000285486        0.000000        0.000000        0.000000
# ENSG00000285492        4.933002        0.000000        4.052033
# ENSG00000285498        0.000000        0.000000        3.376694
# ENSG00000285509        8.632754        0.000000        0.675339
#
# Sample           T3cD_counts.29  T3cD_counts.30  T3cD_counts.31  \
# ENSG00000000003      787.168603      505.498713      220.899233
# ENSG00000000005        0.000000        0.000000        3.100340
# ENSG00000000419      713.548518      611.956601      826.240639
# ENSG00000000457      278.300102      271.432363      230.975338
# ENSG00000000460       79.283169       78.257123       28.678146
# ...                         ...             ...             ...
# ENSG00000285483        0.000000        0.000000        0.000000
# ENSG00000285486        0.000000        0.000000        0.000000
# ENSG00000285492        0.000000        3.525096        6.200680
# ENSG00000285498        0.000000        0.000000        0.000000
# ENSG00000285509       17.798262        1.410038        0.000000
#
# Sample           T3cD_counts.32  T3cD_counts.33  T3cD_counts.34
# ENSG00000000003      530.186095      315.758986      311.756175
# ENSG00000000005        5.995642        0.000000        0.000000
# ENSG00000000419      805.129127      871.704308      802.091130
# ENSG00000000457      260.382186      273.857319      231.547062
# ENSG00000000460       20.556488       44.146398       48.428144
# ...                         ...             ...             ...
# ENSG00000285483        5.139122        0.000000        0.000000
# ENSG00000285486        0.000000        0.000000        0.000000
# ENSG00000285492        3.426081        0.748244        0.000000
# ENSG00000285498        0.000000        0.000000        0.000000
# ENSG00000285509        2.569561        1.496488        6.053518
#
# [48221 rows x 53 columns]

# %%
normalized_df_t= np.log1p(normalized_df)
normalized_df_t

plt.figure(figsize=(12, 8)) 

normalized_df_t.boxplot(patch_artist=True, boxprops = dict(facecolor = "lightblue"))
plt.title('Boxplot of Counts after normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')

plt.xticks(rotation=90)
plt.show()

# %%
columns_T3cD_n = [col for col in normalized_df_t.columns if col.startswith('T3cD')]
columns_ND_n = [col for col in normalized_df_t.columns if col.startswith('ND')]

normalized_t_20 = normalized_df_t[columns_T3cD_n[:10] + columns_ND_n[:10]]

plt.figure(figsize=(12, 8))  # Ajusta el tamaño de la figura

bp=normalized_t_20.boxplot(patch_artist=True, boxprops = dict(facecolor = "lightblue"))

plt.title('Boxplot of Counts after normlitzation')
plt.xlabel('Samples')
plt.ylabel('Counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## DEG study:

# %%
from pydeseq2.default_inference import DefaultInference

#Creació de stat_res: objecte que tindrà només els resultats estadístics: log2foldchange...
inference = DefaultInference(n_cpus=8)
stat_res=DeseqStats(dds, inference=inference, contrast=('condition','T3cD','ND'))
stat_res.summary()
# Out:
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition T3cD vs ND
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  417.376683        0.499057  0.213201  2.340781  0.019243
# ENSG00000000005    0.978594        0.458627  1.342761  0.341555  0.732686
# ENSG00000000419  741.428087        0.000253  0.119866  0.002110  0.998316
# ENSG00000000457  261.221263       -0.179551  0.100580 -1.785161  0.074235
# ENSG00000000460   55.605341       -0.581161  0.192089 -3.025475  0.002482
# ...                     ...             ...       ...       ...       ...
# ENSG00000285483    0.294959       -1.439213  1.850973 -0.777544  0.436838
# ENSG00000285486    0.220988       -0.161045  1.752151 -0.091913  0.926767
# ENSG00000285492    2.305999        0.291646  0.777045  0.375326  0.707418
# ENSG00000285498    0.186420        0.161685  2.729928  0.059227  0.952772
# ENSG00000285509    4.612059       -0.966132  0.595715 -1.621804  0.104845
#
#                      padj
# ENSG00000000003  0.153742
# ENSG00000000005       NaN
# ENSG00000000419  0.999436
# ENSG00000000457  0.330722
# ENSG00000000460  0.042817
# ...                   ...
# ENSG00000285483       NaN
# ENSG00000285486       NaN
# ENSG00000285492  0.897015
# ENSG00000285498       NaN
# ENSG00000285509  0.398371
#
# [48221 rows x 6 columns]
# ... done in 3.75 seconds.

# %%
#Guardar els valors (resultats) de stat_res com a nom de res:
res =stat_res.results_df
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  417.376683        0.499057  0.213201  2.340781  0.019243
# ENSG00000000005    0.978594        0.458627  1.342761  0.341555  0.732686
# ENSG00000000419  741.428087        0.000253  0.119866  0.002110  0.998316
# ENSG00000000457  261.221263       -0.179551  0.100580 -1.785161  0.074235
# ENSG00000000460   55.605341       -0.581161  0.192089 -3.025475  0.002482
# ...                     ...             ...       ...       ...       ...
# ENSG00000285483    0.294959       -1.439213  1.850973 -0.777544  0.436838
# ENSG00000285486    0.220988       -0.161045  1.752151 -0.091913  0.926767
# ENSG00000285492    2.305999        0.291646  0.777045  0.375326  0.707418
# ENSG00000285498    0.186420        0.161685  2.729928  0.059227  0.952772
# ENSG00000285509    4.612059       -0.966132  0.595715 -1.621804  0.104845
#
#                      padj
# ENSG00000000003  0.153742
# ENSG00000000005       NaN
# ENSG00000000419  0.999436
# ENSG00000000457  0.330722
# ENSG00000000460  0.042817
# ...                   ...
# ENSG00000285483       NaN
# ENSG00000285486       NaN
# ENSG00000285492  0.897015
# ENSG00000285498       NaN
# ENSG00000285509  0.398371
#
# [48221 rows x 6 columns]

# %%
from sanbomics.tools import id_map

#Transformar els 'ensmbl' a symbol, i afegir columna a res amb el symbol:
mapper = id_map(species='human')
res['Symbol'] = res.index.map(mapper.mapper)
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  417.376683        0.499057  0.213201  2.340781  0.019243
# ENSG00000000005    0.978594        0.458627  1.342761  0.341555  0.732686
# ENSG00000000419  741.428087        0.000253  0.119866  0.002110  0.998316
# ENSG00000000457  261.221263       -0.179551  0.100580 -1.785161  0.074235
# ENSG00000000460   55.605341       -0.581161  0.192089 -3.025475  0.002482
# ...                     ...             ...       ...       ...       ...
# ENSG00000285483    0.294959       -1.439213  1.850973 -0.777544  0.436838
# ENSG00000285486    0.220988       -0.161045  1.752151 -0.091913  0.926767
# ENSG00000285492    2.305999        0.291646  0.777045  0.375326  0.707418
# ENSG00000285498    0.186420        0.161685  2.729928  0.059227  0.952772
# ENSG00000285509    4.612059       -0.966132  0.595715 -1.621804  0.104845
#
#                      padj       Symbol
# ENSG00000000003  0.153742       TSPAN6
# ENSG00000000005       NaN         TNMD
# ENSG00000000419  0.999436         DPM1
# ENSG00000000457  0.330722        SCYL3
# ENSG00000000460  0.042817     C1orf112
# ...                   ...          ...
# ENSG00000285483       NaN   AL590381.1
# ENSG00000285486       NaN   AC003043.2
# ENSG00000285492  0.897015   AL356417.3
# ENSG00000285498       NaN          NaN
# ENSG00000285509  0.398371  TBCEL-TECTA
#
# [48221 rows x 7 columns]

# %%
#Filtrar els gens amb molt poca expressió, 
#per fer-ho ens bassem en Basemean (promitg dels recomptes de lectures normalitzades d'un gen), basemean >=10:

res=res[res.baseMean>= 10]
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  417.376683        0.499057  0.213201  2.340781  0.019243
# ENSG00000000419  741.428087        0.000253  0.119866  0.002110  0.998316
# ENSG00000000457  261.221263       -0.179551  0.100580 -1.785161  0.074235
# ENSG00000000460   55.605341       -0.581161  0.192089 -3.025475  0.002482
# ENSG00000000938   20.314068        1.283865  0.410055  3.130959  0.001742
# ...                     ...             ...       ...       ...       ...
# ENSG00000285399   18.676032        0.380185  0.355859  1.068356  0.285360
# ENSG00000285410  173.379526        0.174970  0.156829  1.115671  0.264563
# ENSG00000285417   10.993998        0.484542  0.371533  1.304167  0.192177
# ENSG00000285437   16.731025        0.029717  0.287128  0.103498  0.917568
# ENSG00000285476   38.121039       -0.434955  0.290811 -1.495663  0.134742
#
#                      padj      Symbol
# ENSG00000000003  0.153742      TSPAN6
# ENSG00000000419  0.999436        DPM1
# ENSG00000000457  0.330722       SCYL3
# ENSG00000000460  0.042817    C1orf112
# ENSG00000000938  0.033624         FGR
# ...                   ...         ...
# ENSG00000285399  0.636390         NaN
# ENSG00000285410  0.616324  GABPB1-IT1
# ENSG00000285417  0.530044         NaN
# ENSG00000285437  0.972184     POLR2J3
# ENSG00000285476  0.449021         NaN
#
# [17527 rows x 7 columns]

# %%
#Dels resultats identifiquem filtrant els gens diferencialment expressats:
sigs =res[(res.padj < 0.05) & (abs(res.log2FoldChange) > 1)] #dades filtrades per significancia
sigs
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000938   20.314068        1.283865  0.410055  3.130959  0.001742
# ENSG00000000971  476.409980        1.619121  0.384744  4.208306  0.000026
# ENSG00000002726   21.757189        1.623436  0.421621  3.850467  0.000118
# ENSG00000003400   65.378373        1.161735  0.285006  4.076179  0.000046
# ENSG00000009790   19.472053        1.265724  0.334810  3.780427  0.000157
# ...                     ...             ...       ...       ...       ...
# ENSG00000275832   31.777076        1.384043  0.361296  3.830778  0.000128
# ENSG00000276070   43.926440        2.048935  0.572283  3.580284  0.000343
# ENSG00000277734   49.983738        2.039446  0.531066  3.840291  0.000123
# ENSG00000279355   28.902064        1.348516  0.403297  3.343729  0.000827
# ENSG00000282608   22.040193        1.449441  0.485475  2.985615  0.002830
#
#                      padj    Symbol
# ENSG00000000938  0.033624       FGR
# ENSG00000000971  0.001814       CFH
# ENSG00000002726  0.005395      AOC1
# ENSG00000003400  0.002755    CASP10
# ENSG00000009790  0.006482  TRAF3IP3
# ...                   ...       ...
# ENSG00000275832  0.005682  ARHGAP23
# ENSG00000276070  0.011231    CCL4L2
# ENSG00000277734  0.005531      TRAC
# ENSG00000279355  0.020526       NaN
# ENSG00000282608  0.046038    ADORA3
#
# [661 rows x 7 columns]

# %% [markdown]
# ### PCA:

# %% [markdown]
# #### PCA amb valors normalitzats:

# %%
normalized=normalized_df.T
normalized
import pandas as pd

# Añadir la columna "conditions" basada en el índice
normalized['conditions'] = normalized.index.map(lambda x: 'IGT' if x.startswith('IGT') else 'ND' if x.startswith('ND') else 'Other')
normalized.set_index('conditions', inplace=True)
normalized.index.name = None
normalized

# Añadir la columna "patologia" basada en el índice
normalized['patologia'] = normalized.index.map(lambda x: 'IGT' if x.startswith('IGT') else 'ND' if x.startswith('ND') else 'Other')

# Mover el índice a una nueva columna
normalized.reset_index(inplace=True)

# Cambiar el nombre de la nueva columna a 'patologia' y eliminar la columna anterior
normalized = normalized.rename(columns={'index': 'patologia'}).iloc[:, :-1]

normalized
# Out:
#    patologia  ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# 0         ND       204.358515         0.000000       757.648325
# 1         ND       249.917706         0.000000       751.015329
# 2         ND       427.797770         0.000000       627.353581
# 3         ND       207.140421         0.000000       661.107044
# 4         ND       625.627545        32.845446       863.366012
# 5         ND       449.397442         0.000000      1369.470613
# 6         ND       409.058291         0.000000       768.510633
# 7         ND       236.383978         0.000000       442.979730
# 8         ND       160.498157         0.000000       470.551415
# 9         ND       101.163504         0.000000       490.940532
# 10        ND       133.061047         0.000000       703.322676
# 11        ND       215.316402         1.367088       695.164385
# 12        ND       350.368215         0.000000       760.131041
# 13        ND       670.193948        11.423760       833.934515
# 14        ND       274.332981         0.000000       631.456989
# 15        ND       470.236303         0.000000       916.491597
# 16        ND       357.313231         0.000000       801.369706
# 17        ND       348.067983         0.000000       786.137713
# 18     Other       631.843554         0.000000       492.097437
# 19     Other       278.254552         0.000000       365.161454
# 20     Other       113.672572         0.000000       406.523945
# 21     Other       404.442279         4.337183       426.128192
# 22     Other       651.600492         7.192058       854.416539
# 23     Other       153.397499         0.000000       910.857200
# 24     Other       456.459496         0.000000       925.322782
# 25     Other       366.426482         1.600116       637.646084
# 26     Other       118.574873         0.000000       589.753973
# 27     Other       488.870794         0.000000       541.428576
# 28     Other       266.368631         1.682328       645.453252
# 29     Other      1085.877218         0.000000       682.130001
# 30     Other       262.729835         0.000000       471.876611
# 31     Other       391.983104         4.650647       750.082923
# 32     Other       347.398804         0.000000       846.453938
# 33     Other       710.945306         0.000000       906.106762
# 34     Other      1242.357607         0.000000       758.005159
# 35     Other       290.191506         0.000000       610.402822
# 36     Other       382.273936         0.000000       515.734485
# 37     Other       370.658990         0.000000      1272.308535
# 38     Other       535.884900         0.000000       896.164440
# 39     Other       770.675130         0.000000      1214.930741
# 40     Other      1036.297694         0.000000      1072.961713
# 41     Other       342.891399         8.115773       928.241510
# 42     Other       318.769297         0.000000       620.704100
# 43     Other       261.171656         0.839780       767.559142
# 44     Other       393.406923         0.000000       841.693495
# 45     Other       459.899625         1.560745       568.111302
# 46     Other       426.138809         0.000000       815.809321
# 47     Other       787.168603         0.000000       713.548518
# 48     Other       505.498713         0.000000       611.956601
# 49     Other       220.899233         3.100340       826.240639
# 50     Other       530.186095         5.995642       805.129127
# 51     Other       315.758986         0.000000       871.704308
# 52     Other       311.756175         0.000000       802.091130
#
#     ENSG00000000457  ENSG00000000460  ENSG00000000938  ENSG00000000971  \
# 0        252.187104       129.354592        19.566241        31.523388
# 1        289.046236       107.287904         1.262211       152.727487
# 2        174.611335        33.675043        32.427819       588.689642
# 3        290.383768        97.762535         7.743567        22.262756
# 4        294.044946        71.947168         0.000000        65.690892
# 5        295.342637        29.789603         3.404526       184.695539
# 6        323.583424        95.396057         7.631685       229.713705
# 7        333.435936       100.895600         0.960910         2.882731
# 8        255.337977        80.249078         3.647685         7.295371
# 9        217.203993       101.163504         5.950794        20.827780
# 10       270.874274        23.760901         0.000000        23.760901
# 11       295.974610        55.367075         6.835441       200.961976
# 12       366.566745        79.792761         4.799565       665.339640
# 13       235.139070        56.166822        19.039601       193.251948
# 14       299.591260        50.516559        21.750185       258.195747
# 15       344.075344        71.943026        18.767746       230.426215
# 16       340.653932        47.680061        22.978343       363.632275
# 17       209.391821        48.674414         7.347081       371.027612
# 18       327.268684        44.193216        50.165273       472.986857
# 19       170.002096        66.323688        88.431584       157.042295
# 20       410.377253        15.413230         0.000000        11.559923
# 21       322.035809        53.130487         3.252887       470.584314
# 22       237.337927        25.891410         4.315235       125.141816
# 23       124.814114        68.600124        17.150031       558.328786
# 24       267.094958        45.480566        15.711468       405.190494
# 25       268.019370        52.803816        45.603296       469.633941
# 26       237.149746        68.648611         6.240783        62.407828
# 27       278.639668        55.060533        25.027515       688.256664
# 28       271.415616        62.246143        22.991819       431.797571
# 29       172.376095        10.139770         4.608986      1401.131895
# 30       356.068065        47.533358        18.149100       278.286206
# 31       325.545290        85.040402        11.294428       641.789286
# 32       272.452361        56.430263        11.462397       728.303076
# 33       250.921873        86.627789        66.713355      1353.185813
# 34       303.202063        47.535917        35.973126      1058.637713
# 35       136.756916        16.677673         0.000000        53.368553
# 36       233.388298        54.323138        17.437057       578.776152
# 37       162.917556        62.925829         9.481974       323.249120
# 38       197.040755        43.695230        35.450847       277.835710
# 39       312.875141        55.531951         2.708876       361.634903
# 40       250.178007        49.604260        23.723777       704.164822
# 41       268.834973        17.246017        15.217074       279.994161
# 42       235.682922        48.331290        14.662302       803.711346
# 43       182.232313        46.187913        18.475165       397.216055
# 44       206.569466        22.815135         3.699752       475.418084
# 45       194.572918        36.937640        17.688447      1421.318751
# 46       235.017917        20.935504        47.273719       708.430445
# 47       278.300102        79.283169        21.034310      1160.932112
# 48       271.432363        78.257123        18.330497      1731.526973
# 49       230.975338        28.678146        34.103741       442.573550
# 50       260.382186        20.556488        21.413009       925.041975
# 51       273.857319        44.146398       153.390029       756.474726
# 52       231.547062        48.428144        11.350346       920.891420
#
#     ENSG00000001036  ENSG00000001084  ...  ENSG00000285462  ENSG00000285467  \
# 0        665.252187       345.670254  ...          0.00000         5.435067
# 1        590.714578       285.259604  ...          0.00000         3.786632
# 2        693.456443       395.369950  ...          0.00000         7.483343
# 3        563.344509       389.114248  ...          0.00000         9.679459
# 4        599.038374       306.557497  ...          0.00000         3.128138
# 5        652.817874       301.300557  ...          0.00000         1.702263
# 6        435.006019       260.240443  ...          0.00000         6.105348
# 7        414.152416       166.237513  ...          0.96091         4.804552
# 8        543.505122       226.156494  ...          0.00000        10.943056
# 9        449.284972       315.392099  ...          0.00000         2.975397
# 10       479.970204       237.609012  ...          0.00000         9.504360
# 11       417.645466       319.898655  ...          0.00000         6.151897
# 12       464.957819       353.967888  ...          0.00000         1.799837
# 13       527.396942       301.777673  ...          0.00000         6.663860
# 14       506.568829       371.156386  ...          0.00000         2.104857
# 15       515.070363       749.667188  ...          0.00000         0.000000
# 16       539.416598       386.610618  ...          0.00000         2.872293
# 17       562.970115       332.455435  ...          0.00000         0.000000
# 18       538.679476       338.018385  ...          0.00000         7.166468
# 19       619.021087       270.631140  ...          0.00000         4.574047
# 20       709.008587       247.575009  ...          0.00000         5.779961
# 21       596.362609       228.786383  ...          0.00000         6.505774
# 22       466.045385       457.414915  ...          0.00000         4.315235
# 23       622.165012       350.622855  ...          0.00000        20.961149
# 24       434.959592       239.806619  ...          0.00000         1.653839
# 25       776.856145       336.824343  ...          0.00000         4.800347
# 26       748.893934       287.076008  ...          0.00000         9.361174
# 27       563.119089       300.330181  ...          0.00000         0.000000
# 28       549.560544       301.136747  ...          0.00000         3.925432
# 29       565.061744       471.960217  ...          0.00000         0.000000
# 30       516.817240       442.492353  ...          0.00000         1.728486
# 31       364.743600       255.121207  ...          0.00000         1.993134
# 32       523.743374       271.570638  ...          0.00000         0.000000
# 33       684.060819       419.198843  ...          0.00000         3.982887
# 34       607.688881       340.459944  ...          0.00000        14.132300
# 35       643.758167       213.474211  ...          0.00000        20.013207
# 36       408.429521       395.687056  ...          0.00000         3.353280
# 37       689.598122       293.079202  ...          0.00000         2.585993
# 38       586.175637       345.439651  ...          0.00000         3.297753
# 39       795.055011       333.191708  ...          0.00000         0.000000
# 40       727.888599       521.923084  ...          0.00000         6.470121
# 41       822.736464       413.904411  ...          0.00000         0.000000
# 42       710.307054       453.988301  ...          0.00000         2.172193
# 43       688.619799       609.680456  ...          0.00000         0.839780
# 44       519.198478       368.741912  ...          0.00000         6.166253
# 45       750.198257       338.681737  ...          0.00000         4.682236
# 46       698.300362       466.659140  ...          0.00000         7.428727
# 47       478.126048       313.087615  ...          0.00000         5.663083
# 48       603.496372       320.783702  ...          0.00000         0.000000
# 49       625.493617       304.608416  ...          0.00000         6.200680
# 50       686.929319       313.486447  ...          0.00000         0.000000
# 51       809.600053       355.415920  ...          0.00000         0.748244
# 52       797.550992       648.483112  ...          0.00000         2.270069
#
#     ENSG00000285473  ENSG00000285476  ENSG00000285480  ENSG00000285483  \
# 0          0.000000        75.003923         0.000000         0.000000
# 1          0.000000        37.866319         0.000000         0.000000
# 2          0.000000        16.213910         0.000000         0.000000
# 3          0.000000        61.948537         0.000000         0.000000
# 4          0.000000        29.717308         0.000000         0.000000
# 5          0.000000        37.449787         0.000000         0.000000
# 6          0.000000        31.289907         0.000000         4.579011
# 7          0.960910       107.621974         0.000000         0.000000
# 8          0.000000        29.181483         0.000000         0.000000
# 9          0.000000        56.532546         0.000000         0.000000
# 10         0.000000       142.565407         0.000000         0.000000
# 11         0.000000        30.759486         0.000000         1.367088
# 12         0.000000        13.798748         0.000000         1.199891
# 13         0.000000        25.703461         0.000000         0.000000
# 14         0.000000        22.451804         0.000000         0.701619
# 15         0.000000        25.023661         0.000000         2.085305
# 16         0.000000        31.595221         0.000000         0.000000
# 17         0.000000        62.450192         0.000000         0.000000
# 18         0.000000        14.332935         0.000000         0.000000
# 19         0.000000        57.937934         0.000000         0.000000
# 20         0.000000        12.523250         0.000000         0.000000
# 21         0.000000        68.310626         0.000000         0.000000
# 22         0.000000        40.275527         0.000000         0.000000
# 23         0.000000        15.244472         0.000000         0.000000
# 24         0.000000         9.096113         0.000000         0.000000
# 25         0.000000        15.201099         0.000000         0.000000
# 26         0.000000        37.444697         0.000000         0.000000
# 27         0.000000        19.187762         0.000000         0.000000
# 28         0.000000         4.486209         0.000000         0.560776
# 29         0.921797        48.855257         0.000000         0.000000
# 30         0.000000        38.026687         0.000000         0.000000
# 31         0.000000        29.897016         0.000000         0.000000
# 32         0.000000        26.451686         0.000000         0.000000
# 33         0.000000        39.828869         0.000000         0.000000
# 34         0.000000        19.271318         1.284755         0.000000
# 35         3.335535        43.361949         0.000000         0.000000
# 36         0.000000        32.862145         0.000000         0.000000
# 37         0.000000         8.619977         0.000000         0.000000
# 38         0.000000        28.855341         0.000000         0.000000
# 39         0.000000         5.417751         0.000000         0.000000
# 40         0.000000        33.428958         0.000000         0.000000
# 41         0.000000        12.173659         0.000000         0.000000
# 42         0.000000        41.814712         0.000000         0.000000
# 43         0.000000        53.745936         0.000000         0.000000
# 44         0.000000        53.029773         0.000000         0.000000
# 45         0.000000        85.840993         0.000000         0.000000
# 46         0.000000        39.844992         0.000000         0.000000
# 47         0.000000        16.989250         0.000000         0.000000
# 48         0.000000        15.510421         0.000000         0.000000
# 49         0.000000       104.636479         0.000000         0.000000
# 50         0.000000        60.812945         0.000000         5.139122
# 51         0.000000         1.496488         0.000000         0.000000
# 52         0.000000        48.428144         0.000000         0.000000
#
#     ENSG00000285486  ENSG00000285492  ENSG00000285498  ENSG00000285509
# 0          1.087013         0.000000         0.000000         2.174027
# 1          0.000000         6.311053         0.000000         0.000000
# 2          0.000000         0.000000         0.000000         0.000000
# 3          1.935892         4.839729         0.000000         7.743567
# 4          0.000000         0.000000         0.000000        26.589171
# 5          0.000000         3.404526         0.000000         9.362447
# 6          0.000000         3.052674         0.000000         3.815842
# 7         16.335478         9.609105         0.000000         0.000000
# 8          0.000000         3.647685         3.647685         0.000000
# 9          0.000000         0.000000         0.000000         5.950794
# 10         0.000000         0.000000         0.000000         0.000000
# 11         0.000000         2.050632         0.000000         6.151897
# 12         0.000000         0.000000         0.000000         7.799292
# 13         0.000000         0.000000         0.000000        10.471780
# 14         0.000000         2.104857         0.000000         9.121045
# 15         0.000000         0.000000         0.000000         4.170610
# 16         0.000000         0.574459         0.000000         6.893503
# 17         0.000000         0.000000         0.000000        22.041244
# 18         0.000000         0.000000         0.000000         0.000000
# 19         0.762341        19.058531         0.000000         0.000000
# 20         1.926654         0.000000         0.000000         0.000000
# 21         0.000000         0.000000         0.000000         0.000000
# 22         0.000000         0.000000         0.000000         0.000000
# 23         0.000000         0.000000         0.000000         0.000000
# 24         0.000000         0.826919         0.826919        10.749952
# 25         0.000000         0.000000         0.000000         1.600116
# 26         3.120391         6.240783         0.000000         3.120391
# 27         0.000000         0.000000         0.000000        21.690513
# 28         0.000000         2.243104         0.000000         2.803880
# 29         0.000000         0.000000         0.000000         0.921797
# 30         0.000000         0.000000         0.000000         8.642429
# 31         0.000000         9.965672         0.000000         0.000000
# 32         0.000000         0.000000         0.000000         0.881723
# 33         0.995722         5.974330         0.000000         2.987165
# 34         0.000000         0.000000         0.000000         0.000000
# 35         0.000000         3.335535         0.000000         0.000000
# 36         1.341312         5.365248         0.000000         0.670656
# 37         0.000000         0.000000         0.000000         7.757979
# 38         0.000000         0.000000         0.000000        11.542136
# 39         0.000000         0.000000         0.000000         0.000000
# 40         0.000000         0.000000         0.000000         3.235060
# 41         0.000000         6.086830         2.028943         0.000000
# 42         0.543048         3.801337         0.000000         2.715241
# 43         0.000000         0.839780         0.000000         4.198901
# 44         0.000000         4.933002         0.000000         8.632754
# 45         0.000000         0.000000         0.000000         0.000000
# 46         0.000000         4.052033         3.376694         0.675339
# 47         0.000000         0.000000         0.000000        17.798262
# 48         0.000000         3.525096         0.000000         1.410038
# 49         0.000000         6.200680         0.000000         0.000000
# 50         0.000000         3.426081         0.000000         2.569561
# 51         0.000000         0.748244         0.000000         1.496488
# 52         0.000000         0.000000         0.000000         6.053518
#
# [53 rows x 48222 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

x = normalized.iloc[:, 1:49240].values  
y = normalized.loc[:, ["patologia"]].values

pca = PCA(n_components=2)
components = pca.fit_transform(x)

# Crear DataFrame para los componentes principales
pca_df = pd.DataFrame(data=components, columns=['PC1', 'PC2'])

# Concatenar con la columna y
pcaDF = pd.concat([pca_df, pd.DataFrame(y, columns=["patologia"])], axis=1)


# Graficar los resultados
plt.figure(figsize=(12, 6))
scatter=sns.scatterplot(data=pcaDF, x='PC1', y='PC2', hue="patologia")



plt.title('PCA: Componentes Principales')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.show()

# %% [markdown]
# #### PCA sense valors normalitzat:

# %%
import scanpy as sc

#PCA
sc.tl.pca(dds)
sc.pl.pca(dds, color='condition',size=200)

# %% [markdown]
# ### GSEA:

# %%
import gseapy as gp
from gseapy.plot import gseaplot

# %%
res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  417.376683        0.499057  0.213201  2.340781  0.019243
# ENSG00000000419  741.428087        0.000253  0.119866  0.002110  0.998316
# ENSG00000000457  261.221263       -0.179551  0.100580 -1.785161  0.074235
# ENSG00000000460   55.605341       -0.581161  0.192089 -3.025475  0.002482
# ENSG00000000938   20.314068        1.283865  0.410055  3.130959  0.001742
# ...                     ...             ...       ...       ...       ...
# ENSG00000285399   18.676032        0.380185  0.355859  1.068356  0.285360
# ENSG00000285410  173.379526        0.174970  0.156829  1.115671  0.264563
# ENSG00000285417   10.993998        0.484542  0.371533  1.304167  0.192177
# ENSG00000285437   16.731025        0.029717  0.287128  0.103498  0.917568
# ENSG00000285476   38.121039       -0.434955  0.290811 -1.495663  0.134742
#
#                      padj      Symbol
# ENSG00000000003  0.153742      TSPAN6
# ENSG00000000419  0.999436        DPM1
# ENSG00000000457  0.330722       SCYL3
# ENSG00000000460  0.042817    C1orf112
# ENSG00000000938  0.033624         FGR
# ...                   ...         ...
# ENSG00000285399  0.636390         NaN
# ENSG00000285410  0.616324  GABPB1-IT1
# ENSG00000285417  0.530044         NaN
# ENSG00000285437  0.972184     POLR2J3
# ENSG00000285476  0.449021         NaN
#
# [17527 rows x 7 columns]

# %% [markdown]
# ### GSEA dels gens filtrats per padj:

# %%
genes_significativos = res[(res['padj'] < 0.05) & (res['padj'].notna())]
genes_significativos
# Out:
#                     baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000460    55.605341       -0.581161  0.192089 -3.025475  0.002482
# ENSG00000000938    20.314068        1.283865  0.410055  3.130959  0.001742
# ENSG00000000971   476.409980        1.619121  0.384744  4.208306  0.000026
# ENSG00000002726    21.757189        1.623436  0.421621  3.850467  0.000118
# ENSG00000002933  1062.713788        0.589474  0.186522  3.160345  0.001576
# ...                      ...             ...       ...       ...       ...
# ENSG00000280119   117.949015        0.648699  0.205920  3.150245  0.001631
# ENSG00000280229    59.113652        0.684898  0.230876  2.966512  0.003012
# ENSG00000280379    28.502835        0.884069  0.259072  3.412444  0.000644
# ENSG00000282608    22.040193        1.449441  0.485475  2.985615  0.002830
# ENSG00000283526    28.295732       -0.641138  0.217396 -2.949171  0.003186
#
#                      padj    Symbol
# ENSG00000000460  0.042817  C1orf112
# ENSG00000000938  0.033624       FGR
# ENSG00000000971  0.001814       CFH
# ENSG00000002726  0.005395      AOC1
# ENSG00000002933  0.031448  TMEM176A
# ...                   ...       ...
# ENSG00000280119  0.032206       NaN
# ENSG00000280229  0.048070       NaN
# ENSG00000280379  0.017365       NaN
# ENSG00000282608  0.046038    ADORA3
# ENSG00000283526  0.049976    PRRT1B
#
# [1357 rows x 7 columns]

# %%
ranking_padj = genes_significativos[['Symbol', 'padj']].sort_values('padj', ascending=True)
ranking_padj =ranking=ranking_padj.drop_duplicates('Symbol') #elimina els symbols duplicats
ranking_padj
# Out:
#                  Symbol          padj
# ENSG00000148773   MKI67  1.374346e-08
# ENSG00000211896   IGHG1  1.374346e-08
# ENSG00000211592    IGKC  8.769822e-08
# ENSG00000166278      C2  1.625936e-07
# ENSG00000106333  PCOLCE  1.625936e-07
# ...                 ...           ...
# ENSG00000100722  ZC3H14  4.946644e-02
# ENSG00000132801  ZSWIM3  4.947702e-02
# ENSG00000104267     CA2  4.960574e-02
# ENSG00000144468  RHBDD1  4.992714e-02
# ENSG00000283526  PRRT1B  4.997614e-02
#
# [1348 rows x 2 columns]

# %%
lista_genes_significativos = ranking_padj['Symbol'].tolist()
len(lista_genes_significativos)
# Out:
# 1348

# %%
manual_set_adj = {'things': lista_genes_significativos}
manual_set_adj
# Out:
# {'things': ['MKI67',
#   'IGHG1',
#   'IGKC',
#   'C2',
#   'PCOLCE',
#   'COL5A2',
#   'IGLV2-14',
#   'PDGFRB',
#   'DKK3',
#   'COL6A1',
#   'COL5A1',
#   'APLNR',
#   'SAA1',
#   'IGLC2',
#   'PARVG',
#   'COL1A1',
#   'C1QA',
#   'TRBC2',
#   'CD74',
#   'PLXDC1',
#   'JCHAIN',
#   'LAPTM5',
#   'FES',
#   'IGFBP4',
#   'FN1',
#   'COL3A1',
#   'C1R',
#   'HIC1',
#   'IGHGP',
#   'C1QC',
#   'VSTM4',
#   'ITGB2',
#   'RHOC',
#   'HLA-DPB1',
#   'CPXM1',
#   'SERPINH1',
#   'COL4A2',
#   'GLI1',
#   'ADAM19',
#   'PTAFR',
#   'HLA-DRB1',
#   'TSPAN18',
#   'IGHG3',
#   'FCER1G',
#   'MXRA8',
#   'MFAP2',
#   'ELK3',
#   'C1QB',
#   'RBP7',
#   'COL6A2',
#   'SIGLEC1',
#   'CMAHP',
#   'PTPRC',
#   'SLAMF7',
#   'ENC1',
#   'SOX4',
#   'HLA-DRA',
#   'CD52',
#   'FCGBP',
#   'ANGPTL2',
#   'CD53',
#   'ARG2',
#   'MSR1',
#   'SH3BP2',
#   'HTRA1',
#   'DIO2',
#   'NGFR',
#   'REG1B',
#   'CSRP2',
#   'COL1A2',
#   'APOC1',
#   'ALDOB',
#   'VCAN',
#   'COL14A1',
#   'LST1',
#   'MMP2',
#   'INHBA',
#   'HSD17B13',
#   'FMO1',
#   'ITGA5',
#   'SLC15A3',
#   'COL6A3',
#   'LCP2',
#   'G3BP1',
#   'HLA-DMA',
#   'PSMB9',
#   'PLAAT4',
#   'KANK2',
#   'CMTM3',
#   'IRF8',
#   'VIM',
#   'TRIM38',
#   'TDO2',
#   'HLA-DOA',
#   'PRG4',
#   'NFATC4',
#   'MYH9',
#   'NOTCH3',
#   'COL4A1',
#   'CD37',
#   'PTGIS',
#   'MS4A6A',
#   'CDH11',
#   'BST2',
#   'HLA-DMB',
#   'FCGR3A',
#   'IGHA2',
#   'S100A4',
#   'HCLS1',
#   'LCP1',
#   'MYOF',
#   'CLEC2B',
#   'CD248',
#   'KCNAB2',
#   'THBS4',
#   'BGN',
#   'TTLL10-AS1',
#   'DOCK2',
#   'HLA-DQA2',
#   'LAMB2',
#   'HLA-DPA1',
#   'TGM2',
#   'IGSF6',
#   'RASGRP1',
#   'IGKV3-20',
#   'DTX1',
#   'RAB34',
#   'SVIL',
#   'EDNRA',
#   'IL4R',
#   'PXDN',
#   'RARG',
#   'ITGAX',
#   'FAM111A',
#   'HLA-F',
#   'FYB1',
#   'CCDC80',
#   'DNM3OS',
#   'PTP4A3',
#   'COL15A1',
#   'REG3A',
#   'TLR7',
#   'TYROBP',
#   'CD4',
#   'RNF34',
#   'COL8A1',
#   'TMSB10',
#   'ITGA1',
#   'SLC7A7',
#   'CYBB',
#   'NCF2',
#   'AIF1',
#   'SYNPO',
#   'ITIH5',
#   'LGALS1',
#   'ALOX5AP',
#   'RCN3',
#   'C1S',
#   'COL4A5',
#   'DHRS9',
#   'ARHGAP6',
#   'THY1',
#   'PRICKLE2-AS3',
#   'CCT4',
#   'LAMB3',
#   'INPP5D',
#   'MS4A7',
#   'GBP2',
#   'SELPLG',
#   'IGFBP7',
#   'CAPG',
#   'C3',
#   'RUNX3',
#   'FCN3',
#   'RASL12',
#   'AC100803.4',
#   'PPP1R18',
#   'ZEB2',
#   'FMNL3',
#   'GPX8',
#   'SPG21',
#   'GOT1',
#   'RAMP2',
#   'EHD2',
#   'GGT5',
#   'ALPK1',
#   'HLA-DQB2',
#   'CD84',
#   'LGALS9',
#   'CCL4',
#   'EPHA3',
#   'OR2I1P',
#   'ISLR',
#   'GNB4',
#   'NSG1',
#   'CD3D',
#   'SLCO2B1',
#   'ADAM33',
#   'STOM',
#   'MNDA',
#   'BHLHE40',
#   'GDF15',
#   'ARHGEF6',
#   'TNFRSF1B',
#   'SLC16A9',
#   'KLHL6',
#   'RMND1',
#   'MARCKSL1',
#   'IFITM1',
#   'NR2F2-AS1',
#   'CAVIN1',
#   'GLRA1',
#   'CSF1R',
#   'C1orf162',
#   'MOXD1',
#   'HLA-E',
#   'HTR2B',
#   'TPM4',
#   'TPSAB1',
#   'RNF213',
#   'FAS',
#   'TPBG',
#   'PDGFB',
#   'VWA1',
#   'SIGLEC10',
#   'HLA-B',
#   'FSTL1',
#   'MILR1',
#   'TLK2P1',
#   'IGLV1-51',
#   'NGDN',
#   'JAM2',
#   'RAI14',
#   'PPFIBP1',
#   'CALD1',
#   'S100A11',
#   'LY96',
#   'OLR1',
#   'RUNX1',
#   'ZNF521',
#   'TBX3',
#   'CTHRC1',
#   'MAP4',
#   'IRAG1',
#   'TRIM22',
#   'AEBP1',
#   'IL2RG',
#   'MYO9B',
#   'PRDM1',
#   'PALD1',
#   'JAML',
#   'MALAT1',
#   'SAMD4A',
#   'SEPTIN4',
#   'SLC12A4',
#   'AXL',
#   'CST2',
#   'BASP1',
#   'MRC2',
#   'IGLC3',
#   'CHSY1',
#   'RASD2',
#   'SLA',
#   'NCF4',
#   'FBN1',
#   'FBLN1',
#   'ZCCHC24',
#   'TOP2A',
#   'IFI27',
#   'CD300A',
#   'TCP1',
#   'SLFN13',
#   'LPAR6',
#   'STKLD1',
#   'ITGB5',
#   'CASC15',
#   'COL16A1',
#   'APCDD1',
#   'VSIG4',
#   'TBX2',
#   'CCL19',
#   'GJA4',
#   'ANO1',
#   'NR2F1',
#   'HLA-DRB6',
#   'LILRB4',
#   'KCNE4',
#   'EIF4A2',
#   'TAFA4',
#   'CSF1',
#   'PROS1',
#   'COL18A1',
#   'FCGR2A',
#   'AC092490.2',
#   'LAMA2',
#   'TOM1L1',
#   'LAMA4',
#   'IL3RA',
#   'ITGA9',
#   'HES6',
#   'KIRREL1',
#   'HLA-C',
#   'HSPG2',
#   'SSC5D',
#   'CDKN1A',
#   'SCARA3',
#   'VAMP5',
#   'PMEPA1',
#   'RAB31',
#   'HCST',
#   'HLA-DQB1',
#   'TP73-AS3',
#   'IFITM2',
#   'TGFB3',
#   'RAMP3',
#   'SERPING1',
#   'ARHGAP15',
#   'TMEM128',
#   'EDN1',
#   'CXCL2',
#   'MCCC1',
#   'C1orf54',
#   'GAS2L3',
#   'LSP1',
#   'STING1',
#   'IFITM3',
#   'EPB41L5',
#   'SDS',
#   'IGLV2-23',
#   'NEMP2',
#   'CFH',
#   'SLC43A3',
#   'CCNB2',
#   'PDE7B',
#   'IKZF1',
#   'ROM1',
#   'GPR183',
#   'PCCB',
#   'LPCAT2',
#   'HSPB1',
#   'CENPF',
#   'HTRA3',
#   'ESAM',
#   'GIMAP2',
#   'EPHB4',
#   'ITPRIP',
#   'NTN1',
#   'TREM2',
#   'CCDC14',
#   'MPEG1',
#   'WFDC2',
#   'LRRTM2',
#   'RASGEF1B',
#   'IGKV3-15',
#   'ARHGAP31',
#   'DLGAP1-AS1',
#   'TIMP1',
#   'NID1',
#   'ECSCR',
#   'MYL9',
#   'CPNE5',
#   'ANTXR2',
#   'ITPKB',
#   'FOXC1',
#   'CYP1B1',
#   'APOBEC3C',
#   'CDH5',
#   'HLA-A',
#   'CTSC',
#   'THBS4-AS1',
#   'SLC20A2',
#   'CARD16',
#   'GAB3',
#   'AC108463.3',
#   'PLEK',
#   'CIITA',
#   'GPNMB',
#   'RECK',
#   'LRRCC1',
#   'CYTH4',
#   'A2M',
#   'REG3G',
#   'PLCB2',
#   'MRFAP1L1',
#   'CASP10',
#   'IFI16',
#   'DYSF',
#   'RNF6',
#   'MMP14',
#   'NENF',
#   'SRPX2',
#   'WIPF1',
#   'PCOLCE2',
#   'GABRP',
#   'UTRN',
#   'HLA-DQA1',
#   'TNFRSF11B',
#   'COL11A1',
#   'EVI2B',
#   'TSKU',
#   'SKAP2',
#   'TPM2',
#   'CCL5',
#   'PHYH',
#   'CTSS',
#   'SASH3',
#   'CACYBP',
#   'JAG2',
#   'FRMD4A',
#   'CRTAP',
#   'MCAM',
#   'CLEC14A',
#   'PYCARD',
#   'FILIP1L',
#   'TRAM2',
#   'LINC00958',
#   'IL16',
#   'SAMSN1',
#   'SPARC',
#   'GABRA2',
#   'CYGB',
#   'BIN2',
#   'TYMP',
#   'HSD11B1',
#   'AC243960.1',
#   'STAT5A',
#   'PLEKHO2',
#   'DOCK8',
#   'CRISPLD2',
#   'TTYH3',
#   'ENG',
#   'ANTXR1',
#   'DPYSL3',
#   'KCNK5',
#   'CD1D',
#   'UBXN2A',
#   'FGL2',
#   'ZNF2',
#   'RAPGEF2',
#   'MACROD2',
#   'GMFG',
#   'RHOJ',
#   'TRMO',
#   'NR2F2',
#   'SMARCD3',
#   'SHISA2',
#   'PLEKHA4',
#   'MCTP1',
#   'CTSK',
#   'CCDC162P',
#   'FNDC1',
#   'HSPA8',
#   'REEP1',
#   'KNTC1',
#   'SPON2',
#   'TTPAL',
#   'SYTL2',
#   'MN1',
#   'NRP2',
#   'RASSF2',
#   'CMKLR1',
#   'HCCS',
#   'HLA-DRB5',
#   'PDE1C',
#   'GFM2',
#   'DGKH',
#   'TFPI',
#   'HSPA9',
#   'SIRPA',
#   'TXNIP',
#   'DOCK6',
#   'IL18BP',
#   'TCN1',
#   'NUDT14',
#   'RASGRP3',
#   'TAP1',
#   'UACA',
#   'SUCNR1',
#   'C19orf18',
#   'HAND2',
#   'ADAMDEC1',
#   'ARHGAP9',
#   'SP110',
#   'OSBPL3',
#   'NNMT',
#   'EGFL7',
#   'PRSS23',
#   'RIOK1',
#   'NKX3-1',
#   'GLIPR1',
#   'LMO2',
#   'PADI2',
#   'ECM1',
#   'FOLR2',
#   'AOC1',
#   'FGG',
#   'ARHGDIB',
#   'P2RY6',
#   'PCDH12',
#   'ZNF280B',
#   'TIE1',
#   'RFLNB',
#   'TRAC',
#   'ELN',
#   'GEM',
#   'CD48',
#   'GPSM3',
#   'RPS27AP16',
#   'ARHGAP23',
#   'PPID',
#   'TMSB4X',
#   'NEDD4',
#   'TRIM5',
#   'ZNF44',
#   'CD58',
#   'TAX1BP3',
#   'LRRC32',
#   'EFEMP1',
#   'MZB1',
#   'AC097625.1',
#   'MEF2C',
#   'DHX9',
#   'F12',
#   'EPS8',
#   'APOL1',
#   'TPM3',
#   'C11orf96',
#   'CD300LF',
#   'SKI',
#   'TRBC1',
#   'SPRYD7',
#   'PSMB8-AS1',
#   'RPL7L1',
#   'IGFBP5',
#   'BRIX1',
#   'PIAS1',
#   'ARPC2',
#   'AKR1B10',
#   'PODXL',
#   'SEMA3G',
#   'NKD1',
#   'COL8A2',
#   'TRAF3IP3',
#   'BNC2',
#   'THBS2',
#   'DIPK2B',
#   'ITGA11',
#   'TOB1',
#   'FOXF1',
#   'ARHGAP29',
#   'OLFML3',
#   'ARHGEF2',
#   'PDLIM3',
#   'CMYA5',
#   'RGS10',
#   'PPM1F',
#   'IGSF3',
#   'NINJ2',
#   'MUC13',
#   'LAIR1',
#   'TSPYL1',
#   'MTUS1',
#   'GLIS3',
#   'ANKH',
#   'SRGN',
#   'TSPAN11',
#   'CPA3',
#   'PLEKHG1',
#   'GNG7',
#   'SERPINF1',
#   'EMP1',
#   'COL21A1',
#   'IL18',
#   'HLX',
#   'PLEKHO1',
#   'AC005229.4',
#   'SH3PXD2B',
#   'POSTN',
#   'CXCR4',
#   'CHL1',
#   'GOLT1A',
#   'THBS3',
#   'PFN1',
#   'MPP1',
#   'PECAM1',
#   'TNIP2',
#   'ZNF225',
#   'EBF1',
#   'ELP2',
#   'GNAL',
#   'TCF4',
#   'FAM102B',
#   'DGKQ',
#   'PPP1R16B',
#   'RCHY1',
#   'PLA2G2A',
#   'CXCL16',
#   'AGT',
#   'PYGL',
#   'SFRP2',
#   'TSPAN14',
#   'HNMT',
#   'LHFPL6',
#   'SLC15A2',
#   'PLAGL1',
#   'PXDC1',
#   'CD33',
#   'MBNL3',
#   'SAMD9L',
#   'RNASE6',
#   'TEAD2',
#   'LAX1',
#   'NR2F1-AS1',
#   'ARMCX5',
#   'TSPAN31',
#   'IGKV3-11',
#   'EGR3',
#   'MED28',
#   'MMP7',
#   'ZFHX4',
#   'CENPE',
#   'IGHA1',
#   'JAK3',
#   'GJC1',
#   'CCT5',
#   'ADCY3',
#   'COQ3',
#   'RHEX',
#   'CD69',
#   'MTCH2',
#   'PTTG1IP',
#   'TNFSF15',
#   'S100A13',
#   'ZCCHC8',
#   'MCM5',
#   'RGS1',
#   'PRPS1',
#   'MYH11',
#   'CYBRD1',
#   'UNC5D',
#   'ISG15',
#   'OLFML2B',
#   'PTGDS',
#   'HACL1',
#   'GLT8D2',
#   'TGFBI',
#   'IL33',
#   'HCK',
#   'VASP',
#   'OLFM4',
#   'AC103740.1',
#   'SLC22A3',
#   'CLEC2D',
#   'ADGRE2',
#   'CD93',
#   'ETFDH',
#   'EFEMP2',
#   'NEXMIF',
#   'STAT6',
#   'SP100',
#   'CLEC12A',
#   'ENO2',
#   'TRPC6',
#   'NOS3',
#   'GPR4',
#   'ADPRS',
#   'LRP10',
#   'HIP1',
#   'NOTCH4',
#   'ATP8B4',
#   'FPR3',
#   'WDR12',
#   'ADAP2',
#   'DAZAP1',
#   'PDP2',
#   'FOXF2',
#   'PRR5L',
#   'FCGR2B',
#   'FGD2',
#   'ABCC3',
#   'PEX11A',
#   'SHE',
#   'PLCG1-AS1',
#   'CCL4L2',
#   'ADGRL4',
#   'RARRES1',
#   'ANKRD36B',
#   'IFIT3',
#   'PTGIR',
#   'RFWD3',
#   'TMEM165',
#   'ITGB4',
#   'CCDC74A',
#   'SPPL2A',
#   'IGLV3-21',
#   'ADH5',
#   'NUSAP1',
#   'TRADD',
#   'RASSF3',
#   'CRYL1',
#   'IFI6',
#   'STARD8',
#   'LAGE3',
#   'MAF',
#   'GIMAP7',
#   'CNN3',
#   'ATP8B1-AS1',
#   'GPN3',
#   'FTLP14',
#   'PPIE',
#   'PEBP1',
#   'GRK5',
#   'IFNAR2',
#   'PAIP2',
#   'HEG1',
#   'YAP1',
#   'CHRDL2',
#   'FOSB',
#   'GLP1R',
#   'BEX4',
#   'ABCA6',
#   'EXPH5',
#   'NOTUM',
#   'MEAF6',
#   'C4BPA',
#   'ADCYAP1',
#   'HEYL',
#   'PPIC',
#   'SYTL4',
#   'VSIR',
#   'SASH1',
#   'CDKN1C',
#   'AC239809.3',
#   'DBH-AS1',
#   'FMOD',
#   'KLHL41',
#   'TOR4A',
#   'GASK1B',
#   'PTGS1',
#   'FLI1',
#   'LHFPL2',
#   'CCR1',
#   'KBTBD6',
#   'GLDN',
#   'CHST1',
#   'PIEZO2',
#   'TMEM140',
#   'JAG1',
#   'PTCD2',
#   'LMO4',
#   'SIN3B',
#   'GATD3',
#   'CLDN5',
#   'NUP155',
#   'LY86',
#   'TGFBR2',
#   'BMPR1B',
#   'ADAMTS12',
#   'PABPC1P3',
#   'PPT1',
#   'FAM20A',
#   'RGS12',
#   'DNAJC16',
#   'MMD',
#   'NCKAP1L',
#   'SLC16A4',
#   'YIPF6',
#   'ACSM6',
#   nan,
#   'FMNL2',
#   'SDC3',
#   'CCDC18',
#   'FAM241A',
#   'XRCC5',
#   'PSMB8',
#   'IGKV1-5',
#   'GUSBP18',
#   'SERINC2',
#   'FJX1',
#   'FAM89A',
#   'PDE8B',
#   'ZNF582',
#   'PPARGC1B',
#   'SEPTIN11',
#   'OSBPL10',
#   'EIF2A',
#   'ADAMTS9',
#   'BCL2A1',
#   'BACE2',
#   'AC131182.1',
#   'ACVR1B',
#   'LUZP1',
#   'AP1S2',
#   'AHNAK',
#   'PGM2L1',
#   'MED25',
#   'EYA3',
#   'PIK3R4',
#   'HES1',
#   'ZNF689',
#   'MELTF-AS1',
#   'TADA2A',
#   'HPGDS',
#   'SCGB2A1',
#   'RERG',
#   'ADCY4',
#   'TTI2',
#   'AOC3',
#   'PRKDC',
#   'FH',
#   'CD3G',
#   'RPS27AP11',
#   'AC092376.2',
#   'CPVL',
#   'CCNYL1',
#   'CLNS1A',
#   'NDC80',
#   'CSF3R',
#   'SHROOM4',
#   'CCDC102B',
#   'HOXA-AS2',
#   'NES',
#   'HOXA3',
#   'ZMPSTE24-DT',
#   'PLPP1',
#   'SMDT1',
#   'TPRG1',
#   'BMF',
#   'IGLV2-11',
#   'CD3E',
#   'SLIT2',
#   'THNSL1',
#   'VWF',
#   'IGHM',
#   'KAT7',
#   'LIMA1',
#   'CCT3',
#   'ACADSB',
#   'STX4',
#   'PLXND1',
#   'CBWD2',
#   'HMCN1',
#   'PHF11',
#   'TLR3',
#   'CCDC153',
#   'SBDS',
#   'DPP6',
#   'ADAM28',
#   'IGF1',
#   'OMG',
#   'FBXL7',
#   'VDAC2',
#   'PTGES3',
#   'NRP1',
#   'ZNF791',
#   'S100A6',
#   'PSMD1',
#   'UBA7',
#   'DRAM1',
#   'TNFSF13B',
#   'APOD',
#   'ZFC3H1',
#   'AHR',
#   'SLC22A18',
#   'EIF3L',
#   'ZNF253',
#   'TEK',
#   'ARHGAP30',
#   'HDC',
#   'COX4I2',
#   'RBMS1',
#   'FHL3',
#   'TM6SF1',
#   'SWAP70',
#   'SUCLA2',
#   'PPA1',
#   'C1orf21',
#   'SULF2',
#   'POLR3C',
#   'DBR1',
#   'PCAT19',
#   'HACD3',
#   'FKBP3',
#   'SLC16A14',
#   'SATB1-AS1',
#   'CRISPLD1',
#   'NDUFAF3',
#   'SNHG16',
#   'WDFY4',
#   'SCARF1',
#   'SLC12A2',
#   'FGD5',
#   'ANKRD36C',
#   'H2BU1',
#   'PLB1',
#   'PKP4',
#   'PPP1R3B',
#   'CCT8',
#   'MGP',
#   'MSX1',
#   'PDE8A',
#   'PMP22',
#   'LGALS3',
#   'ACSL5',
#   'FILIP1',
#   'SAMHD1',
#   'GPR161',
#   'ANKRD18A',
#   'TRIB2',
#   'TAPBP',
#   'DCN',
#   'CHN1',
#   'SH3GL2',
#   'BTBD17',
#   'ZFP36L1',
#   'LMCD1',
#   'GLP2R',
#   'ST13',
#   'DHFR',
#   'HDAC7',
#   'CASP8',
#   'LTBP2',
#   'EMC4',
#   'RFTN2',
#   'GBP5',
#   'COA3',
#   'OXTR',
#   'SLC1A1',
#   'PTGES3P1',
#   'PLAUR',
#   'CEPT1',
#   'PLXDC2',
#   'FCER1A',
#   'HCP5',
#   'REST',
#   'HS6ST2',
#   'SAT1',
#   'ITGAM',
#   'OAS2',
#   'IGF1R',
#   'TSPO',
#   'RPF1',
#   'RPRD2',
#   'COL13A1',
#   'PALMD',
#   'MTCO2P12',
#   'RILPL2',
#   'AC099509.1',
#   'SULT1C4',
#   'ZBED3',
#   'LOX',
#   'SLFN12',
#   'AMPH',
#   'ACTA2',
#   'LUM',
#   'TESPA1',
#   'CXCL10',
#   'POLR3A',
#   'GZMB',
#   'DCUN1D2',
#   'ACVR1C',
#   'ECM2',
#   'AFAP1L2',
#   'SUSD2',
#   'CSF2RB',
#   'COPS4',
#   'MTPAP',
#   'SLC45A2',
#   'MFAP4',
#   'AC108134.3',
#   'FLNA',
#   'CDK1',
#   'MIR4435-2HG',
#   'MORN4',
#   'PELI1',
#   'MSRB3',
#   'BTN3A3',
#   'MSRA',
#   'PPM1L-DT',
#   'HGF',
#   'LIMD1',
#   'SLC12A2-DT',
#   'SERPINE2',
#   'TOGARAM2',
#   'TRIM16',
#   'LRRTM3',
#   'APOL3',
#   'LOXL2',
#   'CCL21',
#   'SLFN5',
#   'PDGFRA',
#   'AC090197.1',
#   'IGKV4-1',
#   'IL18R1',
#   'EGR2',
#   'LAYN',
#   'TVP23B',
#   'MYO1F',
#   'TMEM17',
#   'ZNF423',
#   ...]}

# %%
gp.get_library_name()
# Out:
# ['ARCHS4_Cell-lines',
#  'ARCHS4_IDG_Coexp',
#  'ARCHS4_Kinases_Coexp',
#  'ARCHS4_TFs_Coexp',
#  'ARCHS4_Tissues',
#  'Achilles_fitness_decrease',
#  'Achilles_fitness_increase',
#  'Aging_Perturbations_from_GEO_down',
#  'Aging_Perturbations_from_GEO_up',
#  'Allen_Brain_Atlas_10x_scRNA_2021',
#  'Allen_Brain_Atlas_down',
#  'Allen_Brain_Atlas_up',
#  'Azimuth_2023',
#  'Azimuth_Cell_Types_2021',
#  'BioCarta_2013',
#  'BioCarta_2015',
#  'BioCarta_2016',
#  'BioPlanet_2019',
#  'BioPlex_2017',
#  'CCLE_Proteomics_2020',
#  'CORUM',
#  'COVID-19_Related_Gene_Sets',
#  'COVID-19_Related_Gene_Sets_2021',
#  'Cancer_Cell_Line_Encyclopedia',
#  'CellMarker_2024',
#  'CellMarker_Augmented_2021',
#  'ChEA_2013',
#  'ChEA_2015',
#  'ChEA_2016',
#  'ChEA_2022',
#  'Chromosome_Location',
#  'Chromosome_Location_hg19',
#  'ClinVar_2019',
#  'DSigDB',
#  'Data_Acquisition_Method_Most_Popular_Genes',
#  'DepMap_WG_CRISPR_Screens_Broad_CellLines_2019',
#  'DepMap_WG_CRISPR_Screens_Sanger_CellLines_2019',
#  'Descartes_Cell_Types_and_Tissue_2021',
#  'Diabetes_Perturbations_GEO_2022',
#  'DisGeNET',
#  'Disease_Perturbations_from_GEO_down',
#  'Disease_Perturbations_from_GEO_up',
#  'Disease_Signatures_from_GEO_down_2014',
#  'Disease_Signatures_from_GEO_up_2014',
#  'DrugMatrix',
#  'Drug_Perturbations_from_GEO_2014',
#  'Drug_Perturbations_from_GEO_down',
#  'Drug_Perturbations_from_GEO_up',
#  'ENCODE_Histone_Modifications_2013',
#  'ENCODE_Histone_Modifications_2015',
#  'ENCODE_TF_ChIP-seq_2014',
#  'ENCODE_TF_ChIP-seq_2015',
#  'ENCODE_and_ChEA_Consensus_TFs_from_ChIP-X',
#  'ESCAPE',
#  'Elsevier_Pathway_Collection',
#  'Enrichr_Libraries_Most_Popular_Genes',
#  'Enrichr_Submissions_TF-Gene_Coocurrence',
#  'Enrichr_Users_Contributed_Lists_2020',
#  'Epigenomics_Roadmap_HM_ChIP-seq',
#  'FANTOM6_lncRNA_KD_DEGs',
#  'GO_Biological_Process_2013',
#  'GO_Biological_Process_2015',
#  'GO_Biological_Process_2017',
#  'GO_Biological_Process_2017b',
#  'GO_Biological_Process_2018',
#  'GO_Biological_Process_2021',
#  'GO_Biological_Process_2023',
#  'GO_Cellular_Component_2013',
#  'GO_Cellular_Component_2015',
#  'GO_Cellular_Component_2017',
#  'GO_Cellular_Component_2017b',
#  'GO_Cellular_Component_2018',
#  'GO_Cellular_Component_2021',
#  'GO_Cellular_Component_2023',
#  'GO_Molecular_Function_2013',
#  'GO_Molecular_Function_2015',
#  'GO_Molecular_Function_2017',
#  'GO_Molecular_Function_2017b',
#  'GO_Molecular_Function_2018',
#  'GO_Molecular_Function_2021',
#  'GO_Molecular_Function_2023',
#  'GTEx_Aging_Signatures_2021',
#  'GTEx_Tissue_Expression_Down',
#  'GTEx_Tissue_Expression_Up',
#  'GTEx_Tissues_V8_2023',
#  'GWAS_Catalog_2019',
#  'GWAS_Catalog_2023',
#  'GeDiPNet_2023',
#  'GeneSigDB',
#  'Gene_Perturbations_from_GEO_down',
#  'Gene_Perturbations_from_GEO_up',
#  'Genes_Associated_with_NIH_Grants',
#  'Genome_Browser_PWMs',
#  'GlyGen_Glycosylated_Proteins_2022',
#  'HDSigDB_Human_2021',
#  'HDSigDB_Mouse_2021',
#  'HMDB_Metabolites',
#  'HMS_LINCS_KinomeScan',
#  'HomoloGene',
#  'HuBMAP_ASCT_plus_B_augmented_w_RNAseq_Coexpression',
#  'HuBMAP_ASCTplusB_augmented_2022',
#  'HumanCyc_2015',
#  'HumanCyc_2016',
#  'Human_Gene_Atlas',
#  'Human_Phenotype_Ontology',
#  'IDG_Drug_Targets_2022',
#  'InterPro_Domains_2019',
#  'Jensen_COMPARTMENTS',
#  'Jensen_DISEASES',
#  'Jensen_TISSUES',
#  'KEA_2013',
#  'KEA_2015',
#  'KEGG_2013',
#  'KEGG_2015',
#  'KEGG_2016',
#  'KEGG_2019_Human',
#  'KEGG_2019_Mouse',
#  'KEGG_2021_Human',
#  'KOMP2_Mouse_Phenotypes_2022',
#  'Kinase_Perturbations_from_GEO_down',
#  'Kinase_Perturbations_from_GEO_up',
#  'L1000_Kinase_and_GPCR_Perturbations_down',
#  'L1000_Kinase_and_GPCR_Perturbations_up',
#  'LINCS_L1000_CRISPR_KO_Consensus_Sigs',
#  'LINCS_L1000_Chem_Pert_Consensus_Sigs',
#  'LINCS_L1000_Chem_Pert_down',
#  'LINCS_L1000_Chem_Pert_up',
#  'LINCS_L1000_Ligand_Perturbations_down',
#  'LINCS_L1000_Ligand_Perturbations_up',
#  'Ligand_Perturbations_from_GEO_down',
#  'Ligand_Perturbations_from_GEO_up',
#  'MAGMA_Drugs_and_Diseases',
#  'MAGNET_2023',
#  'MCF7_Perturbations_from_GEO_down',
#  'MCF7_Perturbations_from_GEO_up',
#  'MGI_Mammalian_Phenotype_2013',
#  'MGI_Mammalian_Phenotype_2017',
#  'MGI_Mammalian_Phenotype_Level_3',
#  'MGI_Mammalian_Phenotype_Level_4',
#  'MGI_Mammalian_Phenotype_Level_4_2019',
#  'MGI_Mammalian_Phenotype_Level_4_2021',
#  'MSigDB_Computational',
#  'MSigDB_Hallmark_2020',
#  'MSigDB_Oncogenic_Signatures',
#  'Metabolomics_Workbench_Metabolites_2022',
#  'Microbe_Perturbations_from_GEO_down',
#  'Microbe_Perturbations_from_GEO_up',
#  'MoTrPAC_2023',
#  'Mouse_Gene_Atlas',
#  'NCI-60_Cancer_Cell_Lines',
#  'NCI-Nature_2015',
#  'NCI-Nature_2016',
#  'NIH_Funded_PIs_2017_AutoRIF_ARCHS4_Predictions',
#  'NIH_Funded_PIs_2017_GeneRIF_ARCHS4_Predictions',
#  'NIH_Funded_PIs_2017_Human_AutoRIF',
#  'NIH_Funded_PIs_2017_Human_GeneRIF',
#  'NURSA_Human_Endogenous_Complexome',
#  'OMIM_Disease',
#  'OMIM_Expanded',
#  'Old_CMAP_down',
#  'Old_CMAP_up',
#  'Orphanet_Augmented_2021',
#  'PFOCR_Pathways',
#  'PFOCR_Pathways_2023',
#  'PPI_Hub_Proteins',
#  'PanglaoDB_Augmented_2021',
#  'Panther_2015',
#  'Panther_2016',
#  'Pfam_Domains_2019',
#  'Pfam_InterPro_Domains',
#  'PheWeb_2019',
#  'PhenGenI_Association_2021',
#  'Phosphatase_Substrates_from_DEPOD',
#  'ProteomicsDB_2020',
#  'Proteomics_Drug_Atlas_2023',
#  'RNA-Seq_Disease_Gene_and_Drug_Signatures_from_GEO',
#  'RNAseq_Automatic_GEO_Signatures_Human_Down',
#  'RNAseq_Automatic_GEO_Signatures_Human_Up',
#  'RNAseq_Automatic_GEO_Signatures_Mouse_Down',
#  'RNAseq_Automatic_GEO_Signatures_Mouse_Up',
#  'Rare_Diseases_AutoRIF_ARCHS4_Predictions',
#  'Rare_Diseases_AutoRIF_Gene_Lists',
#  'Rare_Diseases_GeneRIF_ARCHS4_Predictions',
#  'Rare_Diseases_GeneRIF_Gene_Lists',
#  'Reactome_2013',
#  'Reactome_2015',
#  'Reactome_2016',
#  'Reactome_2022',
#  'Rummagene_kinases',
#  'Rummagene_signatures',
#  'Rummagene_transcription_factors',
#  'SILAC_Phosphoproteomics',
#  'SubCell_BarCode',
#  'SynGO_2022',
#  'SynGO_2024',
#  'SysMyo_Muscle_Gene_Sets',
#  'TF-LOF_Expression_from_GEO',
#  'TF_Perturbations_Followed_by_Expression',
#  'TG_GATES_2020',
#  'TRANSFAC_and_JASPAR_PWMs',
#  'TRRUST_Transcription_Factors_2019',
#  'Table_Mining_of_CRISPR_Studies',
#  'Tabula_Muris',
#  'Tabula_Sapiens',
#  'TargetScan_microRNA',
#  'TargetScan_microRNA_2017',
#  'The_Kinase_Library_2023',
#  'Tissue_Protein_Expression_from_Human_Proteome_Map',
#  'Tissue_Protein_Expression_from_ProteomicsDB',
#  'Transcription_Factor_PPIs',
#  'UK_Biobank_GWAS_v1',
#  'Virus-Host_PPI_P-HIPSTer_2020',
#  'VirusMINT',
#  'Virus_Perturbations_from_GEO_down',
#  'Virus_Perturbations_from_GEO_up',
#  'WikiPathway_2021_Human',
#  'WikiPathway_2023_Human',
#  'WikiPathways_2013',
#  'WikiPathways_2015',
#  'WikiPathways_2016',
#  'WikiPathways_2019_Human',
#  'WikiPathways_2019_Mouse',
#  'dbGaP',
#  'huMAP',
#  'lncHUB_lncRNA_Co-Expression',
#  'miRTarBase_2017']

# %%
import gseapy as gp

# Realiza el análisis de enriquecimiento de genes
pre_res = gp.prerank(rnk=ranking_padj.reset_index(drop=True),
                     gene_sets=['Reactome_2022', manual_set_adj],
                     seed=6, permutation_num=100)
pre_res
# Out:
# 2024-04-25 12:18:56,577 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2024-04-25 12:18:56,581 [WARNING] Duplicated values found in preranked stats: 30.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.

# %%
out=[]

for term in list(pre_res.results):
    out.append([term,
               pre_res.results[term]['fdr'],
               pre_res.results[term]['es'],
               pre_res.results[term]['nes']])
out_df=pd.DataFrame(out, columns=['Term','fdr','es','nes']).sort_values('fdr').reset_index(drop=True)
out_df
# Out:
#                                                   Term       fdr        es  \
# 0    Reactome_2022__Signaling By Nuclear Receptors ...  0.737731  0.571265
# 1    Reactome_2022__Toll Like Receptor 4 (TLR4) Cas...  0.746990  0.594268
# 2    Reactome_2022__ESR-mediated Signaling R-HSA-89...  0.756464  0.595338
# 3    Reactome_2022__Peptide Ligand-Binding Receptor...  0.766214  0.567992
# 4      Reactome_2022__GPCR Ligand Binding R-HSA-500792  0.769994  0.544882
# ..                                                 ...       ...       ...
# 106  Reactome_2022__Toll-like Receptor Cascades R-H...  1.000000  0.500146
# 107  Reactome_2022__Response To Elevated Platelet C...  1.000000  0.350035
# 108  Reactome_2022__Integrin Cell Surface Interacti...  1.000000  0.410770
# 109   Reactome_2022__Innate Immune System R-HSA-168249  1.000000  0.358740
# 110      Reactome_2022__Signaling By VEGF R-HSA-194138  1.000000  0.545367
#
#           nes
# 0    1.204526
# 1    1.223980
# 2    1.233473
# 3    1.192308
# 4    1.179404
# ..        ...
# 106  1.037425
# 107  0.726971
# 108  0.839799
# 109  0.815081
# 110  1.079999
#
# [111 rows x 4 columns]

# %% [markdown]
# ### GSEA filtrat per nes:

# %%
#ranking = res[['Symbol', 'stat']].dropna().sort_values('stat', ascending = False)
#ranking

# %%
#ranking=ranking.drop_duplicates('Symbol') #elimina els symbols duplicats
#ranking

# %%
#manual_set = {'things':['IGHG1','MKI67','IGKC','COL5A2','IGLV2-14']}
#manual_set

# %%
#gp.get_library_name()

# %%
#pre_res = gp.prerank(rnk=ranking.reset_index(drop=True),
 #                    gene_sets=['Reactome_2022', manual_set],
  #                   seed=6, permutation_num=100)
#pre_res

# %%
#out=[]

#for term in list(pre_res.results):
 #   out.append([term,
  #             pre_res.results[term]['fdr'],
   #            pre_res.results[term]['es'],
    #           pre_res.results[term]['nes']])
#out_df=pd.DataFrame(out, columns=['Term','fdr','es','nes']).sort_values('fdr').reset_index(drop=True)
#out_df

#fdr= p_value corrected
#es=enrichment score
#nes= normalized enrichment score

# %%
#print(out_df.head(20))

# %%
#nes=out_df.sort_values('nes')
#print(nes.head(20))

# %% [markdown]
# ### ClusterMap:

# %%
import numpy as np
import seaborn as sns

dds.layers['normed_counts']
# Out:
# array([[2.04358515e+02, 0.00000000e+00, 7.57648325e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 2.17402676e+00],
#        [2.49917706e+02, 0.00000000e+00, 7.51015329e+02, ...,
#         6.31105319e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.27797770e+02, 0.00000000e+00, 6.27353581e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [5.30186095e+02, 5.99564243e+00, 8.05129127e+02, ...,
#         3.42608139e+00, 0.00000000e+00, 2.56956104e+00],
#        [3.15758986e+02, 0.00000000e+00, 8.71704308e+02, ...,
#         7.48244041e-01, 0.00000000e+00, 1.49648808e+00],
#        [3.11756175e+02, 0.00000000e+00, 8.02091130e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 6.05351796e+00]])

# %%
dds.layers['log1p']=np.log1p(dds.layers['normed_counts'])
dds
# Out:
# AnnData object with n_obs × n_vars = 53 × 48221
#     obs: 'condition'
#     uns: 'trend_coeffs', 'disp_function_type', '_squared_logres', 'prior_disp_var', 'pca', 'condition_colors'
#     obsm: 'design_matrix', 'size_factors', 'replaceable', 'X_pca'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'refitted', 'PCs'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks', 'log1p'

# %% [markdown]
# ### Clustermap de Valors normalitzats transformats a log1:

# %%
grapher=pd.DataFrame(dds.layers['log1p'].T,
                    index=dds.var_names, columns=dds.obs_names) #dataframe con los valores filtrados de mayor expression i con los valores transformados a log +1.
grapher
# Out:
# Sample           ND_counts  ND_counts.1  ND_counts.2  ND_counts.3  \
# ENSG00000000003   5.324757     5.525125     6.060985     5.338213
# ENSG00000000005   0.000000     0.000000     0.000000     0.000000
# ENSG00000000419   6.631538     6.622757     6.443103     6.495427
# ENSG00000000457   5.534129     5.670040     5.168273     5.674641
# ENSG00000000460   4.870258     4.684793     3.546020     4.592718
# ...                    ...          ...          ...          ...
# ENSG00000285483   0.000000     0.000000     0.000000     0.000000
# ENSG00000285486   0.735734     0.000000     0.000000     1.077011
# ENSG00000285492   0.000000     1.989387     0.000000     1.764684
# ENSG00000285498   0.000000     0.000000     0.000000     0.000000
# ENSG00000285509   1.155001     0.000000     0.000000     2.168318
#
# Sample           ND_counts.4  ND_counts.5  ND_counts.6  ND_counts.7  \
# ENSG00000000003     6.440352     6.110130     6.016299     5.469679
# ENSG00000000005     3.521804     0.000000     0.000000     0.000000
# ENSG00000000419     6.761996     7.222909     6.645755     6.095779
# ENSG00000000457     5.687128     5.691516     5.782543     5.812445
# ENSG00000000460     4.289735     3.427177     4.568465     4.623949
# ...                      ...          ...          ...          ...
# ENSG00000285483     0.000000     0.000000     1.719011     0.000000
# ENSG00000285486     0.000000     0.000000     0.000000     2.852755
# ENSG00000285492     0.000000     1.482633     1.399377     2.361713
# ENSG00000285498     0.000000     0.000000     0.000000     0.000000
# ENSG00000285509     3.317423     2.338188     1.571911     0.000000
#
# Sample           ND_counts.8  ND_counts.9  ...  T3cD_counts.25  \
# ENSG00000000003     5.084494     4.626575  ...        5.568999
# ENSG00000000005     0.000000     0.000000  ...        0.609646
# ENSG00000000419     6.156028     6.198358  ...        6.644518
# ENSG00000000457     5.546497     5.385430  ...        5.210755
# ENSG00000000460     4.397519     4.626575  ...        3.854138
# ...                      ...          ...  ...             ...
# ENSG00000285483     0.000000     0.000000  ...        0.000000
# ENSG00000285486     0.000000     0.000000  ...        0.000000
# ENSG00000285492     1.536369     0.000000  ...        0.609646
# ENSG00000285498     1.536369     0.000000  ...        0.000000
# ENSG00000285509     0.000000     1.938856  ...        1.648447
#
# Sample           T3cD_counts.26  T3cD_counts.27  T3cD_counts.28  \
# ENSG00000000003        5.977383        6.133180        6.057109
# ENSG00000000005        0.000000        0.940298        0.000000
# ENSG00000000419        6.736603        6.344076        6.705406
# ENSG00000000457        5.335466        5.275933        5.463908
# ENSG00000000460        3.170321        3.635944        3.088107
# ...                         ...             ...             ...
# ENSG00000285483        0.000000        0.000000        0.000000
# ENSG00000285486        0.000000        0.000000        0.000000
# ENSG00000285492        1.780530        0.000000        1.619791
# ENSG00000285498        0.000000        0.000000        1.476294
# ENSG00000285509        2.265169        0.000000        0.516015
#
# Sample           T3cD_counts.29  T3cD_counts.30  T3cD_counts.31  \
# ENSG00000000003        6.669712        6.227522        5.402223
# ENSG00000000005        0.000000        0.000000        1.411070
# ENSG00000000419        6.571651        6.418294        6.718096
# ENSG00000000457        5.632287        5.607390        5.446631
# ENSG00000000460        4.385560        4.372697        3.390411
# ...                         ...             ...             ...
# ENSG00000285483        0.000000        0.000000        0.000000
# ENSG00000285486        0.000000        0.000000        0.000000
# ENSG00000285492        0.000000        1.509639        1.974175
# ENSG00000285498        0.000000        0.000000        0.000000
# ENSG00000285509        2.933764        0.879643        0.000000
#
# Sample           T3cD_counts.32  T3cD_counts.33  T3cD_counts.34
# ENSG00000000003        6.275112        5.758141        5.745424
# ENSG00000000005        1.945287        0.000000        0.000000
# ENSG00000000419        6.692244        6.771597        6.688468
# ENSG00000000457        5.565984        5.616252        5.449093
# ENSG00000000460        3.070677        3.809911        3.900520
# ...                         ...             ...             ...
# ENSG00000285483        1.814682        0.000000        0.000000
# ENSG00000285486        0.000000        0.000000        0.000000
# ENSG00000285492        1.487515        0.558612        0.000000
# ENSG00000285498        0.000000        0.000000        0.000000
# ENSG00000285509        1.272443        0.914885        1.953526
#
# [48221 rows x 53 columns]

# %%
sns.clustermap(grapher, z_score=0, cmap='RdYlBu_r', cbar_kws={'label':'row Z-Score'})
# Out:
# C:\Users\NOE\anaconda3\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# C:\Users\NOE\anaconda3\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reorganizar las muestras
nd_samples = [col for col in grapher.columns if "ND" in col]
T3cD_samples = [col for col in grapher.columns if "T3cD" in col]

ordered_columns = nd_samples + T3cD_samples

grapher_ordered = grapher[ordered_columns]

# Crear el clustermap utilizando seaborn
plt.figure(figsize=(14, 10))
sns.clustermap(grapher_ordered, z_score=0, cmap="RdYlBu_r", col_cluster=False, cbar_kws={'label':'row Z-Score'})

plt.show()
# Out:
# C:\Users\NOE\anaconda3\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# ### Clustermap dels gens més significatius:

# %%
dds_sigs=dds[:, sigs.index]
dds_sigs.obs
# Out:
#                condition
# Sample
# ND_counts             ND
# ND_counts.1           ND
# ND_counts.2           ND
# ND_counts.3           ND
# ND_counts.4           ND
# ND_counts.5           ND
# ND_counts.6           ND
# ND_counts.7           ND
# ND_counts.8           ND
# ND_counts.9           ND
# ND_counts.10          ND
# ND_counts.11          ND
# ND_counts.12          ND
# ND_counts.13          ND
# ND_counts.14          ND
# ND_counts.15          ND
# ND_counts.16          ND
# ND_counts.17          ND
# T3cD_counts         T3cD
# T3cD_counts.1       T3cD
# T3cD_counts.2       T3cD
# T3cD_counts.3       T3cD
# T3cD_counts.4       T3cD
# T3cD_counts.5       T3cD
# T3cD_counts.6       T3cD
# T3cD_counts.7       T3cD
# T3cD_counts.8       T3cD
# T3cD_counts.9       T3cD
# T3cD_counts.10      T3cD
# T3cD_counts.11      T3cD
# T3cD_counts.12      T3cD
# T3cD_counts.13      T3cD
# T3cD_counts.14      T3cD
# T3cD_counts.15      T3cD
# T3cD_counts.16      T3cD
# T3cD_counts.17      T3cD
# T3cD_counts.18      T3cD
# T3cD_counts.19      T3cD
# T3cD_counts.20      T3cD
# T3cD_counts.21      T3cD
# T3cD_counts.22      T3cD
# T3cD_counts.23      T3cD
# T3cD_counts.24      T3cD
# T3cD_counts.25      T3cD
# T3cD_counts.26      T3cD
# T3cD_counts.27      T3cD
# T3cD_counts.28      T3cD
# T3cD_counts.29      T3cD
# T3cD_counts.30      T3cD
# T3cD_counts.31      T3cD
# T3cD_counts.32      T3cD
# T3cD_counts.33      T3cD
# T3cD_counts.34      T3cD

# %%
grapher1=pd.DataFrame(dds_sigs.layers['log1p'].T,
                    index=dds_sigs.var_names, columns=dds_sigs.obs_names) #dataframe con los valores filtrados de mayor expression i con los valores transformados a log +1.
grapher1
# Out:
# Sample           ND_counts  ND_counts.1  ND_counts.2  ND_counts.3  \
# ENSG00000000938   3.023651     0.816342     3.509388     2.168318
# ENSG00000000971   3.481959     5.035181     6.379596     3.146854
# ENSG00000002726   2.152819     2.406737     2.138105     0.000000
# ENSG00000003400   0.735734     3.053783     3.953859     0.676990
# ENSG00000009790   0.000000     0.000000     2.600631     1.361960
# ...                    ...          ...          ...          ...
# ENSG00000275832   0.000000     0.816342     2.845718     2.802580
# ENSG00000276070   1.676733     2.148649     1.789907     0.000000
# ENSG00000277734   3.865803     0.000000     4.242726     0.000000
# ENSG00000279355   1.449513     1.799867     2.275272     2.455083
# ENSG00000282608   0.000000     1.799867     3.471364     0.000000
#
# Sample           ND_counts.4  ND_counts.5  ND_counts.6  ND_counts.7  \
# ENSG00000000938     0.000000     1.482633     2.155440     0.673409
# ENSG00000000971     4.200068     5.224108     5.441178     1.356539
# ENSG00000002726     3.131004     0.000000     2.390705     2.795729
# ENSG00000003400     3.424826     4.145237     3.565088     3.544774
# ENSG00000009790     0.941595     2.558455     3.426331     1.356539
# ...                      ...          ...          ...          ...
# ENSG00000275832     0.000000     3.245822     2.960936     1.577667
# ENSG00000276070     0.000000     2.417125     2.834773     2.670884
# ENSG00000277734     0.000000     0.615797     3.107663     0.000000
# ENSG00000279355     0.000000     0.994090     2.458251     3.986204
# ENSG00000282608     0.000000     3.212120     2.920625     3.257468
#
# Sample           ND_counts.8  ND_counts.9  ...  T3cD_counts.25  \
# ENSG00000000938     1.536369     1.938856  ...        2.969140
# ENSG00000000971     2.115698     3.083183  ...        5.986995
# ENSG00000002726     3.278419     1.380125  ...        2.830611
# ENSG00000003400     3.130530     1.938856  ...        4.837291
# ENSG00000009790     2.480150     0.000000  ...        1.798186
# ...                      ...          ...  ...             ...
# ENSG00000275832     2.480150     0.000000  ...        4.293484
# ENSG00000276070     2.115698     2.295177  ...        1.648447
# ENSG00000277734     0.000000     1.380125  ...        2.779815
# ENSG00000279355     4.143304     2.764871  ...        3.591012
# ENSG00000282608     0.000000     2.557350  ...        3.780291
#
# Sample           T3cD_counts.26  T3cD_counts.27  T3cD_counts.28  \
# ENSG00000000938        1.547510        2.927906        3.876887
# ENSG00000000971        6.166296        7.260044        6.564462
# ENSG00000002726        2.128173        3.811564        3.024554
# ENSG00000003400        4.292446        4.329625        5.021249
# ENSG00000009790        2.265169        2.778024        3.118430
# ...                         ...             ...             ...
# ENSG00000275832        3.930779        4.108060        3.773826
# ENSG00000276070        3.336890        4.712163        4.043983
# ENSG00000277734        2.970351        4.046324        3.876887
# ENSG00000279355        3.685057        3.845496        1.956998
# ENSG00000282608        2.385639        3.740039        3.204244
#
# Sample           T3cD_counts.29  T3cD_counts.30  T3cD_counts.31  \
# ENSG00000000938        3.092601        2.961684        3.558308
# ENSG00000000971        7.057840        7.457336        6.094864
# ENSG00000002726        2.635063        4.025200        3.336765
# ENSG00000003400        4.858446        4.466050        4.053196
# ENSG00000009790        3.229632        3.466387        2.755355
# ...                         ...             ...             ...
# ENSG00000275832        3.643216        3.444123        3.983521
# ENSG00000276070        3.482822        3.129196        1.974175
# ENSG00000277734        4.971167        4.336467        4.248246
# ENSG00000279355        2.889774        3.189061        3.465842
# ENSG00000282608        3.055194        4.407660        3.219981
#
# Sample           T3cD_counts.32  T3cD_counts.33  T3cD_counts.34
# ENSG00000000938        3.109642        5.039482        2.513684
# ENSG00000000971        6.830920        6.629990        6.826427
# ENSG00000002726        4.823011        4.540976        2.232547
# ENSG00000003400        4.698461        4.787248        3.734360
# ENSG00000009790        2.496074        4.083672        1.712019
# ...                         ...             ...             ...
# ENSG00000275832        3.855497        4.058139        4.155835
# ENSG00000276070        5.536048        4.005032        1.712019
# ENSG00000277734        2.422876        6.241342        2.055432
# ENSG00000279355        3.147145        3.302796        2.991586
# ENSG00000282608        2.060789        4.120788        1.840046
#
# [661 rows x 53 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reorganizar las muestras
nd_samples1 = [col for col in grapher1.columns if "ND" in col]
T3cD_samples1 = [col for col in grapher1.columns if "T3cD" in col]

ordered_columns1 = nd_samples1 + T3cD_samples1

grapher_ordered1 = grapher1[ordered_columns1]

# Crear el clustermap utilizando seaborn
plt.figure(figsize=(14, 10))
sns.clustermap(grapher_ordered1, z_score=0, cmap="RdYlBu_r", col_cluster=False, cbar_kws={'label':' row Z-Score'})

plt.show()
# Out:
# C:\Users\NOE\anaconda3\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# ### VolcanoPlot:

# %%
from sanbomics.plots import volcano

res
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003  417.376683        0.499057  0.213201  2.340781  0.019243
# ENSG00000000419  741.428087        0.000253  0.119866  0.002110  0.998316
# ENSG00000000457  261.221263       -0.179551  0.100580 -1.785161  0.074235
# ENSG00000000460   55.605341       -0.581161  0.192089 -3.025475  0.002482
# ENSG00000000938   20.314068        1.283865  0.410055  3.130959  0.001742
# ...                     ...             ...       ...       ...       ...
# ENSG00000285399   18.676032        0.380185  0.355859  1.068356  0.285360
# ENSG00000285410  173.379526        0.174970  0.156829  1.115671  0.264563
# ENSG00000285417   10.993998        0.484542  0.371533  1.304167  0.192177
# ENSG00000285437   16.731025        0.029717  0.287128  0.103498  0.917568
# ENSG00000285476   38.121039       -0.434955  0.290811 -1.495663  0.134742
#
#                      padj      Symbol
# ENSG00000000003  0.153742      TSPAN6
# ENSG00000000419  0.999436        DPM1
# ENSG00000000457  0.330722       SCYL3
# ENSG00000000460  0.042817    C1orf112
# ENSG00000000938  0.033624         FGR
# ...                   ...         ...
# ENSG00000285399  0.636390         NaN
# ENSG00000285410  0.616324  GABPB1-IT1
# ENSG00000285417  0.530044         NaN
# ENSG00000285437  0.972184     POLR2J3
# ENSG00000285476  0.449021         NaN
#
# [17527 rows x 7 columns]

# %%
volcano(res, symbol='Symbol')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Datos
t_results = pd.DataFrame({
    'gen': res['Symbol'],
    'p_value': res['pvalue'],
    'q_value': res['padj'],
    'LogFC': res['log2FoldChange']
})

t_results['sign'] = 'NORMAL'
for idx, row in t_results.iterrows():
    if row['q_value'] < 0.05 and row['LogFC'] > 1:
        t_results.loc[idx, 'sign'] = 'UP'
    elif row['q_value'] < 0.05 and row['LogFC'] < -1:
        t_results.loc[idx, 'sign'] = 'DOWN'

t_sign = t_results[t_results['sign'] != 'NORMAL']

# Crear el Volcano Plot
plt.figure(figsize=(10, 6))
colors = {"NORMAL": "#D2D2D2", "UP": "#FF6462", "DOWN": "#62B8FF"}

sns.scatterplot(x=t_results['LogFC'], y=-np.log10(t_results['q_value']), hue=t_results['sign'], palette=colors, alpha=0.7)
plt.axhline(-np.log10(0.05), color='k', linestyle='--', linewidth=1, label='THRESHOLD')
plt.axvline(1, color='k', linestyle='--', linewidth=1)
plt.axvline(-1, color='k', linestyle='--', linewidth=1)

# Etiquetas y título
plt.xlabel('Diferencia')
plt.ylabel('-log10(q-value)')
plt.title('DE OF T3cD vs No Diabetes')
plt.legend()
plt.grid(True)

# Filtrar los genes UP más significativos
up_genes = t_results[t_results['sign'] == 'UP'].nsmallest(5, 'q_value')

for idx, row in up_genes.iterrows():
    plt.text(row['LogFC'], -np.log10(row['q_value']), row['gen'], fontsize=8, ha='center', va='bottom')

# Filtrar los genes DOWN más significativos
down_genes = t_results[t_results['sign'] == 'DOWN'].nsmallest(5, 'q_value')

for idx, row in down_genes.iterrows():
    plt.text(row['LogFC'], -np.log10(row['q_value']), row['gen'], fontsize=8, ha='center', va='bottom')

plt.show()

# %%
print("Genes diferencialmente expresados con su q-value y dirección:")
de=t_sign[['gen', 'q_value', 'sign']]
de=de.sort_values(by='q_value', ascending=False)
de
# Out:
# Genes diferencialmente expresados con su q-value y dirección:
#                         gen       q_value sign
# ENSG00000104267         CA2  4.960574e-02   UP
# ENSG00000114251       WNT5A  4.912885e-02   UP
# ENSG00000229989  MIR181A1HG  4.847124e-02   UP
# ENSG00000127533       F2RL3  4.846448e-02   UP
# ENSG00000136689       IL1RN  4.803738e-02   UP
# ...                     ...           ...  ...
# ENSG00000106333      PCOLCE  1.625936e-07   UP
# ENSG00000204262      COL5A2  1.625936e-07   UP
# ENSG00000211592        IGKC  8.769822e-08   UP
# ENSG00000148773       MKI67  1.374346e-08   UP
# ENSG00000211896       IGHG1  1.374346e-08   UP
#
# [661 rows x 3 columns]
